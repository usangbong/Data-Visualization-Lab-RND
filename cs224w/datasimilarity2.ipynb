# %% [markdown]
# ## Cosine similarity
#  - 내적 공간내의 두 벡터(변수) 사이의 cosine값을 이용하여 벡터간의 유사도 측정
#  - vector의 크기보다는 방향에 초점을 맞춘 방법.(크기는 의미 없다)
#  - 결과값은 [0,1]의 범위에서 나온다.
#  ![image.png](attachment:image.png)
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Jaccard similarity
#  - 두 집합들의 유사도를 측정하는 방법
#  - 두 집합의 공통 변수의 개수를 count하는 방식
#  - 측정값은 [0,1]의 범위를 가짐
#  - 현재 cosine similarity와 마찬가지로 text similarity 측정으로 많이 사용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
