# %%
data = pd.read_csv('data/gang_csv.csv')

# %%
data
# Out:
#       1220029700  1220032100  1220033000  1220024600  1220028200  1210030000  \
# 0          25.19       29.65       28.08       25.14       20.30       36.73
# 1          26.96       24.27       26.63       26.65       20.49       36.74
# 2          26.20       28.07       27.76       24.94       22.35       32.30
# 3          26.72       23.98       26.34       27.54       24.68       40.67
# 4          27.21       24.11       26.63       24.71       19.57       32.51
# ...          ...         ...         ...         ...         ...         ...
# 2875       25.93       30.45       24.45       33.18       15.57       31.32
# 2876       28.45       27.57       25.38       26.65       14.22       37.60
# 2877       25.24       27.17       25.96       30.91       14.31       29.73
# 2878       28.05       27.64       26.57       27.84       14.21       36.52
# 2879       26.72       25.60       25.77       29.72       16.04       32.49
#
#       1220025300  1220029200  1220034000  1220034300  ...  1220026300  \
# 0          28.74       31.59       32.78       27.48  ...       31.11
# 1          26.28       28.80       30.56       26.95  ...       30.26
# 2          27.88       32.74       32.22       35.34  ...       33.27
# 3          29.85       27.55       28.83       31.98  ...       32.80
# 4          26.93       29.77       30.60       28.39  ...       30.48
# ...          ...         ...         ...         ...  ...         ...
# 2875       20.59       30.61       29.28       23.61  ...       19.85
# 2876       22.52       28.59       31.06       23.44  ...       24.13
# 2877       22.32       33.68       27.55       24.82  ...       22.21
# 2878       19.66       34.09       38.60       23.98  ...       24.17
# 2879       22.76       32.24       29.45       23.94  ...       18.84
#
#       1220033400  1220025200  1220033100  1220031800  1220033300  1220031000  \
# 0          31.87       25.61       35.04       36.00       31.82       25.18
# 1          34.42       26.18       34.95       36.61       30.24       25.07
# 2          24.70       24.06       31.08       37.30       27.94       24.16
# 3          30.08       26.93       35.77       34.74       27.34       25.15
# 4          26.82       26.36       32.22       38.51       28.47       23.82
# ...          ...         ...         ...         ...         ...         ...
# 2875       25.20       27.80       31.92       30.67       24.67       29.33
# 2876       22.81       30.25       33.22       30.90       35.58       24.49
# 2877       23.94       30.70       37.34       36.29       26.00       27.74
# 2878       20.92       29.39       31.57       32.62       27.73       31.33
# 2879       24.23       31.18       35.69       34.26       32.76       24.97
#
#       1220034600  1220032800  1220026800
# 0          24.80       17.00       29.09
# 1          21.33       26.80       28.95
# 2          30.84       24.68       31.14
# 3          27.20       24.02       33.40
# 4          30.69       23.19       33.97
# ...          ...         ...         ...
# 2875       27.84       25.39       19.88
# 2876       20.18       23.27       20.13
# 2877       24.46       27.52       21.00
# 2878       30.03       22.63       20.20
# 2879       27.84       24.15       19.11
#
# [2880 rows x 58 columns]

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE] [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}] [--log_interval LOG_INTERVAL]
#                   [--seed SEED] [--dilation_coefficient DILATION_COEFFICIENT] [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be found is kernel size - 1. Recommended to
#                         be equal to dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss is significant enough to label a
#                         potential cause as true (validated) cause. See paper for more details (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key for each dataset containing multivariate
#                         time series (required file format: csv, a column with header for each time series) and a value
#                         for the corresponding ground truth (required file format: csv, no header, index of cause in
#                         first column, index of effect in second column, time delay between cause and effect in third
#                         column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF containing multiple time series. Required
#                         file format: csv with a column (incl. header) for each time series

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/gang_csv.csv --cuda --significance 0.99 --hidden_layers 2 --kernel_size 58 --log_interval 500 --epochs 1000 --plot
# Out:
# Arguments: Namespace(cuda=True, data=['data/gang_csv.csv'], dilation_coefficient=4, epochs=1000, ground_truth=None, hidden_layers=2, kernel_size=58, learning_rate=0.01, log_interval=500, optimizer='Adam', plot=True, seed=1111, significance=0.99)
# WARNING: The dilation coefficient is not equal to the kernel size. Multiple paths can lead to the same delays. Set kernel_size equal to dilation_c to have exaxtly one path for each delay.
#
#  Dataset:  gang_csv.csv
#
#  Analysis started for target:  1220029700
# Epoch:  1 [0%] 	Loss: 728.800293
# Epoch: 500 [50%] 	Loss: 2.041884
# Epoch: 1000 [100%] 	Loss: 1.186946
# Potential causes:  [29, 21, 11, 8]
# Validated causes:  []
#
#  Analysis started for target:  1220032100
# Epoch:  1 [0%] 	Loss: 717.356934
# Epoch: 500 [50%] 	Loss: 5.243124
# Epoch: 1000 [100%] 	Loss: 0.822605
# Potential causes:  [11, 39, 43, 29, 41, 31, 42, 7, 5, 34, 21, 8, 40]
# Validated causes:  [11, 39, 41, 31, 42, 7, 34, 21]
#
#  Analysis started for target:  1220033000
# Epoch:  1 [0%] 	Loss: 711.336792
# Epoch: 500 [50%] 	Loss: 2.166984
# Epoch: 1000 [100%] 	Loss: 0.913724
# Potential causes:  [42, 40]
# Validated causes:  []
#
#  Analysis started for target:  1220024600
# Epoch:  1 [0%] 	Loss: 548.647949
# Epoch: 500 [50%] 	Loss: 3.421317
# Epoch: 1000 [100%] 	Loss: 0.885594
# Potential causes:  [39, 8, 31]
# Validated causes:  [31]
#
#  Analysis started for target:  1220028200
# Epoch:  1 [0%] 	Loss: 310.845947
# Epoch: 500 [50%] 	Loss: 2.530890
# Epoch: 1000 [100%] 	Loss: 1.008399
# Potential causes:  [52, 39]
# Validated causes:  []
#
#  Analysis started for target:  1210030000
# Epoch:  1 [0%] 	Loss: 850.889099
# Epoch: 500 [50%] 	Loss: 2.878390
# Epoch: 1000 [100%] 	Loss: 75.115028
# Potential causes:  [42, 54, 41, 43, 6, 2, 7, 23, 4, 36, 49, 56, 8, 38, 50, 10, 35, 29, 24, 17, 47, 31]
# Validated causes:  [31]
#
#  Analysis started for target:  1220025300
# Epoch:  1 [0%] 	Loss: 619.265930
# Epoch: 500 [50%] 	Loss: 2.323143
# Epoch: 1000 [100%] 	Loss: 1.116723
# Potential causes:  [8, 14, 7, 41, 39, 42, 31, 52, 34, 54, 46]
# Validated causes:  [31]
#
#  Analysis started for target:  1220029200
# Epoch:  1 [0%] 	Loss: 790.759033
# Epoch: 500 [50%] 	Loss: 4.678805
# Epoch: 1000 [100%] 	Loss: 1.098284
# Potential causes:  [34, 42, 39]
# Validated causes:  [34]
#
#  Analysis started for target:  1220034000
# Epoch:  1 [0%] 	Loss: 819.105896
# Epoch: 500 [50%] 	Loss: 3.777364
# Epoch: 1000 [100%] 	Loss: 0.732742
# Potential causes:  [31, 18]
# Validated causes:  [31, 18]
#
#  Analysis started for target:  1220034300
# Epoch:  1 [0%] 	Loss: 638.394531
# Epoch: 500 [50%] 	Loss: 3.923156
# Epoch: 1000 [100%] 	Loss: 0.970841
# Potential causes:  [8, 10, 5, 42]
# Validated causes:  []
#
#  Analysis started for target:  1220027500
# Epoch:  1 [0%] 	Loss: 713.484192
# Epoch: 500 [50%] 	Loss: 2.402820
# Epoch: 1000 [100%] 	Loss: 45.202129
# Potential causes:  [39, 33, 21, 10, 29, 34, 48, 42, 7]
# Validated causes:  []
#
#  Analysis started for target:  1220034200
# Epoch:  1 [0%] 	Loss: 523.273254
# Epoch: 500 [50%] 	Loss: 3.258010
# Epoch: 1000 [100%] 	Loss: 0.886046
# Potential causes:  [8, 31, 39]
# Validated causes:  [31]
#
#  Analysis started for target:  1220026100
# Epoch:  1 [0%] 	Loss: 802.003662
# Epoch: 500 [50%] 	Loss: 2.763364
# Epoch: 1000 [100%] 	Loss: 2.094900
# Potential causes:  [39, 41, 29]
# Validated causes:  []
#
#  Analysis started for target:  1220033700
# Epoch:  1 [0%] 	Loss: 597.488892
# Epoch: 500 [50%] 	Loss: 3.735180
# Epoch: 1000 [100%] 	Loss: 6.277112
# Potential causes:  [17, 56, 42, 10]
# Validated causes:  []
#
#  Analysis started for target:  1220026700
# Epoch:  1 [0%] 	Loss: 735.859924
# Epoch: 500 [50%] 	Loss: 6.294943
# Epoch: 1000 [100%] 	Loss: 0.923340
# Potential causes:  [40, 8, 39, 21, 41, 42, 46, 7, 31, 20, 14, 29, 5, 4, 34, 25]
# Validated causes:  [39, 21, 41, 42, 46, 7, 31, 20, 4, 34, 25]
#
#  Analysis started for target:  1220035900
# Epoch:  1 [0%] 	Loss: 628.819702
# Epoch: 500 [50%] 	Loss: 2.493843
# Epoch: 1000 [100%] 	Loss: 0.595518
# Potential causes:  [7, 39, 11, 21]
# Validated causes:  []
#
#  Analysis started for target:  1220031900
# Epoch:  1 [0%] 	Loss: 726.767761
# Epoch: 500 [50%] 	Loss: 3.754601
# Epoch: 1000 [100%] 	Loss: 0.539111
# Potential causes:  [39, 8, 7, 31, 21, 33, 54, 41]
# Validated causes:  [31]
#
#  Analysis started for target:  1220035300
# Epoch:  1 [0%] 	Loss: 711.905823
# Epoch: 500 [50%] 	Loss: 2.583962
# Epoch: 1000 [100%] 	Loss: 1.915404
# Potential causes:  [39, 31]
# Validated causes:  [31]
#
#  Analysis started for target:  1220032600
# Epoch:  1 [0%] 	Loss: 571.053467
# Epoch: 500 [50%] 	Loss: 2.891256
# Epoch: 1000 [100%] 	Loss: 1.083166
# Potential causes:  [8, 10, 46]
# Validated causes:  []
#
#  Analysis started for target:  1220034500
# Epoch:  1 [0%] 	Loss: 1106.726807
# Epoch: 500 [50%] 	Loss: 9.648146
# Epoch: 1000 [100%] 	Loss: 1.774653
# Potential causes:  [39, 8, 21, 25, 7, 11, 46, 34, 20, 41, 48]
# Validated causes:  [20]
#
#  Analysis started for target:  1220030400
# Epoch:  1 [0%] 	Loss: 497.381927
# Epoch: 500 [50%] 	Loss: 3.408068
# Epoch: 1000 [100%] 	Loss: 5.947503
# Potential causes:  [36, 35, 38, 2, 24, 56, 39, 46, 33, 0, 23, 53, 6, 42, 54, 4, 55, 50, 26, 51, 41, 15, 3, 5, 10, 48, 20, 17, 47]
# Validated causes:  []
#
#  Analysis started for target:  1220033500
# Epoch:  1 [0%] 	Loss: 651.846619
# Epoch: 500 [50%] 	Loss: 6.805020
# Epoch: 1000 [100%] 	Loss: 0.716554
# Potential causes:  [8, 29, 21]
# Validated causes:  [8]
#
#  Analysis started for target:  1220030000
# Epoch:  1 [0%] 	Loss: 697.382935
# Epoch: 500 [50%] 	Loss: 3.718542
# Epoch: 1000 [100%] 	Loss: 1.092772
# Potential causes:  [39, 31, 21, 8, 7, 25, 42]
# Validated causes:  []
#
#  Analysis started for target:  1220029600
# Epoch:  1 [0%] 	Loss: 589.320312
# Epoch: 500 [50%] 	Loss: 2.783992
# Epoch: 1000 [100%] 	Loss: 0.876641
# Potential causes:  [7, 39, 8]
# Validated causes:  []
#
#  Analysis started for target:  1220024000
# Epoch:  1 [0%] 	Loss: 955.909119
# Epoch: 500 [50%] 	Loss: 3.884066
# Epoch: 1000 [100%] 	Loss: 1.258642
# Potential causes:  [39, 43]
# Validated causes:  []
#
#  Analysis started for target:  1220026600
# Epoch:  1 [0%] 	Loss: 706.546387
# Epoch: 500 [50%] 	Loss: 5.872825
# Epoch: 1000 [100%] 	Loss: 0.739922
# Potential causes:  [39, 8, 43]
# Validated causes:  [8]
#
#  Analysis started for target:  1220030900
# Epoch:  1 [0%] 	Loss: 539.268127
# Epoch: 500 [50%] 	Loss: 4.129929
# Epoch: 1000 [100%] 	Loss: 0.820512
# Potential causes:  [21, 10, 39, 8]
# Validated causes:  []
#
#  Analysis started for target:  1220031100
# Epoch:  1 [0%] 	Loss: 644.202942
# Epoch: 500 [50%] 	Loss: 4.640137
# Epoch: 1000 [100%] 	Loss: 1.088920
# Potential causes:  [39, 21, 11, 7, 4, 41, 33, 31, 34, 52, 8, 25, 29]
# Validated causes:  [7, 4, 31, 34]
#
#  Analysis started for target:  1220034700
# Epoch:  1 [0%] 	Loss: 784.406555
# Epoch: 500 [50%] 	Loss: 3.455181
# Epoch: 1000 [100%] 	Loss: 0.691200
# Potential causes:  [39, 21]
# Validated causes:  []
#
#  Analysis started for target:  1220031200
# Epoch:  1 [0%] 	Loss: 796.183594
# Epoch: 500 [50%] 	Loss: 4.132419
# Epoch: 1000 [100%] 	Loss: 15.294157
# Potential causes:  [41, 17, 7, 27, 2, 45, 35, 24, 6, 34, 56, 53, 55, 28]
# Validated causes:  []
#
#  Analysis started for target:  1220028100
# Epoch:  1 [0%] 	Loss: 457.778992
# Epoch: 500 [50%] 	Loss: 3.570438
# Epoch: 1000 [100%] 	Loss: 2.027183
# Potential causes:  [39, 27]
# Validated causes:  []
#
#  Analysis started for target:  1220031300
# Epoch:  1 [0%] 	Loss: 362.506042
# Epoch: 500 [50%] 	Loss: 3.684973
# Epoch: 1000 [100%] 	Loss: 1.555249
# Potential causes:  [39, 21, 54, 7, 37, 25, 27]
# Validated causes:  [7, 25]
#
#  Analysis started for target:  1220028300
# Epoch:  1 [0%] 	Loss: 575.892273
# Epoch: 500 [50%] 	Loss: 3.488276
# Epoch: 1000 [100%] 	Loss: 0.834919
# Potential causes:  [39, 21, 10]
# Validated causes:  []
#
#  Analysis started for target:  1220030100
# Epoch:  1 [0%] 	Loss: 762.778320
# Epoch: 500 [50%] 	Loss: 3.120856
# Epoch: 1000 [100%] 	Loss: 0.967180
# Potential causes:  [33, 39, 42, 10, 8, 11, 7, 21, 18, 25, 34, 46, 14]
# Validated causes:  []
#
#  Analysis started for target:  1220033600
# Epoch:  1 [0%] 	Loss: 482.695068
# Epoch: 500 [50%] 	Loss: 2.954114
# Epoch: 1000 [100%] 	Loss: 19.027227
# Potential causes:  [14, 17, 37, 34]
# Validated causes:  [34]
#
#  Analysis started for target:  1220029100
# Epoch:  1 [0%] 	Loss: 686.105652
# Epoch: 500 [50%] 	Loss: 3.158644
# Epoch: 1000 [100%] 	Loss: 0.816520
# Potential causes:  [21, 40, 29, 31]
# Validated causes:  []
#
#  Analysis started for target:  1220032300
# Epoch:  1 [0%] 	Loss: 721.475525
# Epoch: 500 [50%] 	Loss: 4.008087
# Epoch: 1000 [100%] 	Loss: 0.698626
# Potential causes:  [7, 40, 42, 31, 5]
# Validated causes:  [7, 42]
#
#  Analysis started for target:  1220032000
# Epoch:  1 [0%] 	Loss: 538.220703
# Epoch: 500 [50%] 	Loss: 4.837898
# Epoch: 1000 [100%] 	Loss: 1.063280
# Potential causes:  [21, 7]
# Validated causes:  []
#
#  Analysis started for target:  1220032200
# Epoch:  1 [0%] 	Loss: 799.278931
# Epoch: 500 [50%] 	Loss: 2.409173
# Epoch: 1000 [100%] 	Loss: 0.630685
# Potential causes:  [11, 8, 39]
# Validated causes:  []
#
#  Analysis started for target:  1220034100
# Epoch:  1 [0%] 	Loss: 641.032166
# Epoch: 500 [50%] 	Loss: 5.537727
# Epoch: 1000 [100%] 	Loss: 0.946136
# Potential causes:  [8, 21, 10, 29]
# Validated causes:  [8]
#
#  Analysis started for target:  1220029800
# Epoch:  1 [0%] 	Loss: 986.960815
# Epoch: 500 [50%] 	Loss: 3.259750
# Epoch: 1000 [100%] 	Loss: 0.894650
# Potential causes:  [42, 46, 29, 10, 34, 51, 25, 54, 18]
# Validated causes:  []
#
#  Analysis started for target:  1220027400
# Epoch:  1 [0%] 	Loss: 737.847778
# Epoch: 500 [50%] 	Loss: 3.624547
# Epoch: 1000 [100%] 	Loss: 0.728763
# Potential causes:  [31, 39, 11, 5, 18, 29, 41, 46, 34, 25, 21, 43]
# Validated causes:  [31]
#
#  Analysis started for target:  1220027200
# Epoch:  1 [0%] 	Loss: 645.418518
# Epoch: 500 [50%] 	Loss: 2.269457
# Epoch: 1000 [100%] 	Loss: 1.021125
# Potential causes:  [39, 42, 7]
# Validated causes:  []
#
#  Analysis started for target:  1220029000
# Epoch:  1 [0%] 	Loss: 524.577026
# Epoch: 500 [50%] 	Loss: 4.936903
# Epoch: 1000 [100%] 	Loss: 1.638405
# Potential causes:  [10, 39, 20]
# Validated causes:  []
#
#  Analysis started for target:  1220026200
# Epoch:  1 [0%] 	Loss: 835.960266
# Epoch: 500 [50%] 	Loss: 2.774557
# Epoch: 1000 [100%] 	Loss: 0.787368
# Potential causes:  [11, 31, 41, 42, 25, 46, 34, 7, 18, 14]
# Validated causes:  []
#
#  Analysis started for target:  1220029300
# Epoch:  1 [0%] 	Loss: 824.335205
# Epoch: 500 [50%] 	Loss: 3.308994
# Epoch: 1000 [100%] 	Loss: 0.751273
# Potential causes:  [39, 42, 40, 7, 43, 41, 46, 31, 8, 21, 36, 49, 25, 34]
# Validated causes:  [42, 7, 46, 31, 36, 25]
#
#  Analysis started for target:  1220032900
# Epoch:  1 [0%] 	Loss: 727.614746
# Epoch: 500 [50%] 	Loss: 2.952057
# Epoch: 1000 [100%] 	Loss: 0.638140
# Potential causes:  [21, 29, 34, 39, 31]
# Validated causes:  [34, 31]
#
#  Analysis started for target:  1220029900
# Epoch:  1 [0%] 	Loss: 862.427612
# Epoch: 500 [50%] 	Loss: 2.481806
# Epoch: 1000 [100%] 	Loss: 0.931551
# Potential causes:  [39, 8]
# Validated causes:  []
#
#  Analysis started for target:  1220026300
# Epoch:  1 [0%] 	Loss: 622.217224
# Epoch: 500 [50%] 	Loss: 2.923279
# Epoch: 1000 [100%] 	Loss: 0.698069
# Potential causes:  [39, 42, 21, 8, 7, 52]
# Validated causes:  []
#
#  Analysis started for target:  1220033400
# Epoch:  1 [0%] 	Loss: 630.259155
# Epoch: 500 [50%] 	Loss: 5.902016
# Epoch: 1000 [100%] 	Loss: 15.635946
# Potential causes:  [7, 26, 17, 56, 10, 50, 45, 53, 23, 31, 35, 52, 42, 51, 24, 47, 0, 6, 54, 2, 15, 28, 37, 38, 18, 3, 14, 19, 4]
# Validated causes:  []
#
#  Analysis started for target:  1220025200
# Epoch:  1 [0%] 	Loss: 563.096863
# Epoch: 500 [50%] 	Loss: 3.178870
# Epoch: 1000 [100%] 	Loss: 1.130634
# Potential causes:  [39, 10]
# Validated causes:  []
#
#  Analysis started for target:  1220033100
# Epoch:  1 [0%] 	Loss: 863.582458
# Epoch: 500 [50%] 	Loss: 2.628940
# Epoch: 1000 [100%] 	Loss: 0.949186
# Potential causes:  [39, 43, 40, 51]
# Validated causes:  []
#
#  Analysis started for target:  1220031800
# Epoch:  1 [0%] 	Loss: 893.424927
# Epoch: 500 [50%] 	Loss: 3.714498
# Epoch: 1000 [100%] 	Loss: 0.668572
# Potential causes:  [11, 41]
# Validated causes:  []
#
#  Analysis started for target:  1220033300
# Epoch:  1 [0%] 	Loss: 796.505127
# Epoch: 500 [50%] 	Loss: 4.010864
# Epoch: 1000 [100%] 	Loss: 0.653654
# Potential causes:  [8, 10, 39, 7]
# Validated causes:  [7]
#
#  Analysis started for target:  1220031000
# Epoch:  1 [0%] 	Loss: 596.601379
# Epoch: 500 [50%] 	Loss: 6.602210
# Epoch: 1000 [100%] 	Loss: 1.465463
# Potential causes:  [8, 39]
# Validated causes:  [8]
#
#  Analysis started for target:  1220034600
# Epoch:  1 [0%] 	Loss: 737.038025
# Epoch: 500 [50%] 	Loss: 4.879126
# Epoch: 1000 [100%] 	Loss: 0.717286
# Potential causes:  [21, 31, 39, 42]
# Validated causes:  [42]
#
#  Analysis started for target:  1220032800
# Epoch:  1 [0%] 	Loss: 713.452820
# Epoch: 500 [50%] 	Loss: 4.225422
# Epoch: 1000 [100%] 	Loss: 26.110859
# Potential causes:  [17, 34]
# Validated causes:  [17, 34]
#
#  Analysis started for target:  1220026800
# Epoch:  1 [0%] 	Loss: 756.302612
# Epoch: 500 [50%] 	Loss: 3.812248
# Epoch: 1000 [100%] 	Loss: 0.870924
# Potential causes:  [11, 7, 8, 21, 41]
# Validated causes:  []
#
# ===================Results for gang_csv.csv ==================================
# 1220034200 causes 1220032100 with a delay of 151 time steps.
# 1220034100 causes 1220032100 with a delay of 262 time steps.
# 1220027400 causes 1220032100 with a delay of 456 time steps.
# 1220031300 causes 1220032100 with a delay of 294 time steps.
# 1220027200 causes 1220032100 with a delay of 1029 time steps.
# 1220029200 causes 1220032100 with a delay of 672 time steps.
# 1220033600 causes 1220032100 with a delay of 28 time steps.
# 1220033500 causes 1220032100 with a delay of 105 time steps.
# 1220031300 causes 1220024600 with a delay of 638 time steps.
# 1220031300 causes 1210030000 with a delay of 886 time steps.
# 1220031300 causes 1220025300 with a delay of 387 time steps.
# 1220033600 causes 1220029200 with a delay of 228 time steps.
# 1220031300 causes 1220034000 with a delay of 706 time steps.
# 1220032600 causes 1220034000 with a delay of 209 time steps.
# 1220031300 causes 1220034200 with a delay of 899 time steps.
# 1220034100 causes 1220026700 with a delay of 558 time steps.
# 1220033500 causes 1220026700 with a delay of 979 time steps.
# 1220027400 causes 1220026700 with a delay of 259 time steps.
# 1220027200 causes 1220026700 with a delay of 375 time steps.
# 1220032900 causes 1220026700 with a delay of 179 time steps.
# 1220029200 causes 1220026700 with a delay of 811 time steps.
# 1220031300 causes 1220026700 with a delay of 381 time steps.
# 1220030400 causes 1220026700 with a delay of 767 time steps.
# 1220028200 causes 1220026700 with a delay of 840 time steps.
# 1220033600 causes 1220026700 with a delay of 492 time steps.
# 1220026600 causes 1220026700 with a delay of 528 time steps.
# 1220031300 causes 1220031900 with a delay of 70 time steps.
# 1220031300 causes 1220035300 with a delay of 979 time steps.
# 1220030400 causes 1220034500 with a delay of 912 time steps.
# 1220034000 causes 1220033500 with a delay of 466 time steps.
# 1220034000 causes 1220026600 with a delay of 220 time steps.
# 1220029200 causes 1220031100 with a delay of 126 time steps.
# 1220028200 causes 1220031100 with a delay of 636 time steps.
# 1220031300 causes 1220031100 with a delay of 945 time steps.
# 1220033600 causes 1220031100 with a delay of 481 time steps.
# 1220029200 causes 1220031300 with a delay of 228 time steps.
# 1220026600 causes 1220031300 with a delay of 513 time steps.
# 1220033600 causes 1220033600 with a delay of 4 time steps.
# 1220029200 causes 1220032300 with a delay of 39 time steps.
# 1220027200 causes 1220032300 with a delay of 363 time steps.
# 1220034000 causes 1220034100 with a delay of 646 time steps.
# 1220031300 causes 1220027400 with a delay of 1141 time steps.
# 1220027200 causes 1220029300 with a delay of 281 time steps.
# 1220029200 causes 1220029300 with a delay of 1048 time steps.
# 1220032900 causes 1220029300 with a delay of 407 time steps.
# 1220031300 causes 1220029300 with a delay of 655 time steps.
# 1220032300 causes 1220029300 with a delay of 828 time steps.
# 1220026600 causes 1220029300 with a delay of 1057 time steps.
# 1220033600 causes 1220032900 with a delay of 21 time steps.
# 1220031300 causes 1220032900 with a delay of 935 time steps.
# 1220029200 causes 1220033300 with a delay of 764 time steps.
# 1220034000 causes 1220031000 with a delay of 322 time steps.
# 1220027200 causes 1220034600 with a delay of 456 time steps.
# 1220035300 causes 1220032800 with a delay of 84 time steps.
# 1220033600 causes 1220032800 with a delay of 240 time steps.
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/gang_csv.csv --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/gang_csv.csv'], dilation_coefficient=4, epochs=1000, hidden_layers=0, kernel_size=4, learning_rate=0.01, log_interval=500, optimizer='Adam', plot=True, seed=1111, train_test_split=0.8)
# WARNING: You have a CUDA device, you should probably run with --cuda to speed up training.
#
#  Analysis started for target:  1220029700
# Epoch:  1 [0%] 	Loss: 718.430420
# Epoch: 500 [50%] 	Loss: 6.604930
# Epoch: 1000 [100%] 	Loss: 6.043391
#
#  Analysis started for target:  1220032100
# Epoch:  1 [0%] 	Loss: 718.778564
# Epoch: 500 [50%] 	Loss: 21.901756
# Epoch: 1000 [100%] 	Loss: 21.392000
#
#  Analysis started for target:  1220033000
# Epoch:  1 [0%] 	Loss: 711.767517
# Epoch: 500 [50%] 	Loss: 7.329293
# Epoch: 1000 [100%] 	Loss: 6.801752
#
#  Analysis started for target:  1220024600
# Epoch:  1 [0%] 	Loss: 531.954468
# Epoch: 500 [50%] 	Loss: 9.296219
# Epoch: 1000 [100%] 	Loss: 9.038824
#
#  Analysis started for target:  1220028200
# Epoch:  1 [0%] 	Loss: 307.295135
# Epoch: 500 [50%] 	Loss: 6.000029
# Epoch: 1000 [100%] 	Loss: 5.493675
#
#  Analysis started for target:  1210030000
# Epoch:  1 [0%] 	Loss: 854.860474
# Epoch: 500 [50%] 	Loss: 10.679034
# Epoch: 1000 [100%] 	Loss: 10.421108
#
#  Analysis started for target:  1220025300
# Epoch:  1 [0%] 	Loss: 616.657532
# Epoch: 500 [50%] 	Loss: 6.868792
# Epoch: 1000 [100%] 	Loss: 6.786660
#
#  Analysis started for target:  1220029200
# Epoch:  1 [0%] 	Loss: 766.386719
# Epoch: 500 [50%] 	Loss: 14.334673
# Epoch: 1000 [100%] 	Loss: 13.977701
#
#  Analysis started for target:  1220034000
# Epoch:  1 [0%] 	Loss: 811.565674
# Epoch: 500 [50%] 	Loss: 18.500740
# Epoch: 1000 [100%] 	Loss: 16.127037
#
#  Analysis started for target:  1220034300
# Epoch:  1 [0%] 	Loss: 648.352783
# Epoch: 500 [50%] 	Loss: 13.076875
# Epoch: 1000 [100%] 	Loss: 12.496046
#
#  Analysis started for target:  1220027500
# Epoch:  1 [0%] 	Loss: 705.044922
# Epoch: 500 [50%] 	Loss: 8.872153
# Epoch: 1000 [100%] 	Loss: 6.258675
#
#  Analysis started for target:  1220034200
# Epoch:  1 [0%] 	Loss: 530.412903
# Epoch: 500 [50%] 	Loss: 8.935139
# Epoch: 1000 [100%] 	Loss: 8.792805
#
#  Analysis started for target:  1220026100
# Epoch:  1 [0%] 	Loss: 796.043701
# Epoch: 500 [50%] 	Loss: 10.783849
# Epoch: 1000 [100%] 	Loss: 9.990181
#
#  Analysis started for target:  1220033700
# Epoch:  1 [0%] 	Loss: 593.182800
# Epoch: 500 [50%] 	Loss: 11.829793
# Epoch: 1000 [100%] 	Loss: 11.540504
#
#  Analysis started for target:  1220026700
# Epoch:  1 [0%] 	Loss: 719.045166
# Epoch: 500 [50%] 	Loss: 29.554375
# Epoch: 1000 [100%] 	Loss: 29.083580
#
#  Analysis started for target:  1220035900
# Epoch:  1 [0%] 	Loss: 626.776489
# Epoch: 500 [50%] 	Loss: 10.069452
# Epoch: 1000 [100%] 	Loss: 7.896331
#
#  Analysis started for target:  1220031900
# Epoch:  1 [0%] 	Loss: 717.153992
# Epoch: 500 [50%] 	Loss: 14.144672
# Epoch: 1000 [100%] 	Loss: 13.799054
#
#  Analysis started for target:  1220035300
# Epoch:  1 [0%] 	Loss: 703.267883
# Epoch: 500 [50%] 	Loss: 8.030874
# Epoch: 1000 [100%] 	Loss: 7.865072
#
#  Analysis started for target:  1220032600
# Epoch:  1 [0%] 	Loss: 571.293701
# Epoch: 500 [50%] 	Loss: 5.808060
# Epoch: 1000 [100%] 	Loss: 5.485300
#
#  Analysis started for target:  1220034500
# Epoch:  1 [0%] 	Loss: 1105.057861
# Epoch: 500 [50%] 	Loss: 22.580711
# Epoch: 1000 [100%] 	Loss: 21.991768
#
#  Analysis started for target:  1220030400
# Epoch:  1 [0%] 	Loss: 503.299438
# Epoch: 500 [50%] 	Loss: 8.808332
# Epoch: 1000 [100%] 	Loss: 8.635345
#
#  Analysis started for target:  1220033500
# Epoch:  1 [0%] 	Loss: 646.061768
# Epoch: 500 [50%] 	Loss: 24.474724
# Epoch: 1000 [100%] 	Loss: 24.015726
#
#  Analysis started for target:  1220030000
# Epoch:  1 [0%] 	Loss: 680.582214
# Epoch: 500 [50%] 	Loss: 10.475026
# Epoch: 1000 [100%] 	Loss: 9.062934
#
#  Analysis started for target:  1220029600
# Epoch:  1 [0%] 	Loss: 589.684265
# Epoch: 500 [50%] 	Loss: 7.627295
# Epoch: 1000 [100%] 	Loss: 7.437907
#
#  Analysis started for target:  1220024000
# Epoch:  1 [0%] 	Loss: 966.114014
# Epoch: 500 [50%] 	Loss: 10.329334
# Epoch: 1000 [100%] 	Loss: 10.201217
#
#  Analysis started for target:  1220026600
# Epoch:  1 [0%] 	Loss: 697.390320
# Epoch: 500 [50%] 	Loss: 25.396872
# Epoch: 1000 [100%] 	Loss: 24.736935
#
#  Analysis started for target:  1220030900
# Epoch:  1 [0%] 	Loss: 535.570618
# Epoch: 500 [50%] 	Loss: 12.428199
# Epoch: 1000 [100%] 	Loss: 12.041195
#
#  Analysis started for target:  1220031100
# Epoch:  1 [0%] 	Loss: 630.103638
# Epoch: 500 [50%] 	Loss: 20.199755
# Epoch: 1000 [100%] 	Loss: 19.366737
#
#  Analysis started for target:  1220034700
# Epoch:  1 [0%] 	Loss: 783.588074
# Epoch: 500 [50%] 	Loss: 14.083928
# Epoch: 1000 [100%] 	Loss: 13.760510
#
#  Analysis started for target:  1220031200
# Epoch:  1 [0%] 	Loss: 773.430908
# Epoch: 500 [50%] 	Loss: 14.641813
# Epoch: 1000 [100%] 	Loss: 14.434001
#
#  Analysis started for target:  1220028100
# Epoch:  1 [0%] 	Loss: 458.825897
# Epoch: 500 [50%] 	Loss: 10.527713
# Epoch: 1000 [100%] 	Loss: 10.423397
#
#  Analysis started for target:  1220031300
# Epoch:  1 [0%] 	Loss: 371.751801
# Epoch: 500 [50%] 	Loss: 10.825404
# Epoch: 1000 [100%] 	Loss: 10.126593
#
#  Analysis started for target:  1220028300
# Epoch:  1 [0%] 	Loss: 578.222717
# Epoch: 500 [50%] 	Loss: 8.964291
# Epoch: 1000 [100%] 	Loss: 8.716434
#
#  Analysis started for target:  1220030100
# Epoch:  1 [0%] 	Loss: 763.130737
# Epoch: 500 [50%] 	Loss: 11.363033
# Epoch: 1000 [100%] 	Loss: 11.025405
#
#  Analysis started for target:  1220033600
# Epoch:  1 [0%] 	Loss: 481.333344
# Epoch: 500 [50%] 	Loss: 8.015274
# Epoch: 1000 [100%] 	Loss: 7.857329
#
#  Analysis started for target:  1220029100
# Epoch:  1 [0%] 	Loss: 672.740784
# Epoch: 500 [50%] 	Loss: 6.998515
# Epoch: 1000 [100%] 	Loss: 6.731815
#
#  Analysis started for target:  1220032300
# Epoch:  1 [0%] 	Loss: 712.341797
# Epoch: 500 [50%] 	Loss: 16.377653
# Epoch: 1000 [100%] 	Loss: 15.663895
#
#  Analysis started for target:  1220032000
# Epoch:  1 [0%] 	Loss: 526.268005
# Epoch: 500 [50%] 	Loss: 14.408898
# Epoch: 1000 [100%] 	Loss: 14.161821
#
#  Analysis started for target:  1220032200
# Epoch:  1 [0%] 	Loss: 791.193054
# Epoch: 500 [50%] 	Loss: 8.527203
# Epoch: 1000 [100%] 	Loss: 7.900821
#
#  Analysis started for target:  1220034100
# Epoch:  1 [0%] 	Loss: 643.944092
# Epoch: 500 [50%] 	Loss: 19.333681
# Epoch: 1000 [100%] 	Loss: 18.850203
#
#  Analysis started for target:  1220029800
# Epoch:  1 [0%] 	Loss: 959.056641
# Epoch: 500 [50%] 	Loss: 7.824162
# Epoch: 1000 [100%] 	Loss: 7.299403
#
#  Analysis started for target:  1220027400
# Epoch:  1 [0%] 	Loss: 735.169189
# Epoch: 500 [50%] 	Loss: 14.650094
# Epoch: 1000 [100%] 	Loss: 11.541405
#
#  Analysis started for target:  1220027200
# Epoch:  1 [0%] 	Loss: 646.756348
# Epoch: 500 [50%] 	Loss: 7.930567
# Epoch: 1000 [100%] 	Loss: 7.008023
#
#  Analysis started for target:  1220029000
# Epoch:  1 [0%] 	Loss: 518.950928
# Epoch: 500 [50%] 	Loss: 7.576599
# Epoch: 1000 [100%] 	Loss: 7.248842
#
#  Analysis started for target:  1220026200
# Epoch:  1 [0%] 	Loss: 827.738464
# Epoch: 500 [50%] 	Loss: 8.598039
# Epoch: 1000 [100%] 	Loss: 7.882686
#
#  Analysis started for target:  1220029300
# Epoch:  1 [0%] 	Loss: 810.217041
# Epoch: 500 [50%] 	Loss: 19.572807
# Epoch: 1000 [100%] 	Loss: 19.007278
#
#  Analysis started for target:  1220032900
# Epoch:  1 [0%] 	Loss: 715.381226
# Epoch: 500 [50%] 	Loss: 16.032339
# Epoch: 1000 [100%] 	Loss: 15.403324
#
#  Analysis started for target:  1220029900
# Epoch:  1 [0%] 	Loss: 847.200134
# Epoch: 500 [50%] 	Loss: 10.371754
# Epoch: 1000 [100%] 	Loss: 9.989460
#
#  Analysis started for target:  1220026300
# Epoch:  1 [0%] 	Loss: 610.020874
# Epoch: 500 [50%] 	Loss: 6.741819
# Epoch: 1000 [100%] 	Loss: 6.368166
#
#  Analysis started for target:  1220033400
# Epoch:  1 [0%] 	Loss: 630.761292
# Epoch: 500 [50%] 	Loss: 22.983902
# Epoch: 1000 [100%] 	Loss: 22.615862
#
#  Analysis started for target:  1220025200
# Epoch:  1 [0%] 	Loss: 561.017639
# Epoch: 500 [50%] 	Loss: 6.877882
# Epoch: 1000 [100%] 	Loss: 6.684500
#
#  Analysis started for target:  1220033100
# Epoch:  1 [0%] 	Loss: 836.529236
# Epoch: 500 [50%] 	Loss: 9.108156
# Epoch: 1000 [100%] 	Loss: 7.771642
#
#  Analysis started for target:  1220031800
# Epoch:  1 [0%] 	Loss: 879.685852
# Epoch: 500 [50%] 	Loss: 13.571405
# Epoch: 1000 [100%] 	Loss: 13.253422
#
#  Analysis started for target:  1220033300
# Epoch:  1 [0%] 	Loss: 778.115295
# Epoch: 500 [50%] 	Loss: 20.598616
# Epoch: 1000 [100%] 	Loss: 20.132338
#
#  Analysis started for target:  1220031000
# Epoch:  1 [0%] 	Loss: 595.828125
# Epoch: 500 [50%] 	Loss: 20.123329
# Epoch: 1000 [100%] 	Loss: 19.838892
#
#  Analysis started for target:  1220034600
# Epoch:  1 [0%] 	Loss: 735.033630
# Epoch: 500 [50%] 	Loss: 11.444515
# Epoch: 1000 [100%] 	Loss: 10.902185
#
#  Analysis started for target:  1220032800
# Epoch:  1 [0%] 	Loss: 715.410522
# Epoch: 500 [50%] 	Loss: 19.425541
# Epoch: 1000 [100%] 	Loss: 18.493107
#
#  Analysis started for target:  1220026800
# Epoch:  1 [0%] 	Loss: 748.883850
# Epoch: 500 [50%] 	Loss: 11.413489
# Epoch: 1000 [100%] 	Loss: 10.857190
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/gang_csv.csv : 0.8509720471646933 with standard deviation 0.12843718169332466
