# %%
import torch
import torch.nn as nn
import numpy as np
from copy import deepcopy

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class RBFlayer(nn.Module):
    def __init__(self, timelag):
        super(RBFlayer, self).__init__()

        self.timelag = timelag

        # device = "cuda" if torch.cuda.is_available() else "cpu"
        torch.cuda.manual_seed(0)

        self.init_weight = nn.Parameter(torch.rand(self.timelag))
        self.rbf_clt = self.init_clt()
        self.rbf_std = self.init_std()
        
        self.b = nn.Parameter(torch.rand(1))

    def init_clt(self):
        return nn.Parameter(torch.rand(1))

    def init_std(self):
        return nn.Parameter(torch.rand(1))
    
    def rbf(self, x, cluster, std):
        return torch.exp(-(x - cluster) * (x - cluster) / 2 * (std * std))
    
    def rbf_gradient(self, x, clt, std):
        return (-1 * (x - clt) * (x - clt) / (std * std)) * (torch.exp(-(x - clt) * (x - clt) / 2 * (std * std)))
    
    
    def forward(self, x):        
        for i in range(len(x)):
            if i == 0:
                a = self.rbf(x[i], self.rbf_clt, self.rbf_std)
            else:
                a = torch.cat([a, self.rbf(x[i], self.rbf_clt, self.rbf_std)], dim=0)
        cause = self.init_weight * a
        
        
        return cause

# %%
def restore_parameters(model, best_model):
    '''Move parameter values from best_model to model.'''
    for params, best_params in zip(model.parameters(), best_model.parameters()):
        params.data = best_params

# %%
def train_RBFlayer(model, input_, lr, epochs, lookback = 5, device = device):
    model.to(device)
    loss_fn = nn.MSELoss(reduction='mean')
    optimizer = torch.optim.Adam(model.parameters(), lr = lr)
    
    train_loss_list = []
    
    best_it = None
    best_model = None
    best_loss = np.inf
    target = []
    for j in range(len(input_) - 2):
        target.append((input_[j+2] - input_[j])/2)
    
    loss_list = []
    cause_list = []
    for epoch in range(epochs):
        cause = model(input_)
        cause_list.append(cause)
        grad = []
        
        
        for i in range(len(cause) - 2):
            grad.append((cause[i+2] - cause[i])/2)
        
        loss1 = sum([loss_fn(grad[i], target[i]) for i in range(len(grad))])
        loss2 = sum([loss_fn(cause[i], input_[i]) for i in range(len(input_))])
        
        loss = loss1 + loss2
        
        loss.backward()
        optimizer.step()
        model.zero_grad()
        
        loss_list.append(loss)
        mean_loss = loss / len(grad)
        train_loss_list.append(mean_loss)
        
        if mean_loss < best_loss:
            best_loss = mean_loss
            best_it = epoch
            best_model = deepcopy(model)
            
        elif (epoch - best_it) == lookback:
            if verbose:
                print('Stopping early')
            break
    print("epoch {} cause loss {} :".format(epoch, loss / len(input_)))
    print('gradient loss :', loss1/len(grad))
    print('value loss :', loss2/len(input_))
                
    best_cause = cause_list[best_it]    
    restore_parameters(model, best_model)

    return best_model, loss_list, best_cause

# %%
def data_split(X, cause, target, timelag, device = device):
    input_cause = []
    input_target = []
    Y = []

    for i in range(len(X) - (timelag + 1)):
        input_cause.append(X[cause].values[i: i + timelag])
        input_target.append(X[target].values[i: i + timelag])
        Y.append([X[target][i + timelag + 1]])

    return torch.tensor(input_cause, device=device).float(), torch.tensor(input_target,device=device).float(), torch.tensor(Y, device=device).float()

# %%
import pandas as pd
df = pd.read_csv('C:/Users/chanyoung/Desktop/Neural-GC-master/lorenz_96_10_10_1000.csv')
X2d = df[['a','b']]
torch.manual_seed(1234)
input_cause, input_target, Y = data_split(X2d, 'a', 'b', 100)

# %%
input_cause1 = input_cause[:20]

# %%
input_cause2 = input_cause[100:130]

# %%
input_cause.size()
# Out:
# torch.Size([20, 100])

# %%
import time

cause_list = []
for i in range(len(input_cause)):
    print(i,"번째 time series")
    start = time.time()
    model = RBFlayer(100)
    best_model, loss_list, best_cause = train_RBFlayer(model, input_cause[i], 0.01, 1000, device)
    cause_list.append(best_cause.cpu().detach().numpy())
    print("time :", time.time() - start)
    print('-------------------------------------------------------------------------------------------')
    
import pickle

filePath = './value_grad1_epcoh1000.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(cause_list, lf)
# Out:
# 0 번째 time series
# epoch 999 cause loss 0.41716113686561584 :
# gradient loss : tensor(0.0458, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3722, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.76029992103577
# -------------------------------------------------------------------------------------------
# 1 번째 time series
# epoch 999 cause loss 0.5941880941390991 :
# gradient loss : tensor(0.0655, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5300, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.80376935005188
# -------------------------------------------------------------------------------------------
# 2 번째 time series
# epoch 999 cause loss 0.429005891084671 :
# gradient loss : tensor(0.0446, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3853, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.98517227172852
# -------------------------------------------------------------------------------------------
# 3 번째 time series
# epoch 999 cause loss 0.5721248984336853 :
# gradient loss : tensor(0.0598, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5135, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.58783960342407
# -------------------------------------------------------------------------------------------
# 4 번째 time series
# epoch 999 cause loss 0.5692209005355835 :
# gradient loss : tensor(0.0595, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5109, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.35032606124878
# -------------------------------------------------------------------------------------------
# 5 번째 time series
# epoch 999 cause loss 0.4309980273246765 :
# gradient loss : tensor(0.0464, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3856, device='cuda:0', grad_fn=<DivBackward0>)
# time : 121.9642014503479
# -------------------------------------------------------------------------------------------
# 6 번째 time series
# epoch 999 cause loss 0.6380915641784668 :
# gradient loss : tensor(0.0658, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5736, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.8135437965393
# -------------------------------------------------------------------------------------------
# 7 번째 time series
# epoch 999 cause loss 0.633134126663208 :
# gradient loss : tensor(0.0691, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5654, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.47481989860535
# -------------------------------------------------------------------------------------------
# 8 번째 time series
# epoch 999 cause loss 0.5823719501495361 :
# gradient loss : tensor(0.0631, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5205, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.116051197052
# -------------------------------------------------------------------------------------------
# 9 번째 time series
# epoch 999 cause loss 0.5818749666213989 :
# gradient loss : tensor(0.0611, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5220, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.64971876144409
# -------------------------------------------------------------------------------------------
# 10 번째 time series
# epoch 999 cause loss 0.4396335780620575 :
# gradient loss : tensor(0.0446, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3959, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.51765370368958
# -------------------------------------------------------------------------------------------
# 11 번째 time series
# epoch 999 cause loss 0.36849620938301086 :
# gradient loss : tensor(0.0395, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3298, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.3117287158966
# -------------------------------------------------------------------------------------------
# 12 번째 time series
# epoch 999 cause loss 0.4713320732116699 :
# gradient loss : tensor(0.0493, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4231, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.32390213012695
# -------------------------------------------------------------------------------------------
# 13 번째 time series
# epoch 999 cause loss 0.32654106616973877 :
# gradient loss : tensor(0.0338, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2934, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.19828939437866
# -------------------------------------------------------------------------------------------
# 14 번째 time series
# epoch 999 cause loss 0.32792988419532776 :
# gradient loss : tensor(0.0345, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2941, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.4765567779541
# -------------------------------------------------------------------------------------------
# 15 번째 time series
# epoch 999 cause loss 0.3626718819141388 :
# gradient loss : tensor(0.0365, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3269, device='cuda:0', grad_fn=<DivBackward0>)
# time : 121.78408861160278
# -------------------------------------------------------------------------------------------
# 16 번째 time series
# epoch 999 cause loss 0.31032878160476685 :
# gradient loss : tensor(0.0313, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2796, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.92465567588806
# -------------------------------------------------------------------------------------------
# 17 번째 time series
# epoch 999 cause loss 0.5235224962234497 :
# gradient loss : tensor(0.0538, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4708, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.27859306335449
# -------------------------------------------------------------------------------------------
# 18 번째 time series
# epoch 999 cause loss 0.38850462436676025 :
# gradient loss : tensor(0.0412, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3481, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.32297730445862
# -------------------------------------------------------------------------------------------
# 19 번째 time series
# epoch 999 cause loss 0.5508097410202026 :
# gradient loss : tensor(0.0581, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4938, device='cuda:0', grad_fn=<DivBackward0>)
# time : 124.08792161941528
# -------------------------------------------------------------------------------------------

# %%
import time

cause_list = []
for i in range(len(input_cause2)):
    print(i,"번째 time series")
    start = time.time()
    model = RBFlayer(100)
    best_model, loss_list, best_cause = train_RBFlayer(model, input_cause2[i], 0.01, 1000, device)
    cause_list.append(best_cause.cpu().detach().numpy())
    print("time :", time.time() - start)
    print('-------------------------------------------------------------------------------------------')
    
import pickle

filePath = './value_grad2_epcoh1000.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(cause_list, lf)
# Out:
# 0 번째 time series
# epoch 999 cause loss 0.3864403963088989 :
# gradient loss : tensor(0.0732, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3147, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.18133425712585
# -------------------------------------------------------------------------------------------
# 1 번째 time series
# epoch 999 cause loss 0.3593389093875885 :
# gradient loss : tensor(0.0705, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2903, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.03879451751709
# -------------------------------------------------------------------------------------------
# 2 번째 time series
# epoch 999 cause loss 0.4457787871360779 :
# gradient loss : tensor(0.0843, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3631, device='cuda:0', grad_fn=<DivBackward0>)
# time : 124.99190902709961
# -------------------------------------------------------------------------------------------
# 3 번째 time series
# epoch 999 cause loss 0.4430575370788574 :
# gradient loss : tensor(0.0863, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3584, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.5204176902771
# -------------------------------------------------------------------------------------------
# 4 번째 time series
# epoch 999 cause loss 0.3449420928955078 :
# gradient loss : tensor(0.0655, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2807, device='cuda:0', grad_fn=<DivBackward0>)
# time : 117.65513801574707
# -------------------------------------------------------------------------------------------
# 5 번째 time series
# epoch 999 cause loss 0.38892436027526855 :
# gradient loss : tensor(0.0708, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3195, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.96729588508606
# -------------------------------------------------------------------------------------------
# 6 번째 time series
# epoch 999 cause loss 0.5534219145774841 :
# gradient loss : tensor(0.1005, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4549, device='cuda:0', grad_fn=<DivBackward0>)
# time : 124.74441742897034
# -------------------------------------------------------------------------------------------
# 7 번째 time series
# epoch 999 cause loss 0.36149051785469055 :
# gradient loss : tensor(0.0708, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2921, device='cuda:0', grad_fn=<DivBackward0>)
# time : 121.48928046226501
# -------------------------------------------------------------------------------------------
# 8 번째 time series
# epoch 999 cause loss 0.640355110168457 :
# gradient loss : tensor(0.1226, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5202, device='cuda:0', grad_fn=<DivBackward0>)
# time : 118.18489050865173
# -------------------------------------------------------------------------------------------
# 9 번째 time series
# epoch 999 cause loss 0.5314225554466248 :
# gradient loss : tensor(0.0979, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4354, device='cuda:0', grad_fn=<DivBackward0>)
# time : 117.52904200553894
# -------------------------------------------------------------------------------------------
# 10 번째 time series
# epoch 999 cause loss 0.40471187233924866 :
# gradient loss : tensor(0.0791, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3272, device='cuda:0', grad_fn=<DivBackward0>)
# time : 120.19121956825256
# -------------------------------------------------------------------------------------------
# 11 번째 time series
# epoch 999 cause loss 0.5799789428710938 :
# gradient loss : tensor(0.1127, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4695, device='cuda:0', grad_fn=<DivBackward0>)
# time : 120.17762637138367
# -------------------------------------------------------------------------------------------
# 12 번째 time series
# epoch 999 cause loss 0.5984997153282166 :
# gradient loss : tensor(0.1105, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4902, device='cuda:0', grad_fn=<DivBackward0>)
# time : 120.22053837776184
# -------------------------------------------------------------------------------------------
# 13 번째 time series
# epoch 999 cause loss 0.5575596690177917 :
# gradient loss : tensor(0.1075, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4522, device='cuda:0', grad_fn=<DivBackward0>)
# time : 120.81095051765442
# -------------------------------------------------------------------------------------------
# 14 번째 time series
# epoch 999 cause loss 0.594748854637146 :
# gradient loss : tensor(0.1139, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4832, device='cuda:0', grad_fn=<DivBackward0>)
# time : 122.30125498771667
# -------------------------------------------------------------------------------------------
# 15 번째 time series
# epoch 999 cause loss 0.5179328322410583 :
# gradient loss : tensor(0.0971, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4228, device='cuda:0', grad_fn=<DivBackward0>)
# time : 118.86794567108154
# -------------------------------------------------------------------------------------------
# 16 번째 time series
# epoch 999 cause loss 0.37177348136901855 :
# gradient loss : tensor(0.0733, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3000, device='cuda:0', grad_fn=<DivBackward0>)
# time : 120.12371850013733
# -------------------------------------------------------------------------------------------
# 17 번째 time series
# epoch 999 cause loss 0.5460777282714844 :
# gradient loss : tensor(0.1049, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4433, device='cuda:0', grad_fn=<DivBackward0>)
# time : 119.05907130241394
# -------------------------------------------------------------------------------------------
# 18 번째 time series
# epoch 999 cause loss 0.40180471539497375 :
# gradient loss : tensor(0.0761, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3272, device='cuda:0', grad_fn=<DivBackward0>)
# time : 116.43006181716919
# -------------------------------------------------------------------------------------------
# 19 번째 time series
# epoch 999 cause loss 0.3995394706726074 :
# gradient loss : tensor(0.0766, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3244, device='cuda:0', grad_fn=<DivBackward0>)
# time : 119.02910900115967
# -------------------------------------------------------------------------------------------
# 20 번째 time series
# epoch 999 cause loss 0.3647325336933136 :
# gradient loss : tensor(0.0708, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2953, device='cuda:0', grad_fn=<DivBackward0>)
# time : 120.94919395446777
# -------------------------------------------------------------------------------------------
# 21 번째 time series
# epoch 999 cause loss 0.39109012484550476 :
# gradient loss : tensor(0.0765, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3162, device='cuda:0', grad_fn=<DivBackward0>)
# time : 120.25662732124329
# -------------------------------------------------------------------------------------------
# 22 번째 time series
# epoch 999 cause loss 0.5496139526367188 :
# gradient loss : tensor(0.1040, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4477, device='cuda:0', grad_fn=<DivBackward0>)
# time : 124.73113322257996
# -------------------------------------------------------------------------------------------
# 23 번째 time series
# epoch 999 cause loss 0.38666287064552307 :
# gradient loss : tensor(0.0747, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.3135, device='cuda:0', grad_fn=<DivBackward0>)
# time : 124.58270192146301
# -------------------------------------------------------------------------------------------
# 24 번째 time series
# epoch 999 cause loss 0.7099168300628662 :
# gradient loss : tensor(0.1376, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5750, device='cuda:0', grad_fn=<DivBackward0>)
# time : 124.32390427589417
# -------------------------------------------------------------------------------------------
# 25 번째 time series
# epoch 999 cause loss 0.36140426993370056 :
# gradient loss : tensor(0.0721, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2907, device='cuda:0', grad_fn=<DivBackward0>)
# time : 121.95289468765259
# -------------------------------------------------------------------------------------------
# 26 번째 time series
# epoch 999 cause loss 0.6165334582328796 :
# gradient loss : tensor(0.1173, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5016, device='cuda:0', grad_fn=<DivBackward0>)
# time : 119.29041838645935
# -------------------------------------------------------------------------------------------
# 27 번째 time series
# epoch 999 cause loss 0.6860111355781555 :
# gradient loss : tensor(0.1352, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.5535, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.04266238212585
# -------------------------------------------------------------------------------------------
# 28 번째 time series
# epoch 999 cause loss 0.35542264580726624 :
# gradient loss : tensor(0.0687, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.2881, device='cuda:0', grad_fn=<DivBackward0>)
# time : 123.30172634124756
# -------------------------------------------------------------------------------------------
# 29 번째 time series
# epoch 999 cause loss 0.5332555174827576 :
# gradient loss : tensor(0.1032, device='cuda:0', grad_fn=<DivBackward0>)
# value loss : tensor(0.4321, device='cuda:0', grad_fn=<DivBackward0>)
# time : 119.94032573699951
# -------------------------------------------------------------------------------------------
