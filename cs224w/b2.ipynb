# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
data = pd.read_csv('./dataset/PimaIndiansDiabetes.csv')

# %%
data
# Out:
#      Pregnancy Count  Blood Glucose  Diastolic BP  \
# 0                  6            148            72
# 1                  1             85            66
# 2                  8            183            64
# 3                  1             89            66
# 4                  0            137            40
# ..               ...            ...           ...
# 763               10            101            76
# 764                2            122            70
# 765                5            121            72
# 766                1            126            60
# 767                1             93            70
#
#      Triceps Skin Fold Thickness  Serum Insulin   BMI  \
# 0                             35              0  33.6
# 1                             29              0  26.6
# 2                              0              0  23.3
# 3                             23             94  28.1
# 4                             35            168  43.1
# ...

# %%
data['Class'].value_counts()[0]
# Out:
# 500

# %%
data_subset = data.loc[:,['Blood Glucose', 'BMI', 'Class']]
X = data_subset.loc[:, ['Blood Glucose', 'BMI']]
y = data_subset.loc[:, 'Class']

# %%
class DummyClassifier:
    def __init__(self):
        self.X = X
        self.target = target
        
    def max_labels(self, X,target='Class'):
        X_label = X[target]
        max_label = X_label.value_counts()[0]
        
        return max_label
    def predict(self, X):
        pred_y = X['Class'].values()
        
        return pred_y
