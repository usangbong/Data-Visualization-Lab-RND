# %%
import pickle
import numpy as np
import pandas as pd
df = pd.read_csv('gang_csv.csv')
df.head()
adj_matrix = np.load('adj_matrix.npy')
with open('./edges_index.pickle', 'rb') as fr:
    edge_index = pickle.load(fr)
for i in range(len(adj_matrix)):
    adj_matrix[i][i] = 1

# %%
matmul_adj = np.matmul(adj_matrix ,df.T)
for i in range(len(matmul_adj)):
    matmul_adj[i] = matmul_adj[i]/sum(adj_matrix)[i]
data_df = pd.DataFrame(matmul_adj)

# %%
data = data_df.T[:6].T

# %%
#Import libraries
import cdt
from cdt import SETTINGS
SETTINGS.verbose=False
SETTINGS.NJOBS=16
import networkx as nx
import time
# A warning on R libraries might occur. It is for the use of the r libraries that could be imported into the framework
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# Detecting 1 CUDA device(s).

# %%
data
# Out:
#             0          1          2          3          4       5
# 0   25.446923  19.044706  26.549231  27.331538  20.021765  346.90
# 1   44.193077  33.502941  46.389231  44.740000  34.217059  564.16
# 2   28.275385  21.303529  27.768462  27.407692  20.324706  344.49
# 3   25.490769  20.244706  27.200000  28.830769  20.507647  362.12
# 4   33.969231  26.471765  33.530769  34.997692  25.613529  430.61
# 5    2.825385   2.161176   2.484615   3.128462   1.912353   39.21
# 6   22.328462  17.665882  23.356923  23.937692  17.662353  311.23
# 7   25.153846  20.646471  26.075385  27.291538  20.582353  337.06
# 8   17.266923  14.372941  17.567692  17.340769  13.093529  225.15
# 9   28.229231  21.322353  28.351538  27.841538  20.428235  345.95
# 10  25.281538  20.228824  27.130000  28.573846  20.417647  366.77
# 11  25.388462  19.008235  27.674615  24.993077  19.934706  324.35
# 12  31.099231  25.274118  32.930000  34.796923  25.035294  441.70
# 13  25.508462  18.820588  27.086923  25.919231  20.001176  329.41
# 14  10.716923   8.703529  11.812308  12.043846   9.150000  144.76
# 15  21.288462  17.181176  21.799231  21.307692  16.358235  272.24
# 16  30.836154  25.070588  31.929231  32.948462  25.784706  414.09
# 17  34.433846  26.246471  35.177692  34.172308  25.178235  429.89
# 18  18.136923  13.514706  19.536923  18.938462  14.569412  234.67
# 19  19.316923  14.200588  21.086923  20.050000  14.872941  251.63
# 20  29.279231  22.084118  29.626923  28.690000  22.295882  371.49
# 21  33.523077  26.635294  34.053846  33.874615  25.669412  425.41
# 22  25.016923  20.618824  25.556923  27.374615  20.720000  336.42
# 23  29.379231  22.428824  30.397692  29.851538  22.244118  375.07
# 24  17.724615  14.340000  18.653077  19.118462  14.285294  245.59
# 25  20.204615  16.345882  21.251538  21.025385  16.754118  257.66
# 26  24.121538  20.186471  25.256923  26.857692  20.684118  335.48
# 27  31.218462  23.725294  31.893846  31.343077  25.175882  405.70
# 28  25.733077  19.179412  27.796923  25.400769  20.294118  330.50
# 29  36.176154  27.565882  38.820000  37.216923  28.705294  470.33
# 30  26.371538  21.418824  27.833077  27.904615  22.084706  350.69
# 31  35.796154  26.486471  36.233846  35.576923  27.442941  449.39
# 32  31.518462  23.543529  32.886154  33.424615  24.820588  428.39
# 33  26.420769  20.682353  28.256923  26.919231  22.087059  353.90
# 34  28.271538  21.175882  27.528462  27.278462  20.191765  342.69
# 35  34.611538  27.093529  34.260000  35.344615  26.411176  439.82
# 36  30.122308  22.348824  29.924615  29.280769  23.017059  374.86
# 37  33.565385  26.830000  33.007692  33.980769  25.093529  416.95
# 38  19.005385  14.182941  20.487692  19.660000  15.152941  246.80
# 39  24.662308  19.093529  26.375385  23.936923  20.756471  319.77
# 40  36.636923  27.865882  39.069231  37.366923  28.952941  480.00
# 41  34.776154  27.061765  33.951538  35.617692  26.172941  443.57
# 42  25.571538  19.202353  26.760000  27.461538  20.202941  350.01
# 43  26.987692  20.543529  27.883846  26.669231  21.960588  354.45
# 44  25.833846  19.047059  27.033077  27.617692  20.234118  352.10
# 45  20.279231  16.609412  21.403077  20.590769  16.935294  264.56
# 46  40.146923  31.588235  40.227692  40.066923  30.570588  501.56
# 47  40.709231  31.951176  40.533846  42.022308  30.870000  525.96
# 48  17.944615  14.461765  18.560000  18.756154  14.173529  241.89
# 49  30.166154  22.668824  31.789231  29.654615  23.126471  380.56
# 50  25.526923  20.217059  27.132308  28.783846  20.604706  365.04
# 51  36.291538  27.468235  38.440769  37.191538  28.650000  473.55
# 52  25.970000  19.305882  27.279231  24.710769  21.478824  327.74
# 53  31.186923  24.602353  33.292308  30.560000  26.060588  406.16
# 54  33.538462  26.634706  32.758462  33.923846  24.776471  418.80
# 55  16.653077  13.830000  17.461538  17.215385  13.098824  217.68
# 56  24.508462  18.728824  26.308462  23.886154  20.577647  321.48
# 57  20.130769  16.113529  21.025385  20.389231  16.718235  267.85

# %%
from cdt.independence.graph import FSGNN

Fsgnn = FSGNN(train_epochs=1000, test_epochs=500, l1=0.1, batch_size=1000)

start_time = time.time()
ugraph = Fsgnn.predict(data, threshold=1e-7)
print("--- Execution time : %4.4s seconds ---" % (time.time() - start_time))
nx.draw_networkx(ugraph, font_size=8) # The plot function allows for quick visualization of the graph.
plt.show()
# List results
pd.DataFrame(list(ugraph.edges(data='weight')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ab1afee4141b> in <module>
#       4
#       5 start_time = time.time()
# ----> 6 ugraph = Fsgnn.predict(data, threshold=1e-7)
#       7 print("--- Execution time : %4.4s seconds ---" % (time.time() - start_time))
#       8 nx.draw_networkx(ugraph, font_size=8) # The plot function allows for quick visualization of the graph.
#
# ~\Desktop\CausalDiscoveryToolbox-master\CausalDiscoveryToolbox-master\cdt\independence\graph\FSGNN.py in predict(self, df_data, threshold, gpus, **kwargs)
#     236         matrix_results = np.array(result_feature_selection)
#     237         matrix_results *= matrix_results.transpose()
# --> 238         np.fill_diagonal(matrix_results, 0)
#     239         matrix_results /= 2
#     240
#
# <__array_function__ internals> in fill_diagonal(*args, **kwargs)
#
# ~\anaconda3\envs\pytorch\lib\site-packages\numpy\lib\index_tricks.py in fill_diagonal(a, val, wrap)
#     857     """
#     858     if a.ndim < 2:
# --> 859         raise ValueError("array must be at least 2-d")
#     860     end = None
#     861     if a.ndim == 2:
#
# ValueError: array must be at least 2-d
