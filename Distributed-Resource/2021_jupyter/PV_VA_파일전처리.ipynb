# %% [markdown]
# ## 기상데이터 : 년도별 -> 파일 하나로

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import fnmatch
from pandas import read_csv
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 
#from feature_engine import variable_transformers as vt
from scipy.stats import yeojohnson

#############################################
# 태양광 전력
#############################################
#def get_pow():

# pow 파일 load
dir_path    = 'C:/Users/VISLAB_PHY/Desktop/PV_VA/data/incheon/'
file_list   = os.listdir(dir_path)
origin = pd.DataFrame()

print(len(file_list))

for filename in file_list:
    if fnmatch.fnmatch(filename,'OBS_*.csv'):
        print(dir_path+filename)
        filedata = pd.read_csv(dir_path+filename, encoding='cp949')
        new    = pd.DataFrame(filedata)
        origin = pd.concat([origin,new])
    
origin.to_csv(dir_path+"/weather_2014_2020.csv",mode='w',index=False, encoding='CP949')
# Out:
# 7
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data/incheon/OBS_ASOS_TIM_20210328111305.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data/incheon/OBS_ASOS_TIM_20210328111351.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data/incheon/OBS_ASOS_TIM_20210328111414.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data/incheon/OBS_ASOS_TIM_20210328111433.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data/incheon/OBS_ASOS_TIM_20210328111515.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data/incheon/OBS_ASOS_TIM_20210328111558.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data/incheon/OBS_ASOS_TIM_20210328111631.csv

# %% [markdown]
# # 파일 복사

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import fnmatch
from pandas import read_csv
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 
#from feature_engine import variable_transformers as vt
from scipy.stats import yeojohnson
import shutil

#############################################
# 태양광 전력
#############################################
#def get_pow():

# pow 파일 load
dir_path    = 'Y:/elsys/'
target_path = 'C:/solar/'
file_list   = os.listdir(dir_path)
origin = pd.DataFrame()

for filename in file_list:
    if fnmatch.fnmatch(filename,'*.bat'):
    
        shutil.copy(dir_path+filename, target_path+filename)

# %% [markdown]
# # 미세먼지 데이터 merge

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import fnmatch
from pandas import read_csv
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 
#from feature_engine import variable_transformers as vt
from scipy.stats import yeojohnson

#############################################
# 태양광 전력
#############################################
#def get_pow():

# pow 파일 load
dir_path    = 'C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/'
file_list   = os.listdir(dir_path)
origin      = pd.DataFrame()
target      = '2017'
#station     = 111274 
#station     = 111251 
station     = 823662 
print(len(file_list))

for filename in file_list:
    if fnmatch.fnmatch(filename,'air_2015_2020_'+str(station)+'*.csv'):
        print(dir_path+filename)
        dataset = pd.read_csv(dir_path+filename, engine='python')
        print(dataset)
        dataset = dataset[dataset['측정소코드']==station]        
        dataset.to_csv(dir_path+filename+'_2.csv',mode='w',index=False, encoding='cp949')
# Out:
# 71
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/air_2015_2020_823662.csv
#             지역   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2   PM10  \
# 0       인천 계양구  823662   계산  2015010101  0.004  0.4  0.025  0.008   68.0
# 1       인천 계양구  823662   계산  2015010102  0.004  0.4  0.024  0.008   99.0
# 2       인천 계양구  823662   계산  2015010103  0.004  0.4  0.023  0.008  110.0
# 3       인천 계양구  823662   계산  2015010104  0.004  0.4  0.023  0.008  126.0
# 4       인천 계양구  823662   계산  2015010105  0.003  0.3  0.023  0.007  130.0
# ...        ...     ...  ...         ...    ...  ...    ...    ...    ...
# 100819  인천 계양구  823662   계산  2020093020  0.005  0.3  0.050  0.012   34.0
# 100820  인천 계양구  823662   계산  2020093021  0.005  0.4  0.039  0.012   30.0
# 100821  인천 계양구  823662   계산  2020093022  0.004  0.3  0.030  0.011   33.0
# 100822  인천 계양구  823662   계산  2020093023  0.004  0.3  0.023  0.013   20.0
# 100823  인천 계양구  823662   계산  2020093024  0.004  0.3  0.018  0.017   10.0
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import fnmatch
from pandas import read_csv
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 
#from feature_engine import variable_transformers as vt
from scipy.stats import yeojohnson

#############################################
# 태양광 전력
#############################################
#def get_pow():

# pow 파일 load
dir_path    = 'C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/'
file_list   = os.listdir(dir_path)
origin      = pd.DataFrame()
target      = '2017'
station     = 111274 
#station     = 111251 
#station     = 823662 
print(len(file_list))

for filename in file_list:
    if fnmatch.fnmatch(filename,target+'*.csv'):
        print(dir_path+filename)
        if target=='2016':
            dataset = pd.read_csv(dir_path+filename, encoding='cp949')
        else:
            dataset = pd.read_csv(dir_path+filename)
        
        dataset = dataset[dataset['측정소코드']==station]
        new    = pd.DataFrame(dataset)
        origin = pd.concat([origin,new])
            
    elif fnmatch.fnmatch(filename,target+'*.xlsx'):
        print(dir_path+filename)
        dataset = pd.read_excel(dir_path+filename)
        
        #if target!='2016':
        dataset.drop(['망'], axis=1, inplace=True)
        dataset = dataset[dataset['측정소코드']==station]
        new    = pd.DataFrame(dataset)
        origin = pd.concat([origin,new])
     
origin.to_csv(dir_path+'/air_'+str(station)+target+'.csv',mode='w',index=False)#, encoding='cp949')
# Out:
# 67
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 10월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 11월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 12월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 1월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 2월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 3월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 4월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 5월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 6월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 7월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 8월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2017년 9월.xlsx

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import fnmatch
from pandas import read_csv
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 
#from feature_engine import variable_transformers as vt
from scipy.stats import yeojohnson

#############################################
# 태양광 전력
#############################################
#def get_pow():

# pow 파일 load
dir_path    = 'C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/'
file_list   = os.listdir(dir_path)
origin      = pd.DataFrame()
target      = '2020'
station     = 111274 #111251
station_list= [111274, 111251, 823662]
print(len(file_list))

for station in station_list:

    for filename in file_list:
        if fnmatch.fnmatch(filename,target+'*.csv'):
            print(dir_path+filename)
            dataset = pd.read_csv(dir_path+filename)
            dataset = dataset[dataset['측정소코드']==station]
            #dataset = dataset[dataset['측정소코드'].isin([111274, 111251, 823662])]
            new    = pd.DataFrame(dataset)
            origin = pd.concat([origin,new])

        elif fnmatch.fnmatch(filename,target+'*.xlsx'):
            print(dir_path+filename)
            dataset = pd.read_excel(dir_path+filename)
            dataset.drop(['망'], axis=1, inplace=True)
            dataset = dataset[dataset['측정소코드']==station]
            new    = pd.DataFrame(dataset)
            origin = pd.concat([origin,new])

    origin.to_csv(dir_path+'/air_'+str(station)+target+'.csv',mode='w',index=False)
# Out:
# 58
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 10월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 1월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 2월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 3월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 4월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 5월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 6월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 7월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 8월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 9월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 10월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 1월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 2월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 3월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/2020년 4월.xlsx
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import fnmatch
from pandas import read_csv
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 
#from feature_engine import variable_transformers as vt
from scipy.stats import yeojohnson

#############################################
# 태양광 전력
#############################################
#def get_pow():

# pow 파일 load
dir_path    = 'C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/'
file_list   = os.listdir(dir_path)
origin      = pd.DataFrame()
target      = 'air_'
#station_list= [111274, 111251, 823662]
station_list= [823662]
print(len(file_list))

for station in station_list:
    for filename in file_list:
        if fnmatch.fnmatch(filename,target+str(station)+'*.csv'):
            print(dir_path+filename)
            dataset = pd.read_csv(dir_path+filename)
            new    = pd.DataFrame(dataset)
            origin = pd.concat([origin,new])
    origin.to_csv(dir_path+'/air_2015_2020_'+str(station)+'.csv',mode='w',index=False, encoding='CP949')
# Out:
# 69
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/air_8236622015.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/air_8236622016.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/air_8236622017.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/air_8236622018.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/air_8236622019.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/monthly/air_8236622020.csv

# %%
##### encoding이 연도별 제각각인 문제.
df = pd.read_csv('open_data_korean.csv', engine='python')
df = pd.read_csv('open_data_korean.csv', encoding='utf-8') #, encoding='utf-16')
df = pd.read_csv('newfile1.csv', encoding='euc-kr')
df = pd.read_csv('./population.csv', encoding='cp949')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import fnmatch
from pandas import read_csv
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 
#from feature_engine import variable_transformers as vt
from scipy.stats import yeojohnson

#############################################
# 태양광 전력
#############################################
#def get_pow():

# pow 파일 load
dir_path    = 'C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/'
file_list   = os.listdir(dir_path)
origin = pd.DataFrame()

print(len(file_list))

for filename in file_list:
    print(dir_path+filename)
    if fnmatch.fnmatch(filename,'air_2015_2020.csv'):
        dataset = pd.read_csv(dir_path+filename, engine='python')
        dataset['측정일시'] = dataset['측정일시'].str[5:]
        new    = pd.DataFrame(dataset)
        origin = pd.concat([origin,new])
            
origin.to_csv(dir_path+"/air_2015_2020.csv",mode='w',index=False)
# Out:
# 43
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2015년1분기.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2015년2분기.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2015년3분기.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2015년4분기.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2016년 1분기.csv
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 10월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 11월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 12월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 1월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 2월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 3월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 4월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 5월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 6월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 7월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 8월.xlsx
# C:/Users/VISLAB_PHY/Desktop/PV_VA/data_pm/2017년 9월.xlsx
# ...

# %%
from pandas import read_csv
from datetime import datetime
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import os
import fnmatch
import shutil

'''
target list
-------------
tooth
carp
stent
vismale
'abdomen', 'bonsai', 'tooth', 
'''

from_date  =20200808
to_date    =20210321
targetList = ['160110033', '160110034', '160110035','160110036']
#filetType  = 'bin' #'png'

for target in targetList:
    dir_path = 'Y:/elsys/solar/inv_achist/UR00000126/1018201609091504.1.1.9.'+target+'/'
    dst_dir  = 'C:/solar/inv_achist/UR00000126/1018201609091504.1.1.9.'+target+'/'

    file_list = os.listdir(dir_path)
    print(dir_path)
    print(len(file_list))

    for filename in os.listdir(dir_path):

        if os.path.exists(filename): continue;
        if len(filename)<10 or filename[8] != '_': continue; # 더미데이터 스킵
        
        file_date = filename[:8]
        if from_date > int(file_date) or int(file_date) > to_date: continue;

        if not(os.path.isdir(dst_dir)):
            os.makedirs(os.path.join(dst_dir))

        shutil.copy(dir_path+filename, dst_dir+filename)
        print(filename)
