# %%
import matplotlib as mpl
# 폰트 설정
mpl.rc('font', family='NanumGothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from pandas.plotting import scatter_matrix

data=pd.read_csv('data/data_wofore.csv')

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(), annot=True, fmt=".2f")
#plt.xticks(labels=np.array(range(12)))
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
plt.figure(figsize=(15,15))
scatter_matrix(data, alpha=0.03,figsize=(15, 15), diagonal='kde')
#plt.save('scatter.png',)
plt.show()

# %%
plt.figure(figsize=(24,1.5))
sns.heatmap(data.corr().iloc[:,:1].T, annot=True, fmt=".2f", annot_kws={"size": 30})
#plt.xticks(labels=np.array(range(13)))
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
array=data.corr().values[0,:]
print(array)
idx=np.argsort(-np.abs(array))
print(data.columns[idx])
print(np.sort(-np.abs(array)))
print(idx)
# Out:
# [ 1.          0.23944318 -0.06897595  0.30369184 -0.2481317  -0.55784698
#   0.00957914  0.00690173 -0.01660978  0.8081524   0.29320514  0.5006532 ]
# Index(['solar', 'sun', 'humi', 'gtemp', 'ws', 'sight', 'wd', 'temp', 'rain',
#        'gprs', 'prs', 'ptemp'],
#       dtype='object')
# [-1.         -0.8081524  -0.55784698 -0.5006532  -0.30369184 -0.29320514
#  -0.2481317  -0.23944318 -0.06897595 -0.01660978 -0.00957914 -0.00690173]
# [ 0  9  5 11  3 10  4  1  2  8  6  7]
