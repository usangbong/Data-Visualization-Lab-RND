# %% [markdown]
# # Acc가 떨어지는 두 부분 확인
# #### 0.02/1의 데이터 -> 오차확률 크게 계산됨
# #### RMSE등 다른 계산방법 사용할 것 (idx: 42, 144)

# %%
#---- to do list -----
# err_data_list 파일자동화
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

from tensorflow.python.keras.optimizer_v2.rmsprop import RMSProp
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv, DataFrame, concat
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, RepeatVector, LSTM, Input, TimeDistributed, Activation, Dropout
from keras.optimizers import SGD
np.set_printoptions(suppress=True)

#pow 낮값만 추출 test
#pow = 0인 구간 : 0~4, 21-23시
powhr_start = 5
powhr_end   = 20

shift_days  = 3
hoursteps   = powhr_end-powhr_start+1 #(16)
timesteps   = shift_days*hoursteps #hours step

data_dim    = 15
out_dim     = 1

n_model    = 10

season_mod = 'all_1030_f9'
date_start = '10190901'
date_end   = '30191201'

err_date_list = ['20190912',
                    '20191122',
                    '20191130',
                    '20191217',
                    '20200501',
                    '20200502',
                    '20191028',
                    '20191107',
                    '20191108',
                    '20191109',
                    '20191110',
                    '20191111',
                    '20191112',
                    '20200214',
                    '20200307',
                    '20200308',
                    '20200309',
                    '20200310',
                    '20200328',
                    '20200329',
                    '20200625',
                    '20200809']

# %% [markdown]
# # Yeo-JohnsonTransformer

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 

transf_type = 'yeo-johnson'
#transf_type = 'box-cox'

def yeo_johnson_transform(dataset):
    
    column_trans = ColumnTransformer(
                    [('sunshine', PowerTransformer(method=transf_type, standardize=True), ['sunshine']),
                     ('humdt', PowerTransformer(method=transf_type, standardize=True), ['humdt']),
                     ('wnd_spd', PowerTransformer(method=transf_type, standardize=True), ['wnd_spd']),
                     ('visiblt', PowerTransformer(method=transf_type, standardize=True), ['visiblt']),
                     ('cloud2', PowerTransformer(method=transf_type, standardize=True), ['cloud2']),
                     ('cloud', PowerTransformer(method=transf_type, standardize=True), ['cloud']),
                     ('grd_temprt', PowerTransformer(method=transf_type, standardize=True), ['grd_temprt']),
                     ('wnd_dir', PowerTransformer(method=transf_type, standardize=True), ['wnd_dir']),
                     ('dewpnt', PowerTransformer(method=transf_type, standardize=True), ['dewpnt']),
                     ('steampressr', PowerTransformer(method=transf_type, standardize=True), ['steampressr']),
                     ('temprt', PowerTransformer(method=transf_type, standardize=True), ['temprt']),
                     ('mincloud', PowerTransformer(method=transf_type, standardize=True), ['mincloud']),
                     ('rain', PowerTransformer(method=transf_type, standardize=True), ['rain']),
                     ('pressr', PowerTransformer(method=transf_type, standardize=True), ['pressr']),
                     ('seapressr', PowerTransformer(method=transf_type, standardize=True), ['seapressr']),
                     ('snow', PowerTransformer(method=transf_type, standardize=True), ['snow'])
                    ])
    
    transformed_data = column_trans.fit_transform(dataset)
    transformed_df = pd.DataFrame(transformed_data, columns=dataset.columns)
    pd.concat([transformed_df], axis = 1)
                    
    return transformed_df

# %% [markdown]
# # Get weather, pow data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import fnmatch
from pandas import read_csv
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer 
#from feature_engine import variable_transformers as vt
from scipy.stats import yeojohnson

#############################################
# 태양광 전력
#############################################
def get_pow():

    # pow 파일 load
    dir_path    = "C:/Users/VISLAB_PHY/Desktop/WORKSPACE/Origin/data/pow_24/UR00000126_csv"
    file_list   = os.listdir(dir_path)
    print(len(file_list))
    hrPow  = []    

    # pow측정값 에러가 큰 일자 제거
    for filename in file_list:
        if (filename[:-4] not in err_date_list):
            if ((filename[:-4]>=date_start) & (filename<date_end)):
                filedata = pd.read_csv(dir_path+'/'+filename).values[:,0]
                hrPow.append(filedata)
                
    #낮시간 추출 (5~20시)
    pow_dataset = pd.DataFrame(hrPow)
    pow_dataset =pow_dataset.iloc[:,powhr_start:powhr_end+1]
    #pow_dataset.to_csv("C:/Users/VISLAB_PHY/Desktop/WORKSPACE/Origin/data/pow_hr.csv",mode='w',index=False)

    # 결측값 보간, reshape
    pow_dataset = pow_dataset.interpolate(method='linear')
    pow_dataset = pow_dataset.values.reshape(-1,1)
    pow_dataset = pd.DataFrame(pow_dataset)
    pow_dataset.columns = ['pow']
    pow_dataset.to_csv("C:/Users/VISLAB_PHY/Desktop/WORKSPACE/Origin/data/pow.csv",mode='w',index=False)

    
    # scale
    sc_pow = MinMaxScaler(feature_range = (0, 1))
    scaled_pow = sc_pow.fit_transform(pow_dataset.values)
    df_pow = pd.DataFrame(scaled_pow, columns=pow_dataset.columns, index=list(pow_dataset.index.values))
    
    return df_pow, sc_pow

#############################################
# 종관기상관측
#############################################
def get_weather():
    # pow 파일 load
    dir_path    = "C:/Users/VISLAB_PHY/Desktop/WORKSPACE/Origin/DATA"
    file_list   = os.listdir(dir_path)
    print(len(file_list))
    for filename in os.listdir(dir_path):
        if fnmatch.fnmatch(filename, 'OBS_ASOS_TIM_*.csv'):
            print(filename)

            # load csv data
            dataset = read_csv(dir_path+'/'+filename, encoding='CP949')
            dataset.drop(['지점','지점명'], axis=1, inplace=True)
            dataset.drop(['기온 QC플래그','강수량 QC플래그','풍속 QC플래그','풍향 QC플래그','습도 QC플래그'], axis=1, inplace=True)
            dataset.drop(['현지기압 QC플래그','해면기압 QC플래그','일조 QC플래그','지면온도 QC플래그'], axis=1, inplace=True)
            dataset.drop(['5cm 지중온도(°C)','10cm 지중온도(°C)','20cm 지중온도(°C)','30cm 지중온도(°C)'], axis=1, inplace=True)
            dataset.drop(['3시간신적설(cm)','일사(MJ/m2)','운형(운형약어)','지면상태(지면상태코드)','현상번호(국내식)'], axis=1, inplace=True)

            # set column name
            dataset.columns = ['ymdhms', 'temprt', 'rain', 'wnd_spd', 'wnd_dir', 'humdt','steampressr',
                               'dewpnt', 'pressr','seapressr','sunshine','snow','cloud','cloud2','mincloud','visiblt','grd_temprt']

            # prioirty sort (피어슨상관계수)
            dataset = dataset[['ymdhms','sunshine','humdt','wnd_spd','visiblt','cloud2',
                               'cloud','grd_temprt','wnd_dir','dewpnt','steampressr','temprt',
                               'mincloud','rain','pressr','seapressr','snow']]


            # set NA data (관측값 0이 누적되어 결측된 경우. 0으로 세팅)
            dataset['rain'].fillna(0, inplace=True)     #강수량
            dataset['sunshine'].fillna(0, inplace=True) #일조
            dataset['snow'].fillna(0, inplace=True)     #적설량

            #일시 패턴 변환(2019-08-20 5:00 -> 2019082005)
            dataset['ymdhms'] = dataset['ymdhms'].str[0:4]+dataset['ymdhms'].str[5:7]+dataset['ymdhms'].str[8:10]+dataset['ymdhms'].str[11:13]
            # pow측정값 중 결측값 많은 일자 제거
            dataset = dataset[(dataset['ymdhms'].str[0:8]>=date_start) & (dataset['ymdhms'].str[0:8]<date_end)]
            for err_date in err_date_list:
                idx_err = dataset[dataset['ymdhms'].str.startswith(err_date)].index
                dataset = dataset.drop(idx_err)

            #낮시간 추출 (5~20시)
            dataset = dataset[(dataset['ymdhms'].str[-2:]>=str(powhr_start).rjust(2, '0')) &(dataset['ymdhms'].str[-2:]<=str(powhr_end))]
            dataset = dataset.interpolate(method='linear')# 결측값 보간
            
            # save file (test용)
            dataset.to_csv("C:/Users/VISLAB_PHY/Desktop/WORKSPACE/Origin/DATA/weather.csv",mode='w',index=False)

            # normalization
            dataset.drop(['ymdhms'], axis=1, inplace=True)
            dataset = dataset.astype('float32')
            dataset = dataset.interpolate(method='linear')
            
            #YEO-JOHNSON transform
            yeo_df = yeo_johnson_transform(dataset)
            
            #insert feature (test)*************************************
            yeo_df.insert(2, 'temp_press', yeo_df['temprt']-yeo_df['steampressr'], True)
            yeo_df.insert(2, 'sunshine_humdt', abs(yeo_df['sunshine'])-(yeo_df['humdt']*(2.1)), True)#0.35
            
            sc = MinMaxScaler(feature_range = (0, 1))#scale
            scaled_weather = sc.fit_transform(yeo_df.values)
            weather = pd.DataFrame(scaled_weather, columns=yeo_df.columns, index=list(yeo_df.index.values))
            
            weather = weather.iloc[:, 0:data_dim] #feature size 조절
            
    return weather

# %% [markdown]
# # Numpy data
# weather, pow

# %%
#############################################
# numpy data 만들기
#############################################

df_pow, sc_pow   = get_pow()
df               = get_weather()

# pow + weather + powY
df.insert(0, 'pow', df_pow.values, True)
df = df.iloc[0:-timesteps, :]
df.insert(df.shape[1], 'pow_Y', df_pow.iloc[timesteps:, :].values, True)

df.to_csv("C:/Users/VISLAB_PHY/Desktop/WORKSPACE/Origin/data/total.csv",mode='w',index=False, encoding='CP949')

#----------------------------------------------
# time step만큼 window 움직여 dataset 생성
#----------------------------------------------
totalsize = df.shape[0]
dataX, dataY = [], []

for i in range(0, totalsize-timesteps-24+1, hoursteps):
    dataX.append(df.iloc[i:(i + timesteps),0:-1])
    dataY.append(df.iloc[i:(i + hoursteps),[0]])

print("len(dataX) : ", len(dataX), dataX[0].shape)
print("len(dataY) : ", len(dataY), dataY[0].shape)

#----------------------------------------------
#  Split train/test 
#----------------------------------------------

train_size = int(len(dataX) * 0.7)
val_size   = int(len(dataX) * 0.2)
test_size  = len(dataX) - train_size - val_size
val_idx = train_size+val_size

trainX, valX, testX = np.array(dataX[0:train_size]), np.array(dataX[train_size:val_idx]), np.array(dataX[val_idx:val_idx+test_size])
trainY, valY, testY = np.array(dataY[0:train_size]), np.array(dataY[train_size:val_idx]), np.array(dataY[val_idx:val_idx+test_size])

print('train X : ', trainX.shape, '\tY : ', trainY.shape)
print('val   X : ', valX.shape,   '\tY : ', valY.shape)
print('test  X : ', testX.shape,  '\tY : ', testY.shape)

np.save("npset/"+season_mod+"_trainX",trainX)
np.save("npset/"+season_mod+"_trainY",trainY)
np.save("npset/"+season_mod+"_valX",valX)
np.save("npset/"+season_mod+"_valY",valY)
np.save("npset/"+season_mod+"_testX",testX)
np.save("npset/"+season_mod+"_testY",testY)
# Out:
# 337
# 18
# OBS_ASOS_TIM_20200929025447.csv
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\numpy\core\_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\numpy\core\_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\numpy\core\_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\numpy\core\_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# len(dataX) :  327 (48, 16)
# len(dataY) :  327 (16, 1)
# train X :  (228, 48, 16) 	Y :  (228, 16, 1)
# val   X :  (65, 48, 16) 	Y :  (65, 16, 1)
# test  X :  (34, 48, 16) 	Y :  (34, 16, 1)

# %% [markdown]
# # 모델 1

# %%
model = Sequential()
model.add(LSTM(256, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(RepeatVector(data_dim+1))
model.add(LSTM(256, return_sequences=True))
model.add(TimeDistributed(Dense(256, activation='relu')))
model.add(TimeDistributed(Dense(1)))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 256)               279552
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 16, 256)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16, 256)           525312
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 16, 256)           65792
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 16, 1)             257
# =================================================================
# Total params: 870,913
# Trainable params: 870,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 모델 fit 반복돌리기
# range 바꾸기

# %%
for i in range(n_model):#0,5):#

    #keras.optimizers.RMSprop(lr=0.005, rho=0.9, epsilon=None, decay=0.0)
    model.compile(loss='mean_squared_error', 
                  optimizer=RMSProp()
                  #optimizer=RMSProp(learning_rate=0.001)
                  #optimizer=SGD(lr=0.01, momentum=0.9, nesterov=True), 
                  #metrics=['acc'])
                 )

    hist = model.fit(trainX, 
                     trainY, 
                     epochs=100, 
                     batch_size=64,
                     validation_data=(valX, valY))


    results = model.evaluate(testX, testY)
    #model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=0)

    model.save('model/model_'+season_mod+'_'+str(i)+'.h5')# # of feature=3,5,7,9,?,12,14,16,18
# Out:
# Train on 228 samples, validate on 65 samples
# Epoch 1/100
# 228/228 [==============================] - 1s 4ms/step - loss: 0.5983 - val_loss: 0.0420
# Epoch 2/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0388 - val_loss: 0.0377
# Epoch 3/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0362 - val_loss: 0.0410
# Epoch 4/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0349 - val_loss: 0.0338
# Epoch 5/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0392 - val_loss: 0.0351
# Epoch 6/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0332 - val_loss: 0.0309
# Epoch 7/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0359 - val_loss: 0.0369
# Epoch 8/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0345 - val_loss: 0.0308
# Epoch 9/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0318 - val_loss: 0.0596
# Epoch 10/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0413 - val_loss: 0.0294
# Epoch 11/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0309 - val_loss: 0.0571
# Epoch 12/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0436 - val_loss: 0.0335
# Epoch 13/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0323 - val_loss: 0.0386
# Epoch 14/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0329 - val_loss: 0.0329
# Epoch 15/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0266 - val_loss: 0.0570
# Epoch 16/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0548 - val_loss: 0.0258
# Epoch 17/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0322 - val_loss: 0.0313
# Epoch 18/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0258 - val_loss: 0.0201
# Epoch 19/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0224 - val_loss: 0.0296
# Epoch 20/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0206 - val_loss: 0.0256
# Epoch 21/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0229 - val_loss: 0.0180
# Epoch 22/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0160 - val_loss: 1.1075
# Epoch 23/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.2715 - val_loss: 0.0259
# Epoch 24/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0228 - val_loss: 0.0220
# Epoch 25/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0221 - val_loss: 0.0240
# Epoch 26/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0197 - val_loss: 0.0245
# Epoch 27/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0188 - val_loss: 0.0178
# Epoch 28/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0162 - val_loss: 0.0175
# Epoch 29/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0302 - val_loss: 0.0267
# Epoch 30/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0227 - val_loss: 0.0192
# Epoch 31/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0164 - val_loss: 0.0185
# Epoch 32/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0166 - val_loss: 0.0238
# Epoch 33/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0166 - val_loss: 0.0130
# Epoch 34/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0165 - val_loss: 0.0388
# Epoch 35/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0228 - val_loss: 0.0121
# Epoch 36/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0153 - val_loss: 0.0150
# Epoch 37/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0156 - val_loss: 0.0313
# Epoch 38/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0161
# Epoch 39/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0172 - val_loss: 0.0233
# Epoch 40/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0245 - val_loss: 0.0232
# Epoch 41/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0162 - val_loss: 0.0193
# Epoch 42/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.0156
# Epoch 43/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0211 - val_loss: 0.0218
# Epoch 44/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0185 - val_loss: 0.0145
# Epoch 45/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0147
# Epoch 46/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0174 - val_loss: 0.0097
# Epoch 47/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0099 - val_loss: 0.0756
# Epoch 48/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0382 - val_loss: 0.0270
# Epoch 49/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0220 - val_loss: 0.0158
# Epoch 50/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0330
# Epoch 51/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0300 - val_loss: 0.0135
# Epoch 52/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0173
# Epoch 53/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0159 - val_loss: 0.0195
# Epoch 54/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0091
# Epoch 55/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0196
# Epoch 56/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0164 - val_loss: 0.0130
# Epoch 57/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0159 - val_loss: 0.0193
# Epoch 58/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0160 - val_loss: 0.0141
# Epoch 59/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0115
# Epoch 60/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0168 - val_loss: 0.0108
# Epoch 61/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0093 - val_loss: 0.0115
# Epoch 62/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0148 - val_loss: 0.0138
# Epoch 63/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0077
# Epoch 64/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0148
# Epoch 65/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0156 - val_loss: 0.0113
# Epoch 66/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 67/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0331
# Epoch 68/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0178 - val_loss: 0.0182
# Epoch 69/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0107 - val_loss: 0.0083
# Epoch 70/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0135
# Epoch 71/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0139
# Epoch 72/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0100 - val_loss: 0.0066
# Epoch 73/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0094 - val_loss: 0.0115
# Epoch 74/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0143 - val_loss: 0.0091
# Epoch 75/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 76/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0070 - val_loss: 0.0291
# Epoch 77/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0077
# Epoch 78/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0109 - val_loss: 0.0053
# Epoch 79/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0126
# Epoch 80/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 81/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0108
# Epoch 82/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0077 - val_loss: 0.0182
# Epoch 83/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0149 - val_loss: 0.0300
# Epoch 84/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0098
# Epoch 85/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0087
# Epoch 86/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0072 - val_loss: 0.0222
# Epoch 87/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 88/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0074
# Epoch 89/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0148 - val_loss: 0.0146
# Epoch 90/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 91/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 92/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0120
# Epoch 93/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0432
# Epoch 94/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0117 - val_loss: 0.0111
# Epoch 95/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 96/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0064
# Epoch 97/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0064
# Epoch 98/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0157 - val_loss: 0.0349
# Epoch 99/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0166 - val_loss: 0.0120
# Epoch 100/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0086
# 34/34 [==============================] - 0s 2ms/step
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\keras\engine\saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# Train on 228 samples, validate on 65 samples
# Epoch 1/100
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2840 - val_loss: 0.0071
# Epoch 2/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 3/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0057
# Epoch 4/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0064
# Epoch 5/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0058
# Epoch 6/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0055
# Epoch 7/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0047
# Epoch 8/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0047
# Epoch 9/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0062
# Epoch 10/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0050
# Epoch 11/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0128
# Epoch 12/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0072
# Epoch 13/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0079
# Epoch 14/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 15/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 16/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0094
# Epoch 17/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0082 - val_loss: 0.0134
# Epoch 18/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0078
# Epoch 19/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0050
# Epoch 20/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0116
# Epoch 21/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0070 - val_loss: 0.0085
# Epoch 22/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0068
# Epoch 23/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0096 - val_loss: 0.0089
# Epoch 24/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 25/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 26/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0340
# Epoch 27/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0067
# Epoch 28/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 29/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 30/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0062
# Epoch 31/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 32/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0154
# Epoch 33/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0078
# Epoch 34/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 35/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 36/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0051
# Epoch 37/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0049
# Epoch 38/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0268
# Epoch 39/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0069
# Epoch 40/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0453
# Epoch 41/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0034
# Epoch 42/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 43/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 44/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0060
# Epoch 45/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0065
# Epoch 46/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 47/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0079 - val_loss: 0.0038
# Epoch 48/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 49/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0096
# Epoch 50/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0051
# Epoch 51/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 52/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0067 - val_loss: 0.0107
# Epoch 53/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0044
# Epoch 54/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0074
# Epoch 55/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0071
# Epoch 56/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0071
# Epoch 57/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0061
# Epoch 58/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0114
# Epoch 59/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 60/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 61/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0087
# Epoch 62/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 63/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0075
# Epoch 64/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0060
# Epoch 65/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0067
# Epoch 66/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0065
# Epoch 67/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0174
# Epoch 68/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0051 - val_loss: 0.0063
# Epoch 69/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0060
# Epoch 70/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 71/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0046
# Epoch 72/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0046
# Epoch 73/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0066
# Epoch 74/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0198
# Epoch 75/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0054
# Epoch 76/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 77/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 78/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0057
# Epoch 79/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0123
# Epoch 80/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0081
# Epoch 81/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0088
# Epoch 82/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0041
# Epoch 83/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0051
# Epoch 84/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0063
# Epoch 85/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0046
# Epoch 86/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 87/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0095
# Epoch 88/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0083
# Epoch 89/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0058 - val_loss: 0.0044
# Epoch 90/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 91/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 92/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0056
# Epoch 93/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0043
# Epoch 94/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 95/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 96/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 97/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0046
# Epoch 98/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0050
# Epoch 99/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 100/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0037
# 34/34 [==============================] - 0s 2ms/step
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\keras\engine\saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# Train on 228 samples, validate on 65 samples
# Epoch 1/100
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0161 - val_loss: 0.0203
# Epoch 2/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0035
# Epoch 3/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0055
# Epoch 4/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 5/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0039
# Epoch 6/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0050
# Epoch 7/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0080
# Epoch 8/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0049
# Epoch 9/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 10/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 11/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0260
# Epoch 12/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 13/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 14/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 15/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0055
# Epoch 16/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0052
# Epoch 17/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0055
# Epoch 18/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 19/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0075
# Epoch 20/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 21/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0047
# Epoch 22/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0146
# Epoch 23/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0061
# Epoch 24/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 25/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0057
# Epoch 26/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0051
# Epoch 27/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0064
# Epoch 28/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0044
# Epoch 29/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0063
# Epoch 30/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0051
# Epoch 31/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0296
# Epoch 32/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0060 - val_loss: 0.0032
# Epoch 33/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0046
# Epoch 34/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 35/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 36/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 37/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0056
# Epoch 38/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 39/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0067
# Epoch 40/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0055
# Epoch 41/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0083
# Epoch 42/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0036
# Epoch 43/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0064
# Epoch 44/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0074
# Epoch 45/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 46/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0061
# Epoch 47/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 48/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 49/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0039
# Epoch 50/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0119
# Epoch 51/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 52/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0036
# Epoch 53/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0067
# Epoch 54/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 55/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 56/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0050
# Epoch 57/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 58/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 59/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0041
# Epoch 60/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 61/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 62/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0046
# Epoch 63/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 64/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 65/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 66/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 67/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0060
# Epoch 68/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 69/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 70/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0042
# Epoch 71/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 72/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0047
# Epoch 73/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 74/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0042
# Epoch 75/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 76/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0051
# Epoch 77/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0087
# Epoch 78/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0083
# Epoch 79/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0042
# Epoch 80/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0042
# Epoch 81/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0058
# Epoch 82/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0057
# Epoch 83/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0108
# Epoch 84/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 85/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 86/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0046
# Epoch 87/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0044
# Epoch 88/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 89/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 90/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0044
# Epoch 91/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 92/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 93/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0045
# Epoch 94/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0064
# Epoch 95/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 96/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 97/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 98/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 99/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0218
# Epoch 100/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0049
# 34/34 [==============================] - 0s 2ms/step
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\keras\engine\saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# Train on 228 samples, validate on 65 samples
# Epoch 1/100
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 2/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0168
# Epoch 3/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 4/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 5/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 6/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 7/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 8/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0064
# Epoch 9/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 10/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0061
# Epoch 11/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 12/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 13/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0067
# Epoch 14/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 15/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 16/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0044
# Epoch 17/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 18/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 19/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 20/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 21/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 22/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0037
# Epoch 23/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 24/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 25/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 26/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0064
# Epoch 27/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0056
# Epoch 28/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0050
# Epoch 29/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 30/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 0.0029
# Epoch 31/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0086
# Epoch 32/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 33/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 34/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 35/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 36/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 37/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0050
# Epoch 38/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 39/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 40/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 41/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0037
# Epoch 42/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0049
# Epoch 43/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0087
# Epoch 44/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0063
# Epoch 45/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 46/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.5919e-04 - val_loss: 0.0036
# Epoch 47/100
# 228/228 [==============================] - 0s 1ms/step - loss: 8.9814e-04 - val_loss: 0.0036
# Epoch 48/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0076
# Epoch 49/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 50/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 51/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 52/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0052
# Epoch 53/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0047
# Epoch 54/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0070
# Epoch 55/100
# 228/228 [==============================] - ETA: 0s - loss: 0.005 - 0s 1ms/step - loss: 0.0051 - val_loss: 0.0077
# Epoch 56/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 57/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 58/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0038
# Epoch 59/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0055
# Epoch 60/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 61/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 62/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0055
# Epoch 63/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0065
# Epoch 64/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 65/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0062
# Epoch 66/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 67/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0055
# Epoch 68/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0041
# Epoch 69/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0048
# Epoch 70/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 71/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 72/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 73/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 74/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 75/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0085
# Epoch 76/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 77/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 78/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 79/100
# 228/228 [==============================] - 0s 1ms/step - loss: 8.5544e-04 - val_loss: 0.0037
# Epoch 80/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.9956e-04 - val_loss: 0.0064
# Epoch 81/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 82/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 83/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 84/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 85/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0054
# Epoch 86/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 87/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0044
# Epoch 88/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 89/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 90/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 91/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 92/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 93/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 94/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 95/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 96/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 0.0030
# Epoch 97/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.5621e-04 - val_loss: 0.0032
# Epoch 98/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 99/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 100/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0040
# 34/34 [==============================] - 0s 2ms/step
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\keras\engine\saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# Train on 228 samples, validate on 65 samples
# Epoch 1/100
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0086 - val_loss: 0.0049
# Epoch 2/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 3/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.7649e-04 - val_loss: 0.0037
# Epoch 4/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.1552e-04 - val_loss: 0.0038
# Epoch 5/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0042
# Epoch 6/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 7/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0050
# Epoch 8/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 9/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 10/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 0.0062
# Epoch 11/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0052
# Epoch 12/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0047
# Epoch 13/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 14/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.6913e-04 - val_loss: 0.0039
# Epoch 15/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0075
# Epoch 16/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 17/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 18/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 19/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 20/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0064
# Epoch 21/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0053
# Epoch 22/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 23/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0073
# Epoch 24/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0047
# Epoch 25/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 26/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 27/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 28/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 29/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 30/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 31/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.9519e-04 - val_loss: 0.0026
# Epoch 32/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 33/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0045
# Epoch 34/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0038
# Epoch 35/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 36/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 37/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 38/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 39/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 40/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.8304e-04 - val_loss: 0.0040
# Epoch 41/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0051
# Epoch 42/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0038
# Epoch 43/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0052
# Epoch 44/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0053
# Epoch 45/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.2486e-04 - val_loss: 0.0038
# Epoch 46/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.6517e-04 - val_loss: 0.0035
# Epoch 47/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.6151e-04 - val_loss: 0.0032
# Epoch 48/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.5120e-04 - val_loss: 0.0050
# Epoch 49/100
# ...
# Epoch 60/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.7328e-04 - val_loss: 0.0046
# Epoch 61/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.5792e-04 - val_loss: 0.0048
# Epoch 62/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9165e-04 - val_loss: 0.0052
# Epoch 63/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.5658e-04 - val_loss: 0.0059
# Epoch 64/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.1161e-04 - val_loss: 0.0058
# Epoch 65/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.7227e-04 - val_loss: 0.0051
# Epoch 66/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.3898e-04 - val_loss: 0.0044
# Epoch 67/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.6501e-04 - val_loss: 0.0043
# Epoch 68/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.1437e-04 - val_loss: 0.0040
# Epoch 69/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.1455e-04 - val_loss: 0.0038
# Epoch 70/100
# 228/228 [==============================] - 0s 1ms/step - loss: 8.8128e-04 - val_loss: 0.0046
# Epoch 71/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.2930e-04 - val_loss: 0.0049
# Epoch 72/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.2286e-04 - val_loss: 0.0052
# Epoch 73/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.2985e-04 - val_loss: 0.0059
# Epoch 74/100
# 228/228 [==============================] - 0s 1ms/step - loss: 8.4247e-04 - val_loss: 0.0058
# Epoch 75/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.1552e-04 - val_loss: 0.0060
# Epoch 76/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.9378e-04 - val_loss: 0.0055
# Epoch 77/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.7999e-04 - val_loss: 0.0043
# Epoch 78/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.1074e-04 - val_loss: 0.0040
# Epoch 79/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.4713e-04 - val_loss: 0.0050
# Epoch 80/100
# 228/228 [==============================] - 0s 1ms/step - loss: 9.1920e-04 - val_loss: 0.0040
# Epoch 81/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.5451e-04 - val_loss: 0.0042
# Epoch 82/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.4081e-04 - val_loss: 0.0038
# Epoch 83/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.9696e-04 - val_loss: 0.0042
# Epoch 84/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.0003e-04 - val_loss: 0.0044
# Epoch 85/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.3987e-04 - val_loss: 0.0048
# Epoch 86/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.6186e-04 - val_loss: 0.0067
# Epoch 87/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.8171e-04 - val_loss: 0.0058
# Epoch 88/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.1398e-04 - val_loss: 0.0056
# Epoch 89/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.4850e-04 - val_loss: 0.0051
# Epoch 90/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.0490e-04 - val_loss: 0.0065
# Epoch 91/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.2328e-04 - val_loss: 0.0057
# Epoch 92/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.9853e-04 - val_loss: 0.0052
# Epoch 93/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.2402e-04 - val_loss: 0.0047
# Epoch 94/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.6479e-04 - val_loss: 0.0043
# Epoch 95/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.1082e-04 - val_loss: 0.0041
# Epoch 96/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.8318e-04 - val_loss: 0.0039
# Epoch 97/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.7348e-04 - val_loss: 0.0041
# Epoch 98/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.1348e-04 - val_loss: 0.0046
# Epoch 99/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.2278e-04 - val_loss: 0.0042
# Epoch 100/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.4626e-04 - val_loss: 0.0045
# 34/34 [==============================] - 0s 2ms/step
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\keras\engine\saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# Train on 228 samples, validate on 65 samples
# Epoch 1/100
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0024 - val_loss: 0.0057
# Epoch 2/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 3/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.3290e-04 - val_loss: 0.0046
# Epoch 4/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.4954e-04 - val_loss: 0.0046
# Epoch 5/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.7832e-04 - val_loss: 0.0043
# Epoch 6/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.3891e-04 - val_loss: 0.0047
# Epoch 7/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.8648e-04 - val_loss: 0.0061
# Epoch 8/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.3947e-04 - val_loss: 0.0077
# Epoch 9/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.9247e-04 - val_loss: 0.0056
# Epoch 10/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.2965e-04 - val_loss: 0.0047
# Epoch 11/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9509e-04 - val_loss: 0.0047
# Epoch 12/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.3332e-04 - val_loss: 0.0043
# Epoch 13/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.4915e-04 - val_loss: 0.0051
# Epoch 14/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.8239e-04 - val_loss: 0.0043
# Epoch 15/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.6101e-04 - val_loss: 0.0043
# Epoch 16/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.4376e-04 - val_loss: 0.0044
# Epoch 17/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.8331e-04 - val_loss: 0.0039
# Epoch 18/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.2030e-04 - val_loss: 0.0043
# Epoch 19/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.5731e-04 - val_loss: 0.0040
# Epoch 20/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.7908e-04 - val_loss: 0.0045
# Epoch 21/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.1800e-04 - val_loss: 0.0054
# Epoch 22/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.7581e-04 - val_loss: 0.0055
# Epoch 23/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.1011e-04 - val_loss: 0.0054
# Epoch 24/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.2231e-04 - val_loss: 0.0061
# Epoch 25/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.3810e-04 - val_loss: 0.0050
# Epoch 26/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.0412e-04 - val_loss: 0.0056
# Epoch 27/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.7622e-04 - val_loss: 0.0058
# Epoch 28/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.2036e-04 - val_loss: 0.0058
# Epoch 29/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.3785e-04 - val_loss: 0.0066
# Epoch 30/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.4412e-04 - val_loss: 0.0056
# Epoch 31/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.5966e-04 - val_loss: 0.0053
# Epoch 32/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.5417e-04 - val_loss: 0.0042
# Epoch 33/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.1479e-04 - val_loss: 0.0054
# Epoch 34/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.3627e-04 - val_loss: 0.0059
# Epoch 35/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.4965e-04 - val_loss: 0.0058
# Epoch 36/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0079
# Epoch 37/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.5694e-04 - val_loss: 0.0063
# Epoch 38/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.0211e-04 - val_loss: 0.0062
# Epoch 39/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.7314e-04 - val_loss: 0.0063
# Epoch 40/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.4879e-04 - val_loss: 0.0061
# Epoch 41/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.9618e-04 - val_loss: 0.0063
# Epoch 42/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.5395e-04 - val_loss: 0.0073
# Epoch 43/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.9478e-04 - val_loss: 0.0059
# Epoch 44/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.0792e-04 - val_loss: 0.0063
# Epoch 45/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.7061e-04 - val_loss: 0.0051
# Epoch 46/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.7127e-04 - val_loss: 0.0057
# Epoch 47/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.0047e-04 - val_loss: 0.0075
# Epoch 48/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.2919e-04 - val_loss: 0.0066
# Epoch 49/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.7806e-04 - val_loss: 0.0051
# Epoch 50/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.7817e-04 - val_loss: 0.0048
# Epoch 51/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.4126e-04 - val_loss: 0.0049
# Epoch 52/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.5586e-04 - val_loss: 0.0054
# Epoch 53/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.9709e-04 - val_loss: 0.0072
# Epoch 54/100
# 228/228 [==============================] - 0s 1ms/step - loss: 8.9610e-04 - val_loss: 0.0058
# Epoch 55/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.6081e-04 - val_loss: 0.0046
# Epoch 56/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9445e-04 - val_loss: 0.0061
# Epoch 57/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.5711e-04 - val_loss: 0.0050
# Epoch 58/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.5654e-04 - val_loss: 0.0055
# Epoch 59/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.7102e-04 - val_loss: 0.0047
# Epoch 60/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.9986e-04 - val_loss: 0.0045
# Epoch 61/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.8733e-04 - val_loss: 0.0039
# Epoch 62/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.8713e-04 - val_loss: 0.0042
# Epoch 63/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.5462e-04 - val_loss: 0.0042
# Epoch 64/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.1586e-04 - val_loss: 0.0047
# Epoch 65/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.3483e-04 - val_loss: 0.0049
# Epoch 66/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.7709e-04 - val_loss: 0.0054
# Epoch 67/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.8461e-04 - val_loss: 0.0059
# Epoch 68/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.7179e-04 - val_loss: 0.0077
# Epoch 69/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.0417e-04 - val_loss: 0.0050
# Epoch 70/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.6848e-04 - val_loss: 0.0046
# Epoch 71/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.0914e-04 - val_loss: 0.0051
# Epoch 72/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.6552e-04 - val_loss: 0.0064
# Epoch 73/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.5323e-04 - val_loss: 0.0062
# Epoch 74/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.0998e-04 - val_loss: 0.0052
# Epoch 75/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.7010e-04 - val_loss: 0.0053
# Epoch 76/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9492e-04 - val_loss: 0.0049
# Epoch 77/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.0509e-04 - val_loss: 0.0056
# Epoch 78/100
# 228/228 [==============================] - 0s 1ms/step - loss: 3.9341e-04 - val_loss: 0.0055
# Epoch 79/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9418e-04 - val_loss: 0.0060
# Epoch 80/100
# 228/228 [==============================] - 0s 1ms/step - loss: 8.4739e-04 - val_loss: 0.0063
# Epoch 81/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.4498e-04 - val_loss: 0.0049
# Epoch 82/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.0695e-04 - val_loss: 0.0047
# Epoch 83/100
# 228/228 [==============================] - 0s 1ms/step - loss: 1.2534e-04 - val_loss: 0.0044
# Epoch 84/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9350e-04 - val_loss: 0.0043
# Epoch 85/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.7083e-04 - val_loss: 0.0047
# Epoch 86/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.4025e-04 - val_loss: 0.0039
# Epoch 87/100
# 228/228 [==============================] - 0s 1ms/step - loss: 7.1454e-04 - val_loss: 0.0045
# Epoch 88/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9525e-04 - val_loss: 0.0045
# Epoch 89/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.3814e-04 - val_loss: 0.0040
# Epoch 90/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.9403e-04 - val_loss: 0.0043
# Epoch 91/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.4486e-04 - val_loss: 0.0043
# Epoch 92/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.6372e-04 - val_loss: 0.0045
# Epoch 93/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9455e-04 - val_loss: 0.0062
# Epoch 94/100
# 228/228 [==============================] - 0s 1ms/step - loss: 6.4803e-04 - val_loss: 0.0054
# Epoch 95/100
# 228/228 [==============================] - 0s 1ms/step - loss: 4.0949e-04 - val_loss: 0.0062
# Epoch 96/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.7030e-04 - val_loss: 0.0057
# Epoch 97/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.9393e-04 - val_loss: 0.0047
# Epoch 98/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.0746e-04 - val_loss: 0.0048
# Epoch 99/100
# 228/228 [==============================] - 0s 1ms/step - loss: 2.0415e-04 - val_loss: 0.0052
# Epoch 100/100
# 228/228 [==============================] - 0s 1ms/step - loss: 5.9686e-04 - val_loss: 0.0057
# 34/34 [==============================] - 0s 2ms/step
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\keras\engine\saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '

# %% [markdown]
# # trainX 학습과정

# %%
# 5. 모델 학습 과정 표시하기
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper right')
plt.show()
print('result : ', results)
# Out:
# result :  0.002466204110532999

# %%
plotY = trainY.reshape(-1,1)
plotY_pred = model.predict(trainX).reshape(-1,1)
#144 42
end = 48
step = hoursteps*7
#for i in range(42, plotY.shape[0]-step, step):
#for i in range(0, 240-step, step):
i = 6* hoursteps*7
plt.rcParams["figure.figsize"] = (12,4)
plt.plot(plotY[i:i+step], 'ro-', label="target")
plt.plot(plotY_pred[i:i+step], 'ys-', label="output")
plt.ylim(0,1)
plt.legend()
plt.show()

#for i in range(0, plotY.shape[0]-step, step):
#for i in range(0, 240-step, step):
i = 20*hoursteps*7
plt.rcParams["figure.figsize"] = (12,4)
plt.plot(plotY[i:i+step], 'ro-', label="target")
plt.plot(plotY_pred[i:i+step], 'ys-', label="output")
plt.ylim(0,1)
plt.legend()
plt.show()
    
#print(plotY_pred)


end = 48
step = hoursteps*1
#for i in range(42, plotY.shape[0]-step, step):
#for i in range(0, 240-step, step):
i = (6* hoursteps*7)
plt.rcParams["figure.figsize"] = (12,4)
plt.plot(plotY[i:i+step], 'ro-', label="target")
plt.plot(plotY_pred[i:i+step], 'ys-', label="output")
plt.ylim(0,0.05)
plt.legend()
plt.show()

#for i in range(0, plotY.shape[0]-step, step):
#for i in range(0, 240-step, step):
i = (20* hoursteps*7) + hoursteps*4
plt.rcParams["figure.figsize"] = (12,4)
plt.plot(plotY[i:i+step], 'ro-', label="target")
plt.plot(plotY_pred[i:i+step], 'ys-', label="output")
plt.ylim(0,0.05)
plt.legend()
plt.show()
    
#print(plotY_pred)

# %%
plotY = trainY.reshape(-1,1)
plotY_pred = model.predict(trainX).reshape(-1,1)

end = 48
step = hoursteps*7
for i in range(0, plotY.shape[0]-step, step):
#for i in range(0, 240-step, step):
    plt.rcParams["figure.figsize"] = (12,4)
    plt.plot(plotY[i:i+step], 'ro-', label="target")
    plt.plot(plotY_pred[i:i+step], 'ys-', label="output")
    plt.legend()
    plt.show()

#print(plotY_pred)

# %%
y = sc_pow.inverse_transform(trainY[:,:,0])
plotY = y.reshape(-1,1)

pred = model.predict(trainX)[:,:,0]
#pred[pred<0] = 0

x = sc_pow.inverse_transform(pred)
plot_pred = x.reshape(-1,1)

acc_list = []
target_list=[]

for i in range(0, plotY.shape[0]-hoursteps, hoursteps):
    plt.rcParams["figure.figsize"] = (12,4)
    plt.plot(plotY[i:i+hoursteps], 'ro-', label="target")
    plt.plot(plot_pred[i:i+hoursteps], 'ys-', label="output")
    #plt.legend()
    #plt.show()
    
    pred = np.sum(plot_pred[i:i+hoursteps])
    target      = round(np.sum(plotY[i:i+hoursteps]), 2)
    
    error       = round(np.abs(target-pred), 2)
    error_rate  = round(error/target, 2)
    acc_rate    = np.max([round((1.0-error_rate)*100, 2),0])
    
    target_list.append(target)
    acc_list.append(acc_rate)
    #print("   pred: ",pred," | target: ",target," | error: ",error," | err rate: ",error_rate," | acc: ",acc_rate,sep="")

# %%
print("mean(acc rate): ",np.mean(acc_list),sep='')
    
#plotAcc = np.array(acc_list).reshape(-1,1)
plt.plot(acc_list, 'ro-')
plt.title("Accuracy")
plt.show()
print(acc_list)
# Out:
# mean(acc rate): 94.68281938325991
# [88.0, 88.0, 93.0, 98.0, 94.0, 98.0, 92.0, 91.0, 86.0, 88.0, 99.0, 92.0, 86.0, 92.0, 97.0, 88.0, 95.0, 86.0, 91.0, 95.0, 97.0, 99.0, 94.0, 96.0, 99.0, 96.0, 85.0, 99.0, 98.0, 96.0, 94.0, 97.0, 95.0, 100.0, 99.0, 94.0, 93.0, 90.0, 96.0, 91.0, 91.0, 98.0, 22.0, 94.0, 92.0, 94.0, 93.0, 97.0, 100.0, 95.0, 97.0, 97.0, 96.0, 98.0, 99.0, 98.0, 97.0, 91.0, 99.0, 98.0, 100.0, 96.0, 99.0, 99.0, 100.0, 98.0, 98.0, 94.0, 97.0, 97.0, 97.0, 95.0, 95.0, 96.0, 95.0, 98.0, 95.0, 92.0, 96.0, 96.0, 91.0, 100.0, 97.0, 90.0, 97.0, 97.0, 95.0, 96.0, 91.0, 92.0, 90.0, 96.0, 91.0, 99.0, 88.0, 97.0, 89.0, 96.0, 100.0, 95.0, 94.0, 94.0, 87.0, 96.0, 97.0, 100.0, 94.0, 94.0, 98.0, 99.0, 95.0, 99.0, 92.0, 91.0, 98.0, 94.0, 90.0, 94.0, 99.0, 95.0, 92.0, 97.0, 98.0, 96.0, 91.0, 99.0, 95.0, 92.0, 93.0, 77.0, 85.0, 98.0, 93.0, 94.0, 93.0, 100.0, 93.0, 91.0, 96.0, 95.0, 97.0, 94.0, 99.0, 94.0, 37.0, 96.0, 96.0, 87.0, 96.0, 86.0, 91.0, 100.0, 96.0, 92.0, 93.0, 96.0, 99.0, 95.0, 95.0, 92.0, 97.0, 100.0, 97.0, 94.0, 95.0, 98.0, 95.0, 99.0, 100.0, 99.0, 97.0, 99.0, 95.0, 100.0, 97.0, 97.0, 97.0, 90.0, 98.0, 97.0, 91.0, 89.0, 90.0, 91.0, 90.0, 99.0, 98.0, 99.0, 98.0, 95.0, 97.0, 99.0, 95.0, 100.0, 97.0, 99.0, 96.0, 98.0, 97.0, 96.0, 98.0, 100.0, 99.0, 91.0, 99.0, 96.0, 97.0, 97.0, 98.0, 99.0, 98.0, 99.0, 100.0, 97.0, 99.0, 99.0, 97.0, 93.0, 95.0, 97.0, 97.0, 96.0, 98.0, 97.0, 97.0, 97.0, 98.0]

# %% [markdown]
# # model들 acc 평균 출력

# %%
from keras.models import load_model

mod = 'summer'

#get test data
X_test = np.load("npset/"+season_mod+"_testX.npy")
y_test = np.load("npset/"+season_mod+"_testY.npy")

#get pow scale form
#powdata, scaler = libs_yeon.get_pow()

print("X_test : ", X_test.shape)
print("y_test : ", y_test.shape)

n_dataset   = y_test.shape[0]
acc_list    = []
acc_model   = []
model       = []

for i in range(n_model):
    model.append(load_model('model/model_'+season_mod+'_'+str(i)+'.h5'))
    acc_model.append(0)
    
print("[ dataset ]")
for i in range(n_dataset):
    #if(i in [2,3,4,5,6,7,8]): continue;
    y = sc_pow.inverse_transform(y_test[i:i+1,:,0])

    for m in range(n_model):
        #print("(model",m+1,")\t",end="")

        pred = model[m].predict([X_test[i:i+1]])
        pred[pred<0] = 0
        pred = pred[:,:,0]
        pred = sc_pow.inverse_transform(pred)
        pred = np.sum(pred)

        target      = round(np.sum(y), 2)
        error       = round(np.abs(target-pred), 2)
        error_rate  = np.min([round(error/target, 2),1])
        acc_rate    = round((1.0-error_rate)*100, 2)
        acc_list.append(acc_rate)
        acc_model[m] += acc_rate
                 
        #print("   pred: ",pred," | target: ",target," | error: ",error," | err rate: ",error_rate," | acc: ",acc_rate,sep="")
        
    #print("acc rate: ",np.mean(acc_list[-n_model:]),sep='')
    print(np.mean(acc_list[-n_model:]), " / ",sep='', end='')
        
print("\n----------------------------------------------")
print("mean(acc rate): ",np.mean(acc_list),sep='')
print("----------------------------------------------")
print("[ model ]")
for i in range(n_model):
    acc_model[i] = round(acc_model[i]/(n_dataset),2)
    print(acc_model[i])
# Out:
# X_test :  (34, 48, 16)
# y_test :  (34, 16, 1)
# c:\users\vislab_phy\anaconda3\envs\py37\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# [ dataset ]
# 62.0 / 61.7 / 82.0 / 82.4 / 42.6 / 80.0 / 92.0 / 71.8 / 89.9 / 87.2 / 87.5 / 54.9 / 77.0 / 50.4 / 44.9 / 64.2 / 64.5 / 89.3 / 91.4 / 86.8 / 47.0 / 82.0 / 74.7 / 76.9 / 19.5 / 63.2 / 70.1 / 92.9 / 71.1 / 80.4 / 81.5 / 82.9 / 74.1 / 73.8 /
# ----------------------------------------------
# mean(acc rate): 72.13529411764706
# ----------------------------------------------
# [ model ]
# 57.12
# 72.38
# 73.88
# 64.53
# 76.82
# 73.35
# 77.09
# 74.76
# 75.85
# 75.56
