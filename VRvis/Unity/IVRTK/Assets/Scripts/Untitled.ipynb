# %%
import pandas as pd
import numpy as np
import os

# %%
path="C:/Users/SoobinYim/IVRTK/Assets/IATK/Datasets/IATK Datasets/Source Data/"

# %%
file_list=os.listdir(path)
file_list
# Out:
# ['auto-mpg.csv',
#  'auto-mpg.csv.meta',
#  'big_bike_path_clean.csv',
#  'big_bike_path_clean.csv.meta',
#  'bike_paths_boston.csv',
#  'bike_paths_boston.csv.meta',
#  'bike_paths_boston.txt',
#  'bike_paths_boston.txt.meta',
#  'cameras.csv',
#  'cameras.csv.meta',
#  'cameras.txt',
#  'cameras.txt.meta',
#  'cereal.csv',
#  'cereal.csv.meta',
#  'dow_jones_index.txt',
#  'dow_jones_index.txt.meta',
#  'WineQualityCombined.csv',
#  'WineQualityCombined.csv.meta',
#  'WineQualityCombined_t_sne.csv',
#  'WineQualityCombined_t_sne.csv.meta']

# %%
data=[]
for i in file_list :
    print(i);
    d=pd.read_csv(path+i,  encoding = 'utf-8')
    d=d.dropna()
    data.append(d)
# Out:
# auto-mpg.csv
# auto-mpg.csv.meta
# big_bike_path_clean.csv
# big_bike_path_clean.csv.meta
# bike_paths_boston.csv
# bike_paths_boston.csv.meta
# bike_paths_boston.txt
# bike_paths_boston.txt.meta
# cameras.csv
# cameras.csv.meta
# cameras.txt
# cameras.txt.meta
# cereal.csv
# cereal.csv.meta
# dow_jones_index.txt
# dow_jones_index.txt.meta
# WineQualityCombined.csv
# WineQualityCombined.csv.meta
# WineQualityCombined_t_sne.csv
# WineQualityCombined_t_sne.csv.meta

# %%
data[2]
# Out:
#          Latitude  Longitude Activity        Date     Time  \
# 348     42.321047 -71.119795  Cycling  30/05/2010  0:50:10
# 349     42.321253 -71.120760  Cycling  30/05/2010  0:50:10
# 350     42.319778 -71.122520  Cycling  30/05/2010  0:50:10
# 351     42.319024 -71.123684  Cycling  30/05/2010  0:50:10
# 352     42.317507 -71.123398  Cycling  30/05/2010  0:50:10
# ...           ...        ...      ...         ...      ...
# 113164  42.337580 -71.143499  Cycling  17/12/2014  0:59:45
# 113165  42.337529 -71.143751  Cycling  17/12/2014  0:59:45
# 113166  42.337450 -71.144140  Cycling  17/12/2014  0:59:45
# 113167  42.337390 -71.144460  Cycling  17/12/2014  0:59:45
# 113168  42.337250 -71.145100  Cycling  17/12/2014  0:59:45
#
#                                    Route  \
# 348     066ba4fdef15455d41fb08b49718d603
# 349     066ba4fdef15455d41fb08b49718d603
# 350     066ba4fdef15455d41fb08b49718d603
# 351     066ba4fdef15455d41fb08b49718d603
# 352     066ba4fdef15455d41fb08b49718d603
# ...
