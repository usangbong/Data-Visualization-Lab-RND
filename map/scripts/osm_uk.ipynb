# %%
import csv
import json
from OSMPythonTools.overpass import Overpass

# %%
overpass = Overpass()
region_list = []
type_list = []
regions = {}

# %%
# 데이터셋에서 지역 정보 가져옴
with open('./data/hidden/UK Coronavirus Cases 1112.csv') as csv_file:
  next(csv_file)
  reader = csv.reader(csv_file)
  for row in reader:
    region_name = row[0]
    region_postcode = row[1]
    region_type = row[2]

    if region_type not in type_list:
      type_list.append(region_type)
      regions[region_type] = []
    if region_name not in region_list:
      region_list.append(region_name)
      regions[region_type].append({
        'name': region_name,
        'type': region_type,
        'postcode': region_postcode
      })
# Out:
# ['Adur',
#  'Allerdale',
#  'Amber Valley',
#  'Arun',
#  'Ashfield',
#  'Ashford',
#  'Aylesbury Vale',
#  'Babergh',
#  'Barking and Dagenham',
#  'Barnet',
#  'Barnsley',
#  'Barrow-in-Furness',
#  'Basildon',
#  'Basingstoke and Deane',
#  'Bassetlaw',
#  'Bath and North East Somerset',
#  'Bedford',
#  'Bexley',
#  'Birmingham',
#  'Blaby',
#  'Blackburn with Darwen',
#  'Blackpool',
#  'Bolsover',
#  'Bolton',
#  'Boston',
#  'Bournemouth, Christchurch and Poole',
#  'Bracknell Forest',
#  'Bradford',
#  'Braintree',
#  'Breckland',
#  'Brent',
#  'Brentwood',
#  'Brighton and Hove',
#  'Bristol, City of',
#  'Broadland',
#  'Bromley',
#  'Bromsgrove',
#  'Broxbourne',
#  'Broxtowe',
#  'Burnley',
#  'Bury',
#  'Calderdale',
#  'Cambridge',
#  'Camden',
#  'Cannock Chase',
#  'Canterbury',
#  'Carlisle',
#  'Castle Point',
#  'Central Bedfordshire',
#  'Charnwood',
#  'Chelmsford',
#  'Cheltenham',
#  'Cherwell',
#  'Cheshire East',
#  'Cheshire West and Chester',
#  'Chesterfield',
#  'Chichester',
#  'Chiltern',
#  'Chorley',
#  'Colchester',
#  'Copeland',
#  'Corby',
#  'Cornwall and Isles of Scilly',
#  'Cotswold',
#  'County Durham',
#  'Coventry',
#  'Craven',
#  'Crawley',
#  'Croydon',
#  'Dacorum',
#  'Darlington',
#  'Dartford',
#  'Daventry',
#  'Derby',
#  'Derbyshire Dales',
#  'Doncaster',
#  'Dorset',
#  'Dover',
#  'Dudley',
#  'Ealing',
#  'East Cambridgeshire',
#  'East Devon',
#  'East Hampshire',
#  'East Hertfordshire',
#  'East Lindsey',
#  'East Northamptonshire',
#  'East Riding of Yorkshire',
#  'East Staffordshire',
#  'East Suffolk',
#  'Eastbourne',
#  'Eastleigh',
#  'Eden',
#  'Elmbridge',
#  'Enfield',
#  'Epping Forest',
#  'Epsom and Ewell',
#  'Erewash',
#  'Exeter',
#  'Fareham',
#  'Fenland',
#  'Folkestone and Hythe',
#  'Forest of Dean',
#  'Fylde',
#  'Gateshead',
#  'Gedling',
#  'Gloucester',
#  'Gosport',
#  'Gravesham',
#  'Great Yarmouth',
#  'Greenwich',
#  'Guildford',
#  'Hackney and City of London',
#  'Halton',
#  'Hambleton',
#  'Hammersmith and Fulham',
#  'Harborough',
#  'Haringey',
#  'Harlow',
#  'Harrogate',
#  'Harrow',
#  'Hart',
#  'Hartlepool',
#  'Hastings',
#  'Havant',
#  'Havering',
#  'Herefordshire, County of',
#  'Hertsmere',
#  'High Peak',
#  'Hillingdon',
#  'Hinckley and Bosworth',
#  'Horsham',
#  'Hounslow',
#  'Huntingdonshire',
#  'Hyndburn',
#  'Ipswich',
#  'Isle of Wight',
#  'Islington',
#  'Kensington and Chelsea',
#  'Kettering',
#  "King's Lynn and West Norfolk",
#  'Kingston upon Hull, City of',
#  'Kingston upon Thames',
#  'Kirklees',
#  'Knowsley',
#  'Lambeth',
#  'Lancaster',
#  'Leeds',
#  'Leicester',
#  'Lewes',
#  'Lewisham',
#  'Lichfield',
#  'Lincoln',
#  'Liverpool',
#  'Luton',
#  'Maidstone',
#  'Maldon',
#  'Malvern Hills',
#  'Manchester',
#  'Mansfield',
#  'Medway',
#  'Melton',
#  'Mendip',
#  'Merton',
#  'Mid Devon',
#  'Mid Suffolk',
#  'Mid Sussex',
#  'Middlesbrough',
#  'Milton Keynes',
#  'Mole Valley',
#  'New Forest',
#  'Newark and Sherwood',
#  'Newcastle upon Tyne',
#  'Newcastle-under-Lyme',
#  'Newham',
#  'North Devon',
#  'North East Derbyshire',
#  'North East Lincolnshire',
#  'North Hertfordshire',
#  'North Kesteven',
#  'North Lincolnshire',
#  'North Norfolk',
#  'North Somerset',
#  'North Tyneside',
#  'North Warwickshire',
#  'North West Leicestershire',
#  'Northampton',
#  'Northumberland',
#  'Norwich',
#  'Nottingham',
#  'Nuneaton and Bedworth',
#  'Oadby and Wigston',
#  'Oldham',
#  'Oxford',
#  'Pendle',
#  'Peterborough',
#  'Plymouth',
#  'Portsmouth',
#  'Preston',
#  'Reading',
#  'Redbridge',
#  'Redcar and Cleveland',
#  'Redditch',
#  'Reigate and Banstead',
#  'Ribble Valley',
#  'Richmond upon Thames',
#  'Richmondshire',
#  'Rochdale',
#  'Rochford',
#  'Rossendale',
#  'Rother',
#  'Rotherham',
#  'Rugby',
#  'Runnymede',
#  'Rushcliffe',
#  'Rushmoor',
#  'Rutland',
#  'Ryedale',
#  'Salford',
#  'Sandwell',
#  'Scarborough',
#  'Sedgemoor',
#  'Sefton',
#  'Selby',
#  'Sevenoaks',
#  'Sheffield',
#  'Shropshire',
#  'Slough',
#  'Solihull',
#  'Somerset West and Taunton',
#  'South Bucks',
#  'South Cambridgeshire',
#  'South Derbyshire',
#  'South Gloucestershire',
#  'South Hams',
#  'South Holland',
#  'South Kesteven',
#  'South Lakeland',
#  'South Norfolk',
#  'South Northamptonshire',
#  'South Oxfordshire',
#  'South Ribble',
#  'South Somerset',
#  'South Staffordshire',
#  'South Tyneside',
#  'Southampton',
#  'Southend-on-Sea',
#  'Southwark',
#  'Spelthorne',
#  'St Albans',
#  'St. Helens',
#  'Stafford',
#  'Staffordshire Moorlands',
#  'Stevenage',
#  'Stockport',
#  'Stockton-on-Tees',
#  'Stoke-on-Trent',
#  'Stratford-on-Avon',
#  'Stroud',
#  'Sunderland',
#  'Surrey Heath',
#  'Sutton',
#  'Swale',
#  'Swindon',
#  'Tameside',
#  'Tamworth',
#  'Tandridge',
#  'Teignbridge',
#  'Telford and Wrekin',
#  'Tendring',
#  'Test Valley',
#  'Tewkesbury',
#  'Thanet',
#  'Three Rivers',
#  'Thurrock',
#  'Tonbridge and Malling',
#  'Torbay',
#  'Torridge',
#  'Tower Hamlets',
#  'Trafford',
#  'Tunbridge Wells',
#  'Uttlesford',
#  'Vale of White Horse',
#  'Wakefield',
#  'Walsall',
#  'Waltham Forest',
#  'Wandsworth',
#  'Warrington',
#  'Warwick',
#  'Watford',
#  'Waverley',
#  'Wealden',
#  'Wellingborough',
#  'Welwyn Hatfield',
#  'West Berkshire',
#  'West Devon',
#  'West Lancashire',
#  'West Lindsey',
#  'West Oxfordshire',
#  'West Suffolk',
#  'Westminster',
#  'Wigan',
#  'Wiltshire',
#  'Winchester',
#  'Windsor and Maidenhead',
#  'Wirral',
#  'Woking',
#  'Wokingham',
#  'Wolverhampton',
#  'Worcester',
#  'Worthing',
#  'Wychavon',
#  'Wycombe',
#  'Wyre',
#  'Wyre Forest',
#  'York',
#  'England',
#  'East Midlands',
#  'East of England',
#  'London',
#  'North East',
#  'North West',
#  'South East',
#  'South West',
#  'West Midlands',
#  'Yorkshire and The Humber',
#  'Buckinghamshire',
#  'Cambridgeshire',
#  'Cumbria',
#  'Derbyshire',
#  'Devon',
#  'East Sussex',
#  'Essex',
#  'Gloucestershire',
#  'Hampshire',
#  'Hertfordshire',
#  'Kent',
#  'Lancashire',
#  'Leicestershire',
#  'Lincolnshire',
#  'Norfolk',
#  'North Yorkshire',
#  'Northamptonshire',
#  'Nottinghamshire',
#  'Oxfordshire',
#  'Somerset',
#  'Staffordshire',
#  'Suffolk',
#  'Surrey',
#  'Warwickshire',
#  'West Sussex',
#  'Worcestershire']

# %%
# 지역에 해당하는 OSM 데이터
for region_type in type_list:
  geodata = {
    'type': 'FeatureCollection',
    'features': []
  }
  for index, region in enumerate(regions[region_type]):
    osm = overpass.query(f'\
        area["ISO3166-1:alpha2"="GB"];\
        relation(area)["ref:gss"="{region['postcode']}"];\
        out geom;
    ')
    osm = nominatim.query(f"{region['postcode']}, England")
    osm = osm.toJSON()[0]
    feature = {
      'type': 'Feature',
      'geometry': {
        'type': 'Point',
        'coordinates': [float(osm['lon']), float(osm['lat'])]
      },
      'properties': {
        'osmid': osm['osm_id'],
        'cell_id': index,
        'name': region['name'],
        'type': region['type'],
        'postcode': region['postcode']
      }
    }
    geodata['features'].append(feature)
# Out:
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [nominatim] downloading data: search
# [{'place_id': 234631496,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 114656,
#   'boundingbox': ['50.8161082', '50.874745', '-0.3715427', '-0.2153222'],
#   'lat': '50.845221249999994',
#   'lon': '-0.2939300331646212',
#   'display_name': 'Adur, West Sussex, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6938780776692448,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Adur'},
#  {'place_id': 303658820,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 182132,
#   'boundingbox': ['54.4541025', '54.9636733', '-3.5800622', '-2.9829942'],
#   'lat': '54.70888095',
#   'lon': '-3.252788011003595',
#   'display_name': 'Allerdale, Cumbria, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7536874052811474,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Allerdale'},
#  {'place_id': 235416414,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 141905,
#   'boundingbox': ['52.924187', '53.1339433', '-1.6100994', '-1.3074469'],
#   'lat': '53.029038400000005',
#   'lon': '-1.4625031096700565',
#   'display_name': 'Amber Valley, Derbyshire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8297961884202653,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Amber Valley'},
#  {'place_id': 235299335,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 114663,
#   'boundingbox': ['50.7563876', '50.9058787', '-0.7648267', '-0.3635171'],
#   'lat': '50.8312375',
#   'lon': '-0.5667058666407475',
#   'display_name': 'Arun, West Sussex, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5873340667019618,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Arun'},
#  {'place_id': 235426901,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 154043,
#   'boundingbox': ['53.0080617', '53.1714343', '-1.3445928', '-1.1642542'],
#   'lat': '53.089773750000006',
#   'lon': '-1.2518767461557148',
#   'display_name': 'Ashfield, Nottinghamshire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6568437919960062,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Ashfield'},
#  {'place_id': 235785707,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 2068847,
#   'boundingbox': ['50.9894944', '51.2702434', '0.5903385', '1.0292101'],
#   'lat': '51.148555',
#   'lon': '0.8722566',
#   'display_name': 'Ashford, Kent, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8464486909434287,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Ashford'},
#  {'place_id': 282175648,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1906838,
#   'boundingbox': ['51.7183992', '52.0815218', '-1.1406964', '-0.5376541'],
#   'lat': '51.899954750000006',
#   'lon': '-0.8782710004180965',
#   'display_name': 'Aylesbury Vale, North Marston, Buckinghamshire, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'historic',
#   'importance': 0.8489809918404536,
#   'name': 'Aylesbury Vale'},
#  {'place_id': 234530318,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 53322,
#   'boundingbox': ['51.9446347', '52.1813005', '0.6268565', '1.2887209'],
#   'lat': '52.06297535',
#   'lon': '0.9122241568513769',
#   'display_name': 'Babergh, Suffolk, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7542833349457883,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Babergh'},
#  {'place_id': 235539931,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 185483,
#   'boundingbox': ['51.5087685', '51.5994365', '0.066649', '0.1901898'],
#   'lat': '51.5541171',
#   'lon': '0.15050434261994267',
#   'display_name': 'London Borough of Barking and Dagenham, London, Greater London, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.963523495604311,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Barking and Dagenham'},
#  {'place_id': 63743375,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 5557467720,
#   'boundingbox': ['51.61309', '51.69309', '-0.2402261', '-0.1602261'],
#   'lat': '51.65309',
#   'lon': '-0.2002261',
#   'display_name': 'Chipping Barnet, Greater London, England, EN5 5SB, United Kingdom',
#   'class': 'place',
#   'type': 'town',
#   'importance': 0.7512631657055138,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_town.p.20.png',
#   'name': 'Barnet'},
#  {'place_id': 235428815,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 106964,
#   'boundingbox': ['53.4382974', '53.6127223', '-1.8225901', '-1.2757101'],
#   'lat': '53.5527719',
#   'lon': '-1.4827755',
#   'display_name': 'Barnsley, Yorkshire and the Humber, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.82059387313743,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Barnsley'},
#  {'place_id': 233320179,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 176965,
#   'boundingbox': ['54.0396284', '54.2184678', '-3.3248213', '-3.1242815'],
#   'lat': '54.1113351',
#   'lon': '-3.2289494',
#   'display_name': 'Barrow-in-Furness, Cumbria, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.85,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Barrow-in-Furness'},
#  {'place_id': 235185604,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 76516,
#   'boundingbox': ['51.5298243', '51.6512393', '0.3750985', '0.5687684'],
#   'lat': '51.5754602',
#   'lon': '0.4757363',
#   'display_name': 'Basildon, Essex, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.710690081410952,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Basildon'},
#  {'place_id': 235315303,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 127249,
#   'boundingbox': ['51.133543', '51.3839153', '-1.4601663', '-0.974813'],
#   'lat': '51.2587797',
#   'lon': '-1.221107318149007',
#   'display_name': 'Basingstoke and Deane, Hampshire, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9220589959875694,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Basingstoke and Deane'},
#  {'place_id': 235416103,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 77270,
#   'boundingbox': ['53.1963741', '53.5024958', '-1.2130282', '-0.747138'],
#   'lat': '53.34945205',
#   'lon': '-0.9616604011939824',
#   'display_name': 'Bassetlaw, Nottinghamshire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7278628547155854,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Bassetlaw'},
#  {'place_id': 235516710,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 81941,
#   'boundingbox': ['51.2731011', '51.4395352', '-2.707888', '-2.2785383'],
#   'lat': '51.35632375',
#   'lon': '-2.486661424502094',
#   'display_name': 'Bath and North East Somerset, South West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.178793346941117,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Bath and North East Somerset'},
#  {'place_id': 105877,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 4085941,
#   'boundingbox': ['52.0963806', '52.1763806', '-0.5075041', '-0.4275041'],
#   'lat': '52.1363806',
#   'lon': '-0.4675041',
#   'display_name': 'Bedford, East of England, England, MK40 1SU, United Kingdom',
#   'class': 'place',
#   'type': 'town',
#   'importance': 0.8212899422682275,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_town.p.20.png',
#   'name': 'Bedford'},
#  {'place_id': 145730,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 27485892,
#   'boundingbox': ['51.4216793', '51.4616793', '0.130488', '0.170488'],
#   'lat': '51.4416793',
#   'lon': '0.150488',
#   'display_name': 'Bexley, London Borough of Bexley, London, Greater London, England, DA5 1LD, United Kingdom',
#   'class': 'place',
#   'type': 'suburb',
#   'importance': 0.6870730099093615,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png',
#   'name': 'Bexley'},
#  {'place_id': 235295061,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 162378,
#   'boundingbox': ['52.381053', '52.6087058', '-2.0336486', '-1.7288578'],
#   'lat': '52.4796992',
#   'lon': '-1.9026911',
#   'display_name': 'Birmingham, West Midlands Combined Authority, West Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9834272656139734,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Birmingham'},
#  {'place_id': 235549808,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 162357,
#   'boundingbox': ['52.4931957', '52.6643832', '-1.3391385', '-1.0594019'],
#   'lat': '52.5731976',
#   'lon': '-1.1646389',
#   'display_name': 'Blaby, Leicestershire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6857002939364222,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Blaby'},
#  {'place_id': 235258017,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 148780,
#   'boundingbox': ['53.6165681', '53.7818047', '-2.5647705', '-2.362643'],
#   'lat': '53.699176949999995',
#   'lon': '-2.4709000953138327',
#   'display_name': 'Blackburn with Darwen, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9606881443638815,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Blackburn with Darwen'},
#  {'place_id': 234870380,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 148603,
#   'boundingbox': ['53.7731016', '53.8759029', '-3.0764221', '-2.9833444'],
#   'lat': '53.824548300000004',
#   'lon': '-3.037319995021968',
#   'display_name': 'Blackpool, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.868381295512646,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Blackpool'},
#  {'place_id': 233107726,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 108323,
#   'boundingbox': ['53.0809659', '53.3129256', '-1.3782668', '-1.1664888'],
#   'lat': '53.228666',
#   'lon': '-1.2912756',
#   'display_name': 'Bolsover, Derbyshire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7191508612432211,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Bolsover'},
#  {'place_id': 234868713,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 146937,
#   'boundingbox': ['53.5228655', '53.6460294', '-2.6286157', '-2.3370404'],
#   'lat': '53.5782863',
#   'lon': '-2.4300367',
#   'display_name': 'Bolton, Greater Manchester, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.838700489869415,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Bolton'},
#  {'place_id': 280522991,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 2776224,
#   'boundingbox': ['52.9560574', '53.0016379', '-0.0602528', '0.0033826'],
#   'lat': '52.9770408',
#   'lon': '-0.0239836',
#   'display_name': 'Boston, Lincolnshire, East Midlands, England, United Kingdom',
#   'class': 'place',
#   'type': 'town',
#   'importance': 0.8072557220197782,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_town.p.20.png',
#   'name': 'Boston'},
#  {'place_id': 276073366,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 130884,
#   'boundingbox': ['50.7089425', '50.7803889', '-1.9376143', '-1.7405372'],
#   'lat': '50.744673199999994',
#   'lon': '-1.8579577396350433',
#   'display_name': 'Bournemouth, Queens Park, Bournemouth, Bournemouth, Christchurch and Poole, South West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'historic',
#   'importance': 1.1742860930499666,
#   'name': 'Bournemouth, Christchurch and Poole'},
#  {'place_id': 235207426,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 113682,
#   'boundingbox': ['51.3319362', '51.4687318', '-0.8373663', '-0.6305698'],
#   'lat': '51.4002688',
#   'lon': '-0.7417888011413043',
#   'display_name': 'Bracknell Forest, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8539727184858658,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Bracknell Forest'},
#  {'place_id': 234826110,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 118323,
#   'boundingbox': ['53.7243414', '53.963151', '-2.0612483', '-1.6403301'],
#   'lat': '53.7944229',
#   'lon': '-1.7519186',
#   'display_name': 'Bradford, West Yorkshire, Yorkshire and the Humber, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8865366261116545,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Bradford'},
#  {'place_id': 234693934,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 52187,
#   'boundingbox': ['51.7504098', '52.0870262', '0.3796085', '0.782257'],
#   'lat': '51.8780637',
#   'lon': '0.5537161',
#   'display_name': 'Braintree, Essex, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7586843760767399,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Braintree'},
#  {'place_id': 235272273,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1168814,
#   'boundingbox': ['52.3695004', '52.8111013', '0.5304996', '1.1082995'],
#   'lat': '52.5903063',
#   'lon': '0.7590357662336945',
#   'display_name': 'Breckland, Norfolk, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7319935340596175,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Breckland'},
#  {'place_id': 101130980,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 59456537,
#   'boundingbox': ['50.3324465', '50.3344619', '-4.5113159', '-4.5109878'],
#   'lat': '50.3334685',
#   'lon': '-4.5113159',
#   'display_name': 'Brent, Polperro, Cornwall, South West England, England, PL13 2JJ, United Kingdom',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.41000000000000003,
#   'name': 'Brent'},
#  {'place_id': 233059882,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 76515,
#   'boundingbox': ['51.5642976', '51.7170079', '0.1756759', '0.4125337'],
#   'lat': '51.6201654',
#   'lon': '0.3018662',
#   'display_name': 'Brentwood, Essex, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7590654776650234,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Brentwood'},
#  {'place_id': 295310349,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 114085,
#   'boundingbox': ['50.7982097', '50.8923741', '-0.2450771', '-0.0160307'],
#   'lat': '50.845221249999994',
#   'lon': '-0.14975850541139246',
#   'display_name': 'Brighton and Hove, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.004654308718293,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Brighton and Hove'},
#  {'place_id': 236160893,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 5746665,
#   'boundingbox': ['51.3972838', '51.5444317', '-2.7183704', '-2.5104192'],
#   'lat': '51.4538022',
#   'lon': '-2.5972985',
#   'display_name': 'Bristol, City of Bristol, South West England, England, United Kingdom',
#   'class': 'place',
#   'type': 'city',
#   'importance': 1.14975968539103,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_city.p.20.png',
#   'name': 'Bristol, City of'},
#  {'place_id': 235325289,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1168615,
#   'boundingbox': ['52.5552106', '52.8305868', '0.9903484', '1.6780183'],
#   'lat': '52.6928977',
#   'lon': '1.2564875194162244',
#   'display_name': 'Broadland, Norfolk, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7463071198400415,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Broadland'},
#  {'place_id': 132919,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 26049431,
#   'boundingbox': ['51.3628046', '51.4428046', '-0.0251858', '0.0548142'],
#   'lat': '51.4028046',
#   'lon': '0.0148142',
#   'display_name': 'Bromley, Greater London, England, BR1 1EY, United Kingdom',
#   'class': 'place',
#   'type': 'town',
#   'importance': 0.7951277956683381,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_town.p.20.png',
#   'name': 'Bromley'},
#  {'place_id': 235455967,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1875338,
#   'boundingbox': ['52.2780457', '52.4452691', '-2.1677834', '-1.8454812'],
#   'lat': '52.3353816',
#   'lon': '-2.0597449',
#   'display_name': 'Bromsgrove, Worcestershire, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7370827450740329,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Bromsgrove'},
#  {'place_id': 235804274,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 2677978,
#   'boundingbox': ['51.6808751', '51.7806237', '-0.1142041', '0.0145267'],
#   'lat': '51.7465723',
#   'lon': '-0.0190782',
#   'display_name': 'Broxbourne, Hertfordshire, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7044632229559893,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Broxbourne'},
#  {'place_id': 4190613,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 469813524,
#   'boundingbox': ['52.9599943', '52.9999943', '-1.2345858', '-1.1945858'],
#   'lat': '52.9799943',
#   'lon': '-1.2145858',
#   'display_name': 'Broxtowe, Wollaton, East Midlands, England, NG8 6FY, United Kingdom',
#   'class': 'place',
#   'type': 'suburb',
#   'importance': 0.56,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png',
#   'name': 'Broxtowe'},
#  {'place_id': 235422731,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 149101,
#   'boundingbox': ['53.722997', '53.8252624', '-2.3423051', '-2.1122772'],
#   'lat': '53.7907262',
#   'lon': '-2.2439196',
#   'display_name': 'Burnley, Lancashire, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8147911936149229,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Burnley'},
#  {'place_id': 117015,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 21409982,
#   'boundingbox': ['52.2060367', '52.2860367', '0.6725173', '0.7525173'],
#   'lat': '52.2460367',
#   'lon': '0.7125173',
#   'display_name': 'Bury St Edmunds, Suffolk, East of England, England, IP33 1BZ, United Kingdom',
#   'class': 'place',
#   'type': 'town',
#   'importance': 0.7794672150434407,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_town.p.20.png',
#   'name': 'Bury'},
#  {'place_id': 235528418,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 118327,
#   'boundingbox': ['53.6153034', '53.8256213', '-2.1732936', '-1.7272229'],
#   'lat': '53.720474800000005',
#   'lon': '-1.9622886329676708',
#   'display_name': 'Calderdale, West Yorkshire, Yorkshire and the Humber, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7541463232568195,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Calderdale'},
#  {'place_id': 235555859,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 295355,
#   'boundingbox': ['52.1579417', '52.2372296', '0.0686389', '0.184552'],
#   'lat': '52.2034823',
#   'lon': '0.1235817',
#   'display_name': 'Cambridge, Cambridgeshire, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9527670135653464,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Cambridge'},
#  {'place_id': 3574760,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 399607277,
#   'boundingbox': ['51.5023045', '51.5823045', '-0.1795604', '-0.0995604'],
#   'lat': '51.5423045',
#   'lon': '-0.1395604',
#   'display_name': 'Camden Town, Greater London, England, NW1 9PJ, United Kingdom',
#   'class': 'place',
#   'type': 'town',
#   'importance': 0.776456293514185,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_town.p.20.png',
#   'name': 'Camden'},
#  {'place_id': 234739793,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 168500,
#   'boundingbox': ['52.639637', '52.7741798', '-2.0546383', '-1.9108121'],
#   'lat': '52.7069197',
#   'lon': '-1.9784347546729857',
#   'display_name': 'Cannock Chase, Staffordshire, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.75,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Cannock Chase'},
#  {'place_id': 235543051,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 448590,
#   'boundingbox': ['51.1771875', '51.3825395', '0.9372021', '1.2500695'],
#   'lat': '51.2800275',
#   'lon': '1.0802533',
#   'display_name': 'Canterbury, Kent, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8990018713112681,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Canterbury'},
#  {'place_id': 235322605,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 182118,
#   'boundingbox': ['54.7761506', '55.1889788', '-3.1828094', '-2.4823325'],
#   'lat': '54.8948478',
#   'lon': '-2.9362311',
#   'display_name': 'Carlisle, Cumbria, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8264793805329572,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Carlisle'},
#  {'place_id': 235184924,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 76488,
#   'boundingbox': ['51.5007502', '51.5882672', '0.5157342', '0.7041561'],
#   'lat': '51.5444908',
#   'lon': '0.5839688775147929',
#   'display_name': 'Castle Point, Essex, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8095529004990607,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Castle Point'},
#  {'place_id': 235550506,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 161643,
#   'boundingbox': ['51.8050872', '52.1909132', '-0.7021802', '-0.1439574'],
#   'lat': '51.99803275',
#   'lon': '-0.47915142854055964',
#   'display_name': 'Central Bedfordshire, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8649100354799661,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Central Bedfordshire'},
#  {'place_id': 235484204,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 172008,
#   'boundingbox': ['52.6538477', '52.8247029', '-1.3350747', '-0.9472461'],
#   'lat': '52.7392639',
#   'lon': '-1.1370832780406597',
#   'display_name': 'Charnwood, Leicestershire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6418593501289871,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Charnwood'},
#  {'place_id': 235492109,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 52189,
#   'boundingbox': ['51.6166234', '51.8574836', '0.3321643', '0.6489798'],
#   'lat': '51.7345436',
#   'lon': '0.4724544',
#   'display_name': 'Chelmsford, Essex, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8284688170190069,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Chelmsford'},
#  {'place_id': 235057208,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 184094,
#   'boundingbox': ['51.8583342', '51.9388732', '-2.1430198', '-2.0102235'],
#   'lat': '51.8995685',
#   'lon': '-2.0711559',
#   'display_name': 'Cheltenham, Gloucestershire, South West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8423037748297107,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Cheltenham'},
#  {'place_id': 235467773,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 394565,
#   'boundingbox': ['51.7809593', '52.1684702', '-1.5228401', '-1.047144'],
#   'lat': '51.974716900000004',
#   'lon': '-1.226266289998037',
#   'display_name': 'Cherwell, Oxfordshire, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.722525597452115,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Cherwell'},
#  {'place_id': 233265380,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 153487,
#   'boundingbox': ['52.9472122', '53.3874616', '-2.7529286', '-1.9747864'],
#   'lat': '53.1673422',
#   'lon': '-2.2928802778613573',
#   'display_name': 'Cheshire East, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8842753939224641,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Cheshire East'},
#  {'place_id': 235288947,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 153488,
#   'boundingbox': ['52.9829101', '53.3446834', '-3.128278', '-2.3463547'],
#   'lat': '53.16379785',
#   'lon': '-2.7285361135416943',
#   'display_name': 'Cheshire West and Chester, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.0827547210662574,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Cheshire West and Chester'},
#  {'place_id': 234953676,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 138738,
#   'boundingbox': ['53.2124229', '53.2990253', '-1.4842881', '-1.3013021'],
#   'lat': '53.2352134',
#   'lon': '-1.4264097',
#   'display_name': 'Chesterfield, Derbyshire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8098280518850378,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Chesterfield'},
#  {'place_id': 235751328,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 2991708,
#   'boundingbox': ['50.8258875', '50.8631538', '-0.8110582', '-0.7539465'],
#   'lat': '50.8364862',
#   'lon': '-0.7791721',
#   'display_name': 'Chichester, West Sussex, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8343280757250848,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Chichester'},
#  {'place_id': 282175652,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1908837,
#   'boundingbox': ['51.5893865', '51.7684649', '-0.7621389', '-0.5051296'],
#   'lat': '51.67893035',
#   'lon': '-0.6295205849333023',
#   'display_name': 'Chiltern, Amersham, Buckinghamshire, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'historic',
#   'importance': 0.7162606679842716,
#   'name': 'Chiltern'},
#  {'place_id': 234995271,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 148744,
#   'boundingbox': ['53.5935869', '53.7513923', '-2.8242508', '-2.5113254'],
#   'lat': '53.6531915',
#   'lon': '-2.6294313',
#   'display_name': 'Chorley, Lancashire, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.66,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Chorley'},
#  {'place_id': 235501893,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 76493,
#   'boundingbox': ['51.7657055', '51.9771532', '0.6993788', '1.0268034'],
#   'lat': '51.8896903',
#   'lon': '0.8994651',
#   'display_name': 'Colchester, Essex, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8437415510038926,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Colchester'},
#  {'place_id': 234811572,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 178136,
#   'boundingbox': ['54.1678441', '54.607344', '-3.6406213', '-3.1141407'],
#   'lat': '54.3876165',
#   'lon': '-3.331125339681134',
#   'display_name': 'Copeland, Cumbria, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7229062805609389,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Copeland'},
#  {'place_id': 235391787,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 310064,
#   'boundingbox': ['52.4544608', '52.5586208', '-0.8079457', '-0.596403'],
#   'lat': '52.48763',
#   'lon': '-0.701543',
# ...
#   'importance': 0.41000000000000003,
#   'name': 'North West'},
#  {'place_id': 235278136,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 151304,
#   'boundingbox': ['50.5746776', '52.1963233', '-1.9572806', '1.4517689'],
#   'lat': '51.451019099999996',
#   'lon': '-0.9934914404975159',
#   'display_name': 'South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.0139902057569206,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'South East'},
#  {'place_id': 91834601,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 24598760,
#   'boundingbox': ['51.4737193', '51.4744753', '-0.1251739', '-0.1234982'],
#   'lat': '51.4742479',
#   'lon': '-0.12433969996478875',
#   'display_name': 'Stockwell Bus Garage, Binfield Road, Stockwell, London Borough of Lambeth, London, Greater London, England, SW4 6ST, United Kingdom',
#   'class': 'amenity',
#   'type': 'bus_garage',
#   'importance': 0.41912463163390334,
#   'name': 'South West'},
#  {'place_id': 232989993,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 57517,
#   'boundingbox': ['52.3477247', '52.6627172', '-2.2068817', '-1.4239574'],
#   'lat': '52.5050033',
#   'lon': '-1.964396123331272',
#   'display_name': 'West Midlands, West Midlands Combined Authority, West Midlands, England, B36 8BS, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9721184050393166,
#   'name': 'West Midlands'},
#  {'place_id': 234999472,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 151012,
#   'boundingbox': ['53.3015483', '54.5621437', '-2.564739', '0.1498318'],
#   'lat': '53.9318994',
#   'lon': '-1.1664716608886017',
#   'display_name': 'Yorkshire and the Humber, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.1589233731133919,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Yorkshire and The Humber'},
#  {'place_id': 235192438,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 87460,
#   'boundingbox': ['51.4854689', '52.1963233', '-1.1406964', '-0.4766156'],
#   'lat': '51.840894',
#   'lon': '-0.8998073587480795',
#   'display_name': 'Buckinghamshire, Waddesdon, Buckinghamshire, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9065495955819974,
#   'name': 'Buckinghamshire'},
#  {'place_id': 235558515,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 180837,
#   'boundingbox': ['52.005779', '52.7399783', '-0.4999138', '0.514455'],
#   'lat': '52.333333',
#   'lon': '0.083333',
#   'display_name': 'Cambridgeshire, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8445272287500889,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Cambridgeshire'},
#  {'place_id': 303658819,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 88065,
#   'boundingbox': ['54.0396284', '55.1889788', '-3.6406213', '-2.1589939'],
#   'lat': '54.6143136',
#   'lon': '-2.9420983340597866',
#   'display_name': 'Cumbria, North West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9238592926788941,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Cumbria'},
#  {'place_id': 235273432,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 88077,
#   'boundingbox': ['52.6965185', '53.5404524', '-2.034097', '-1.1664888'],
#   'lat': '53.1185033',
#   'lon': '-1.5566179305872214',
#   'display_name': 'Derbyshire, England, DE21 7BD, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9109006985735364,
#   'name': 'Derbyshire'},
#  {'place_id': 295976485,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 57538,
#   'boundingbox': ['50.2014643', '51.2468388', '-4.6806562', '-2.8866407'],
#   'lat': '50.724165',
#   'lon': '-3.660795843955193',
#   'display_name': 'Devon, England, TQ3 1PT, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9413286280614067,
#   'name': 'Devon'},
#  {'place_id': 295310351,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 2126747,
#   'boundingbox': ['50.7334349', '51.147457', '-0.2450771', '0.8678559'],
#   'lat': '50.9404266',
#   'lon': '0.3699977891068864',
#   'display_name': 'East Sussex, South East, England, TN21 8TP, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9627970925422952,
#   'name': 'East Sussex'},
#  {'place_id': 235139804,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 62162,
#   'boundingbox': ['51.4482784', '52.0926625', '-0.0197697', '1.2965922'],
#   'lat': '51.77046785',
#   'lon': '0.46466977412300386',
#   'display_name': 'Essex, England, CM3 6AA, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9337328574912976,
#   'name': 'Essex'},
#  {'place_id': 289280742,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 85103,
#   'boundingbox': ['51.5775306', '52.1125797', '-2.6875372', '-1.615202'],
#   'lat': '51.8333313',
#   'lon': '-2.1666674',
#   'display_name': 'Gloucestershire, South West England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9123427486910208,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Gloucestershire'},
#  {'place_id': 235544197,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 2698314,
#   'boundingbox': ['50.7057404', '51.3839153', '-1.9572806', '-0.7293437'],
#   'lat': '51.04483545',
#   'lon': '-1.2434093603442158',
#   'display_name': 'Hampshire, England, SO40 9DS, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9350680492932151,
#   'name': 'Hampshire'},
#  {'place_id': 234534864,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 57032,
#   'boundingbox': ['51.5995828', '52.0805364', '-0.7457892', '0.195567'],
#   'lat': '51.840052299999996',
#   'lon': '-0.09785519224523963',
#   'display_name': 'Hertfordshire, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9228669995961313,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Hertfordshire'},
#  {'place_id': 235353926,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 172385,
#   'boundingbox': ['50.9104763', '51.4822724', '0.0335249', '1.4517689'],
#   'lat': '51.2474823',
#   'lon': '0.7105077',
#   'display_name': 'Kent, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9631668604105881,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Kent'},
#  {'place_id': 235187502,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 118082,
#   'boundingbox': ['53.4827602', '54.2395575', '-3.0845488', '-2.0450727'],
#   'lat': '53.8611703',
#   'lon': '-2.5650887919475496',
#   'display_name': 'Lancashire, England, PR7 4DF, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9526028209470422,
#   'name': 'Lancashire'},
#  {'place_id': 235071327,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 189890,
#   'boundingbox': ['52.392171', '52.9776581', '-1.5975472', '-0.6641111'],
#   'lat': '52.666667',
#   'lon': '-1',
#   'display_name': 'Leicestershire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8844140623772802,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Leicestershire'},
#  {'place_id': 278311821,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1916530,
#   'boundingbox': ['52.6402179', '53.7244601', '-0.9500054', '0.3579713'],
#   'lat': '53.1823034',
#   'lon': '-0.2031208542548153',
#   'display_name': 'Lincolnshire, England, LN10 6XY, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9223737476000039,
#   'name': 'Lincolnshire'},
#  {'place_id': 235492902,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 57397,
#   'boundingbox': ['52.3553354', '52.9916398', '0.1536217', '1.7457818'],
#   'lat': '52.666667',
#   'lon': '1',
#   'display_name': 'Norfolk, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9219216119553134,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Norfolk'},
#  {'place_id': 235807527,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 3123501,
#   'boundingbox': ['53.6210944', '54.6479755', '-2.564739', '-0.2123533'],
#   'lat': '54.13453275',
#   'lon': '-1.498628491239545',
#   'display_name': 'North Yorkshire, England, YO10 3WF, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9904919390090774,
#   'name': 'North Yorkshire'},
#  {'place_id': 235498960,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 63375,
#   'boundingbox': ['51.9772678', '52.6436008', '-1.33236', '-0.3416081'],
#   'lat': '52.25',
#   'lon': '-0.833333',
#   'display_name': 'Northamptonshire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8953335027270082,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Northamptonshire'},
#  {'place_id': 235320528,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 181040,
#   'boundingbox': ['52.7894181', '53.5024958', '-1.3445928', '-0.6662631'],
#   'lat': '53.1459288',
#   'lon': '-1.0214971168122484',
#   'display_name': 'Nottinghamshire, East Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8926383991374569,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Nottinghamshire'},
#  {'place_id': 234769948,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 76155,
#   'boundingbox': ['51.4594132', '52.1684702', '-1.7195008', '-0.870066'],
#   'lat': '51.833333',
#   'lon': '-1.25',
#   'display_name': 'Oxfordshire, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9130929470928735,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Oxfordshire'},
#  {'place_id': 235590963,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 3125930,
#   'boundingbox': ['50.8208387', '51.5026877', '-3.8398029', '-2.2444018'],
#   'lat': '51.161750850000004',
#   'lon': '-3.0753867062227487',
#   'display_name': 'Somerset, England, BS48 4TF, United Kingdom',
#   'class': 'boundary',
#   'type': 'ceremonial',
#   'importance': 0.9326944711819499,
#   'name': 'Somerset'},
#  {'place_id': 235493072,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 195444,
#   'boundingbox': ['52.4232438', '53.226224', '-2.4708418', '-1.5853561'],
#   'lat': '52.824694199999996',
#   'lon': '-2.0074546723348115',
#   'display_name': 'Staffordshire, West Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8971837528873898,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Staffordshire'},
#  {'place_id': 234673988,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 28595,
#   'boundingbox': ['51.9317644', '52.5502218', '0.3399748', '1.7689121'],
#   'lat': '52.241001350000005',
#   'lon': '1.0466830312565236',
#   'display_name': 'Suffolk, East of England, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9123813533896664,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Suffolk'},
#  {'place_id': 301938883,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 57582,
#   'boundingbox': ['51.0714966', '51.4715643', '-0.848929', '0.0582163'],
#   'lat': '51.2715316',
#   'lon': '-0.3414523511290909',
#   'display_name': 'Surrey, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9426222700750434,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Surrey'},
#  {'place_id': 235399768,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 57516,
#   'boundingbox': ['51.9553939', '52.6872437', '-1.9620067', '-1.1721264'],
#   'lat': '52.32130635',
#   'lon': '-1.5536905536661392',
#   'display_name': 'Warwickshire, West Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8951945553486134,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Warwickshire'},
#  {'place_id': 295310348,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 113757,
#   'boundingbox': ['50.7217802', '51.167301', '-0.9575973', '0.0445498'],
#   'lat': '51',
#   'lon': '-0.416667',
#   'display_name': 'West Sussex, South East, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9655616915330515,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'West Sussex'},
#  {'place_id': 235507008,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 57581,
#   'boundingbox': ['51.9665565', '52.4553027', '-2.6632101', '-1.7574091'],
#   'lat': '52.2109495',
#   'lon': '-2.156955513242221',
#   'display_name': 'Worcestershire, West Midlands, England, United Kingdom',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8881170306360969,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png',
#   'name': 'Worcestershire'}]
