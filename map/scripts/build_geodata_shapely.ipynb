# %%
from shapely.ops import voronoi_diagram
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-d679c671ffc0> in <module>
# ----> 1 from shapely.ops import voronoi_diagram
#
# ImportError: cannot import name 'voronoi_diagram' from 'shapely.ops' (C:\Users\admin\.conda\envs\covid19\lib\site-packages\shapely\ops.py)
