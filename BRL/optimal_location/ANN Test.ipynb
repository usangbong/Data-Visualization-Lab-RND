# %%
from keras import datasets
from keras.utils import np_utils

# %%
from keras import layers, models

def ANN(Nin, Nh, Nout):
    model = models.Sequential()
    model.add(layers.Dense(Nh, activation = 'relu', input_shape = (Nin,)))
    model.add(layers.Dense(Nout), activation = 'softmax')
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                 metrics=['accuracy'])
    return model

# %%
class ANN_class(models.Sequential):
    def __init__(self, Nin, Nh, Nout):
        super().__init__()
        self.add(layers.Dense(Nh, activation='relu', input_shape=(Nin,)))
        self.add(layers.Dense(Nout, activation='softmax'))
        self.compile(loss='categorical_crossentropy', optimizer='adam',
                    metrics=['accuracy'])

# %%
import numpy as np

# %%
def Data_func():
    (x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()
    y_train = np_utils.to_categorical(y_train)
    y_test = np_utils.to_categorical(y_test)
    
    l, w, h = x_train.shape
    x_train = x_train.reshape(-1, w * h)
    x_test = x_test.reshape(-1, w * h)
    
    x_train = x_train / 255.0
    y_train = y_train / 255.0
    
    return(x_train, y_train), (x_test, y_test)

# %%
import matplotlib.pyplot as plt

# %%
def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    
    plt.title('Model Loss')
    
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    
    plt.legend(['Train', 'Test'], loc=0)

# %%
def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    
    plt.title('Model Accuracy')
    
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    
    plt.legend(['Train', 'Test'], loc=0)

# %%
Nin = 784
Nh = 100
number_of_class=10
Nout = number_of_class

# %%
model = ANN_class(Nin, Nh, Nout)
(x_train, y_train), (x_test, y_test) = Data_func()

# %%
history = model.fit(x_train, y_train, epochs=15, batch_size=100, 
                   validation_split=0.2)
# Out:
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001CD8732D4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001CD8732D4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 432/480 [==========================>...] - ETA: 0s - loss: 0.0099 - accuracy: 0.1089WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001CD8FB7C0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001CD8FB7C0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 480/480 [==============================] - 1s 2ms/step - loss: 0.0099 - accuracy: 0.1084 - val_loss: 0.0104 - val_accuracy: 0.0978
# Epoch 2/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0105 - accuracy: 0.0870 - val_loss: 0.0108 - val_accuracy: 0.0887
# Epoch 3/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0164 - accuracy: 0.0962 - val_loss: 0.0098 - val_accuracy: 0.1135
# Epoch 4/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0167 - accuracy: 0.1216 - val_loss: 0.0329 - val_accuracy: 0.0996
# Epoch 5/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0336 - accuracy: 0.1025 - val_loss: 0.0523 - val_accuracy: 0.0999
# Epoch 6/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0423 - accuracy: 0.1042 - val_loss: 0.0479 - val_accuracy: 0.0990
# Epoch 7/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0474 - accuracy: 0.1027 - val_loss: 0.0966 - val_accuracy: 0.0975
# Epoch 8/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0637 - accuracy: 0.1015 - val_loss: 0.0419 - val_accuracy: 0.0393
# Epoch 9/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0590 - accuracy: 0.1011 - val_loss: 0.0601 - val_accuracy: 0.1701
# Epoch 10/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0649 - accuracy: 0.1022 - val_loss: 0.1075 - val_accuracy: 0.0975
# Epoch 11/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0746 - accuracy: 0.1033 - val_loss: 0.1149 - val_accuracy: 0.0975
# Epoch 12/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0860 - accuracy: 0.0993 - val_loss: 0.1136 - val_accuracy: 0.0735
# Epoch 13/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.1005 - accuracy: 0.1021 - val_loss: 0.0605 - val_accuracy: 0.1922
# Epoch 14/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0944 - accuracy: 0.1033 - val_loss: 0.0662 - val_accuracy: 0.1019
# Epoch 15/15
# 480/480 [==============================] - 1s 1ms/step - loss: 0.1001 - accuracy: 0.1010 - val_loss: 0.0906 - val_accuracy: 0.0997

# %%
performance_Test = model.evaluate(x_test, y_test, batch_size=100)
print('Test Lost and Accuracy ->', performance_Test)
# Out:
# 100/100 [==============================] - 0s 1ms/step - loss: 4264.0142 - accuracy: 0.0607
# Test Lost and Accuracy -> [4264.01416015625, 0.06069999933242798]

# %%
plot_loss(history)
plt.show()

# %%
plot_acc(history)
plt.show()

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3075b36c09c8> in <module>
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
print(tf.__version__)
# Out:
# 2.2.0

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt

# %%
mnist = keras.datasets.fashion_mnist
type(mnist)
# Out:
# module

# %%
mnist
# Out:
# <module 'tensorflow.keras.datasets.fashion_mnist' from 'C:\\Users\\vfgtr\\anaconda3\\envs\\learning\\lib\\site-packages\\tensorflow\\keras\\datasets\\fashion_mnist\\__init__.py'>

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
np.max(x_train)
# Out:
# 255

# %%
np.mean(x_train)
# Out:
# 72.94035223214286

# %%
class_name = ['top', 'trouser', 'pullover', 'dress', 'coat', 'sendal',
             'shirt', 'sneaker', 'bag', 'ankle_boot']

plt.figure()
plt.imshow(x_train[0])

# %%
x_train = x_train / 255.0
x_testt = x_test / 255.0

# %%
model = Sequential()
model.add(Flatten(input_shape = (28, 28)))
model.add(Dense(28, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 28)                21980
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                290
# =================================================================
# Total params: 22,270
# Trainable params: 22,270
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3097 - accuracy: 0.8876
# Epoch 2/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3031 - accuracy: 0.8897
# Epoch 3/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2972 - accuracy: 0.8917
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2926 - accuracy: 0.8934
# Epoch 5/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2881 - accuracy: 0.8954
# Epoch 6/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2844 - accuracy: 0.8968
# Epoch 7/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2800 - accuracy: 0.8982
# Epoch 8/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2767 - accuracy: 0.8972
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2727 - accuracy: 0.9004
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2692 - accuracy: 0.9006
# Epoch 11/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2662 - accuracy: 0.9021
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2633 - accuracy: 0.9022
# Epoch 13/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2607 - accuracy: 0.9037
# Epoch 14/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2582 - accuracy: 0.9048
# Epoch 15/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2561 - accuracy: 0.9056
# Epoch 16/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2535 - accuracy: 0.9054
# Epoch 17/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2501 - accuracy: 0.9074
# Epoch 18/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2481 - accuracy: 0.9082
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2468 - accuracy: 0.9085
# Epoch 20/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2434 - accuracy: 0.9094
# Epoch 21/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2425 - accuracy: 0.9097
# Epoch 22/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2413 - accuracy: 0.9101
# Epoch 23/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2378 - accuracy: 0.9107
# Epoch 24/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2352 - accuracy: 0.9121
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2350 - accuracy: 0.9131
# Epoch 26/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2322 - accuracy: 0.9143
# Epoch 27/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2333 - accuracy: 0.9129
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2301 - accuracy: 0.9148
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2271 - accuracy: 0.9163
# Epoch 30/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2267 - accuracy: 0.9166
# Epoch 31/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2248 - accuracy: 0.9168
# Epoch 32/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2253 - accuracy: 0.9156
# Epoch 33/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2232 - accuracy: 0.9164
# Epoch 34/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2227 - accuracy: 0.9183
# Epoch 35/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2206 - accuracy: 0.9191
# Epoch 36/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2194 - accuracy: 0.9189
# Epoch 37/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2170 - accuracy: 0.9191
# Epoch 38/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2160 - accuracy: 0.9190
# Epoch 39/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2149 - accuracy: 0.9196
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2145 - accuracy: 0.9209
# Epoch 41/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2130 - accuracy: 0.9209
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2128 - accuracy: 0.9215
# Epoch 43/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2114 - accuracy: 0.9220
# Epoch 44/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2106 - accuracy: 0.9224
# Epoch 45/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2079 - accuracy: 0.9230
# Epoch 46/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2075 - accuracy: 0.9229
# Epoch 47/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2079 - accuracy: 0.9232
# Epoch 48/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2058 - accuracy: 0.9234
# Epoch 49/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2040 - accuracy: 0.9249
# Epoch 50/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2047 - accuracy: 0.9238
# Epoch 51/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2024 - accuracy: 0.9253
# Epoch 52/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2026 - accuracy: 0.9253
# Epoch 53/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2019 - accuracy: 0.9254
# Epoch 54/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2020 - accuracy: 0.9252
# Epoch 55/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1999 - accuracy: 0.9262
# Epoch 56/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1994 - accuracy: 0.9265
# Epoch 57/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1986 - accuracy: 0.9259
# Epoch 58/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1973 - accuracy: 0.9270
# Epoch 59/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1950 - accuracy: 0.9265
# Epoch 60/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1970 - accuracy: 0.9267
# Epoch 61/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1951 - accuracy: 0.9273
# Epoch 62/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1951 - accuracy: 0.9279
# Epoch 63/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1950 - accuracy: 0.9275
# Epoch 64/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1936 - accuracy: 0.9283
# Epoch 65/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1919 - accuracy: 0.9297
# Epoch 66/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1918 - accuracy: 0.9289
# Epoch 67/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1906 - accuracy: 0.9291
# Epoch 68/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1909 - accuracy: 0.9293
# Epoch 69/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1901 - accuracy: 0.9291
# Epoch 70/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1898 - accuracy: 0.9297
# Epoch 71/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1902 - accuracy: 0.9287
# Epoch 72/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1872 - accuracy: 0.9304
# Epoch 73/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1878 - accuracy: 0.9305
# Epoch 74/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1880 - accuracy: 0.9302
# Epoch 75/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1867 - accuracy: 0.9305
# Epoch 76/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1849 - accuracy: 0.9314
# Epoch 77/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1866 - accuracy: 0.9304
# Epoch 78/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1831 - accuracy: 0.9312
# Epoch 79/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1851 - accuracy: 0.9311
# Epoch 80/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1831 - accuracy: 0.9326
# Epoch 81/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1832 - accuracy: 0.9323
# Epoch 82/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1849 - accuracy: 0.9310
# Epoch 83/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1804 - accuracy: 0.9326
# Epoch 84/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1804 - accuracy: 0.9330
# Epoch 85/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1822 - accuracy: 0.9323
# Epoch 86/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1802 - accuracy: 0.9343
# Epoch 87/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1783 - accuracy: 0.9334
# Epoch 88/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1805 - accuracy: 0.9328
# Epoch 89/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1789 - accuracy: 0.9339
# Epoch 90/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1785 - accuracy: 0.9330
# Epoch 91/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1778 - accuracy: 0.9341
# Epoch 92/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1760 - accuracy: 0.9352
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1766 - accuracy: 0.9354
# Epoch 94/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1772 - accuracy: 0.9344
# Epoch 95/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1766 - accuracy: 0.9351
# Epoch 96/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1773 - accuracy: 0.9335
# Epoch 97/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1742 - accuracy: 0.9360
# Epoch 98/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1744 - accuracy: 0.9348
# Epoch 99/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1754 - accuracy: 0.9349
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1727 - accuracy: 0.9363

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(test_loss)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 136.9182 - accuracy: 0.8306
# 136.918212890625

# %%
print(test_acc)
# Out:
# 0.8306000232696533

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict_classes(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8306

# %%
y_pred.shape
# Out:
# (10000,)

# %%
for i in range(len(y_pred)):
    print(class_name[y_pred[i]])
    plt.figure()
    plt.imshow(x_train[i])
    plt.show()
# Out:
# ankle_boot
# pullover
# trouser
# trouser
# top
# trouser
# coat
# shirt
# sendal
# sneaker
# coat
# sendal
# sendal
# dress
# coat
# trouser
# pullover
# coat
# bag
# top
# pullover
# sendal
# sneaker
# sendal
# trouser
# pullover
# shirt
# top
# ankle_boot
# coat
# bag
# bag
# dress
# dress
# bag
# top
# sneaker
# sendal
# sneaker
# ankle_boot
# top
# trouser
# top
# ankle_boot
# shirt
# sneaker
# pullover
# trouser
# pullover
# shirt
# coat
# coat
# sendal
# bag
# pullover
# pullover
# bag
# shirt
# bag
# top
# sneaker
# ankle_boot
# bag
# sendal
# trouser
# trouser
# pullover
# coat
# sneaker
# bag
# sneaker
# top
# top
# shirt
# coat
# dress
# trouser
# pullover
# bag
# coat
# trouser
# bag
# sendal
# ankle_boot
# sendal
# top
# dress
# pullover
# top
# pullover
# sendal
# top
# shirt
# sneaker
# trouser
# bag
# top
# trouser
# coat
# pullover
# dress
# shirt
# sneaker
# shirt
# sneaker
# bag
# sendal
# ankle_boot
# ankle_boot
# coat
# pullover
# sendal
# sneaker
# top
# sendal
# pullover
# bag
# coat
# sneaker
# bag
# top
# top
# ankle_boot
# ankle_boot
# dress
# top
# bag
# coat
# trouser
# sendal
# coat
# trouser
# ankle_boot
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-2ff09bdef599> in <module>
#       2     print(class_name[y_pred[i]])
#       3     plt.figure()
# ----> 4     plt.imshow(x_train[i])
#       5     plt.show()
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2706         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2707         data=None, **kwargs):
# -> 2708     __ret = gca().imshow(
#    2709         X, cmap=cmap, norm=norm, aspect=aspect,
#    2710         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\pyplot.py in gca(**kwargs)
#    2350 @_copy_docstring_and_deprecators(Figure.gca)
#    2351 def gca(**kwargs):
# -> 2352     return gcf().gca(**kwargs)
#    2353
#    2354
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\figure.py in gca(self, **kwargs)
#    2063
#    2064         # no axes found, so create one which spans the figure
# -> 2065         return self.add_subplot(1, 1, 1, **kwargs)
#    2066
#    2067     def sca(self, a):
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         if sharex is not None:
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1113         self.containers = []
#    1114
# -> 1115         self.grid(False)  # Disable grid on init to use rcParameter
#    1116         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1117                   axis=mpl.rcParams['axes.grid.axis'])
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    2891         cbook._check_in_list(['x', 'y', 'both'], axis=axis)
#    2892         if axis in ['x', 'both']:
# -> 2893             self.xaxis.grid(b, which=which, **kwargs)
#    2894         if axis in ['y', 'both']:
#    2895             self.yaxis.grid(b, which=which, **kwargs)
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axis.py in grid(self, b, which, **kwargs)
#    1446                 self._gridOnMajor = b
#    1447             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
# -> 1448                                  **gridkw)
#    1449         self.stale = True
#    1450
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axis.py in set_tick_params(self, which, reset, **kw)
#     836             if which in ['major', 'both']:
#     837                 self._major_tick_kw.update(kwtrans)
# --> 838                 for tick in self.majorTicks:
#     839                     tick._apply_params(**kwtrans)
#     840             if which in ['minor', 'both']:
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     616             if self._major:
#     617                 instance.majorTicks = []
# --> 618                 tick = instance._get_tick(major=True)
#     619                 instance.majorTicks.append(tick)
#     620                 return instance.majorTicks
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2011         else:
#    2012             tick_kw = self._minor_tick_kw
# -> 2013         return XTick(self.axes, 0, major=major, **tick_kw)
#    2014
#    2015     def set_label_position(self, position):
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     415
#     416     def __init__(self, *args, **kwargs):
# --> 417         super().__init__(*args, **kwargs)
#     418         # x in data coords, y in axes coords
#     419         self.tick1line.set(
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     164         )
#     165         self.gridline.get_path()._interpolation_steps = \
# --> 166             GRIDLINE_INTERPOLATION_STEPS
#     167         self.label1 = mtext.Text(
#     168             np.nan, np.nan,
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1009         """
#    1010         if self._invalidy or self._invalidx:
# -> 1011             self.recache()
#    1012         return self._path
#    1013
#
# ~\anaconda3\envs\learning\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     660             y = self._y
#     661
# --> 662         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     663         self._x, self._y = self._xy.T  # views
#     664
#
# KeyboardInterrupt:
