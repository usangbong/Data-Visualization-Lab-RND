# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
tf.get_logger().setLevel('ERROR')
gpu_devices = tf.config.experimental.list_physical_devices("GPU")
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %% [markdown]
# # Make Input

# %%
def txtToDataframe(filename, flag1, flag2):
    file = open(filename, 'r')
    lines = file.readlines()
    datas = []
    for line in lines:
        txt = line.replace('   ', ' ').lstrip().rstrip().replace(' ', ',')
        data = txt.split(',')
        datas.append(data)
    df = pd.DataFrame(datas)
    df.columns = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'F8', 'AF4']
    df['label1']=flag1
    df['label2']=flag2
    return df


def getData(src) :
    file_list = os.listdir(src)
    
    rating = pd.DataFrame(pd.read_csv(src+'ratings.txt'))
    file_list.remove('ratings.txt')
    
    dataList=[]
    highList=[]
    lowList=[]
    
    print(rating.columns)
    j=0
    for i in rating['subject']:
        if i<10:
            num = str(0)+str(i)
        else:
            num = str(i)
        dataList.append(txtToDataframe(src+'sub'+num+'_hi.txt', 1,rating['test'][j]))
        dataList.append(txtToDataframe(src+'sub'+num+'_lo.txt', 0,rating['rest'][j]))
        highList.append(txtToDataframe(src+'sub'+num+'_hi.txt', 1,rating['test'][j]))
        lowList.append(txtToDataframe(src+'sub'+num+'_lo.txt', 0,rating['rest'][j]))
        j+=1
    return dataList, highList, lowList

src = 'data/STEW Dataset/'
originalData, highData, lowData = getData(src)
# Out:
# Index(['subject', 'rest', 'test'], dtype='object')

# %%
def mergedData(dataList):
    merged_data = pd.concat([dataList[0],dataList[1]],ignore_index=True)
    for i in range(2,len(dataList)):
        merged_data = pd.concat([merged_data,dataList[i]],ignore_index=True)
    merged_data = merged_data.apply(pd.to_numeric)
    return merged_data

# %%
mergedData = mergedData(originalData)
label=mergedData['label1']
data=mergedData.drop(['label1','label2'],axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled = scaler.fit_transform(data)
data = pd.DataFrame(scaled, columns = data.columns, index=data.index)
data
# Out:
#               AF3        F7        F3       FC5        T7        O1        O2  \
# 0        0.558932  0.452258  0.539627  0.553295  0.479273  0.449631  0.482450
# 1        0.558867  0.451482  0.540022  0.550698  0.479207  0.449895  0.483076
# 2        0.557644  0.451223  0.540286  0.551317  0.479142  0.450158  0.483952
# 3        0.557580  0.452775  0.539759  0.556078  0.480956  0.450357  0.484202
# 4        0.558803  0.453422  0.539430  0.557129  0.482576  0.450753  0.484076
# ...           ...       ...       ...       ...       ...       ...       ...
# 1727995  0.506663  0.480335  0.481982  0.504143  0.541975  0.478809  0.499843
# 1727996  0.506404  0.480140  0.482113  0.504018  0.542493  0.479074  0.499781
# 1727997  0.506598  0.479816  0.481850  0.503833  0.542104  0.478809  0.499155
# 1727998  0.506920  0.479752  0.481785  0.504081  0.541456  0.478677  0.498968
# 1727999  0.506920  0.479687  0.481916  0.504266  0.542104  0.479602  0.499719
#
#                P8        T8       FC6        F4        F8        F8       AF4
# 0        0.542340  0.558323  0.505813  0.479338  0.521798  0.533296  0.494656
# 1        0.543015  0.558871  0.506793  0.480193  0.521187  0.535799  0.490618
# 2        0.543629  0.559726  0.508383  0.479766  0.519600  0.538119  0.488070
# 3        0.544427  0.560153  0.508873  0.480681  0.520759  0.537874  0.491798
# 4        0.544489  0.560032  0.508444  0.482268  0.522042  0.538057  0.493351
# ...           ...       ...       ...       ...       ...       ...       ...
# 1727995  0.512926  0.527864  0.479439  0.542453  0.561057  0.560825  0.551323
# 1727996  0.512004  0.527193  0.479073  0.542391  0.561301  0.560215  0.550765
# 1727997  0.510224  0.526094  0.477727  0.541964  0.560813  0.559361  0.550143
# 1727998  0.510347  0.526277  0.477665  0.542026  0.560752  0.559788  0.550765
# 1727999  0.511268  0.527009  0.478460  0.541964  0.560936  0.559605  0.551013
#
# [1728000 rows x 14 columns]

# %%
high_data = mergedData(highData)
high_label = high_data['label2']
high_data = high_data.drop(['label1','label2'],axis=1)
high_scaled = scaler.fit_transform(high_data)
high_data = pd.DataFrame(high_scaled, columns = high_data.columns, index=high_data.index)

# %%
low_data = mergedData(lowData)
low_label = low_data['label2']
low_data = low_data.drop(['label1','label2'],axis=1)
low_scaled = scaler.fit_transform(low_data)
low_data = pd.DataFrame(low_scaled, columns = low_data.columns, index=low_data.index)

# %%
def windowing_dataset(data, label, window_size):
    data_list = []
    label_list = []
    
    for i in range(0,len(data)//window_size,window_size):
        data_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i]))
    return np.array(data_list), np.array(label_list)

dataList, labelList = windowing_dataset(data,label,14)
print(data.shape, label.shape, dataList.shape, labelList.shape)
# Out:
# (1728000, 14) (1728000,) (8817, 14, 14) (8817,)

# %%
from tensorflow.keras.utils import to_categorical

high_dataList, high_labelList = windowing_dataset(high_data,high_label,14)
high_labelList = to_categorical(high_labelList,9)
print(high_data.shape, high_label.shape, high_dataList.shape, high_labelList.shape)
# Out:
# (864000, 14) (864000,) (4409, 14, 14) (4409, 9)

# %%
low_dataList, low_labelList = windowing_dataset(low_data,low_label,14)
low_labelList = to_categorical(low_labelList,9)
print(low_data.shape, low_label.shape, low_dataList.shape, low_labelList.shape)
# Out:
# (864000, 14) (864000,) (4409, 14, 14) (4409, 9)

# %%
high_labelList=high_labelList.astype('int32')
low_labelList=low_labelList.astype('int32')

high_labelList.dtype, low_labelList.dtype
# Out:
# (dtype('int32'), dtype('int32'))

# %% [markdown]
# # Model Tuning

# %% [markdown]
# ## Model 1

# %%
from autokeras.keras_layers import ExpandLastDim
from autokeras.keras_layers import CastToFloat32
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, GlobalAveragePooling2D, LSTM, SimpleRNN
from tensorflow.keras.layers import InputLayer, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.layers.experimental.preprocessing import RandomTranslation, RandomFlip
from tensorflow.keras.layers.experimental.preprocessing import Resizing
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.applications import EfficientNetB7

# %%
import matplotlib.pyplot as plt

def drawResult(history):
    fig, loss_ax = plt.subplots()
    acc_ax = loss_ax.twinx()

    loss_ax.plot(history.history['loss'], 'y', label='train loss')
    loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    loss_ax.legend(loc='upper left')

    acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
    acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')
    acc_ax.set_ylabel('accuracy')
    acc_ax.legend(loc='upper left')

    plt.show()

# %%
from sklearn.metrics import f1_score

def runModel(model, crossentropy, x_train, y_train, x_valid, y_valid):
    early_stop = EarlyStopping(monitor='val_loss', patience=10)
    model.compile(optimizer='adam', loss= crossentropy, metrics='accuracy')

    history = model.fit(x_train, y_train, 
                        epochs = 200, 
                        validation_data = (x_valid, y_valid), 
                        callbacks=[early_stop], verbose=0)
    drawResult(history)
    return model
    
def eval_model(model, x_test, y_test):
    pred = model.predict(x_test)
    y_pred = pred.round(0).astype('int32')

    return f1_score(y_test, y_pred, average='macro')

# %%
def Model1_1():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    
    model.add(Flatten())
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    #model.summary()
    return model

def Model1_2():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    
    model.add(Flatten())
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    #model.summary()
    return model

def Model1_3():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    
    model.add(GlobalMaxPooling2D())
    model.add(Dense(1, activation='sigmoid'))
    
    #model.summary()
    return model

# %%
X_train, X_, Y_train, Y_ = train_test_split(dataList,labelList, train_size=0.7, random_state=True ,stratify = labelList)
X_valid, X_test, Y_valid, Y_test = train_test_split(X_,Y_, train_size=0.5, random_state=True ,stratify = Y_)

print(X_train.shape, X_valid.shape, X_test.shape, Y_train.shape, Y_valid.shape, Y_test.shape)
print(X_train.dtype, X_valid.dtype, X_test.dtype, Y_train.dtype, Y_valid.dtype, Y_test.dtype)
# Out:
# (6171, 14, 14) (1323, 14, 14) (1323, 14, 14) (6171,) (1323,) (1323,)
# float64 float64 float64 int64 int64 int64

# %%
crossentropy = 'binary_crossentropy'

print(eval_model(runModel(Model1_1(),crossentropy,X_train, Y_train, X_valid, Y_valid), X_test, Y_test))
# Out:
# Epoch 1/200
# 193/193 [==============================] - 3s 13ms/step - loss: 4.4092 - accuracy: 0.6108 - val_loss: 0.5245 - val_accuracy: 0.7377
# Epoch 2/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.5387 - accuracy: 0.6997 - val_loss: 0.4997 - val_accuracy: 0.7642
# Epoch 3/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.4649 - accuracy: 0.7561 - val_loss: 0.4646 - val_accuracy: 0.7566
# Epoch 4/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.4458 - accuracy: 0.7728 - val_loss: 0.4110 - val_accuracy: 0.8420
# Epoch 5/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3894 - accuracy: 0.8206 - val_loss: 0.4610 - val_accuracy: 0.7543
# Epoch 6/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.4313 - accuracy: 0.7932 - val_loss: 0.4658 - val_accuracy: 0.7491
# Epoch 7/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.3759 - accuracy: 0.8200 - val_loss: 0.4411 - val_accuracy: 0.7785
# Epoch 8/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.3638 - accuracy: 0.8323 - val_loss: 0.4571 - val_accuracy: 0.7596
# Epoch 9/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3267 - accuracy: 0.8511 - val_loss: 0.3444 - val_accuracy: 0.8322
# Epoch 10/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2983 - accuracy: 0.8687 - val_loss: 0.3224 - val_accuracy: 0.8534
# Epoch 11/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.3046 - accuracy: 0.8629 - val_loss: 0.3284 - val_accuracy: 0.8534
# Epoch 12/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.2853 - accuracy: 0.8764 - val_loss: 0.2577 - val_accuracy: 0.9169
# Epoch 13/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.2541 - accuracy: 0.8888 - val_loss: 0.2603 - val_accuracy: 0.9070
# Epoch 14/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.2503 - accuracy: 0.8935 - val_loss: 0.2361 - val_accuracy: 0.9131
# Epoch 15/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.2310 - accuracy: 0.9037 - val_loss: 0.2229 - val_accuracy: 0.9267
# Epoch 16/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.2389 - accuracy: 0.9021 - val_loss: 0.2401 - val_accuracy: 0.9259
# Epoch 17/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.2274 - accuracy: 0.9084 - val_loss: 0.2044 - val_accuracy: 0.9305
# Epoch 18/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.2260 - accuracy: 0.9071 - val_loss: 0.2869 - val_accuracy: 0.8904
# Epoch 19/200
# 193/193 [==============================] - 3s 14ms/step - loss: 0.1994 - accuracy: 0.9251 - val_loss: 0.2065 - val_accuracy: 0.9312
# Epoch 20/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.2096 - accuracy: 0.9144 - val_loss: 0.1747 - val_accuracy: 0.9418
# Epoch 21/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1745 - accuracy: 0.9297 - val_loss: 0.1985 - val_accuracy: 0.9221
# Epoch 22/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1786 - accuracy: 0.9274 - val_loss: 0.2394 - val_accuracy: 0.9214
# Epoch 23/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1618 - accuracy: 0.9386 - val_loss: 0.1638 - val_accuracy: 0.9486
# Epoch 24/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1737 - accuracy: 0.9321 - val_loss: 0.1780 - val_accuracy: 0.9539
# Epoch 25/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1649 - accuracy: 0.9373 - val_loss: 0.3659 - val_accuracy: 0.8375
# Epoch 26/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1756 - accuracy: 0.9287 - val_loss: 0.2058 - val_accuracy: 0.9297
# Epoch 27/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1780 - accuracy: 0.9327 - val_loss: 0.3238 - val_accuracy: 0.8964
# Epoch 28/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1737 - accuracy: 0.9334 - val_loss: 0.1696 - val_accuracy: 0.9577
# Epoch 29/200
# 193/193 [==============================] - 3s 14ms/step - loss: 0.1567 - accuracy: 0.9413 - val_loss: 0.2189 - val_accuracy: 0.9221
# Epoch 30/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1607 - accuracy: 0.9412 - val_loss: 0.1782 - val_accuracy: 0.9471
# Epoch 31/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1620 - accuracy: 0.9358 - val_loss: 0.2033 - val_accuracy: 0.9373
# Epoch 32/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1794 - accuracy: 0.9290 - val_loss: 0.1864 - val_accuracy: 0.9403
# Epoch 33/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1418 - accuracy: 0.9443 - val_loss: 0.1818 - val_accuracy: 0.9289
# 0.9332464875625541

# %%
print(eval_model(runModel(Model1_2(),crossentropy,X_train, Y_train, X_valid, Y_valid), X_test, Y_test))
# Out:
# Epoch 1/200
# 193/193 [==============================] - 3s 14ms/step - loss: 5.3811 - accuracy: 0.6043 - val_loss: 0.6484 - val_accuracy: 0.6599
# Epoch 2/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.5087 - accuracy: 0.7224 - val_loss: 0.4560 - val_accuracy: 0.7611
# Epoch 3/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.4684 - accuracy: 0.7444 - val_loss: 0.4640 - val_accuracy: 0.7778
# Epoch 4/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.4086 - accuracy: 0.7932 - val_loss: 0.4050 - val_accuracy: 0.8231
# Epoch 5/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.4126 - accuracy: 0.7978 - val_loss: 0.4009 - val_accuracy: 0.8125
# Epoch 6/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.3769 - accuracy: 0.8211 - val_loss: 0.3843 - val_accuracy: 0.8246
# Epoch 7/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.3776 - accuracy: 0.8141 - val_loss: 0.4017 - val_accuracy: 0.8193
# Epoch 8/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.3619 - accuracy: 0.8328 - val_loss: 0.5039 - val_accuracy: 0.7286
# Epoch 9/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.3429 - accuracy: 0.8438 - val_loss: 0.3619 - val_accuracy: 0.8587
# Epoch 10/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.3318 - accuracy: 0.8503 - val_loss: 0.4105 - val_accuracy: 0.7937
# Epoch 11/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3373 - accuracy: 0.8389 - val_loss: 0.3527 - val_accuracy: 0.8435
# Epoch 12/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3157 - accuracy: 0.8595 - val_loss: 0.3221 - val_accuracy: 0.8776
# Epoch 13/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3174 - accuracy: 0.8605 - val_loss: 0.3468 - val_accuracy: 0.8753
# Epoch 14/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3127 - accuracy: 0.8580 - val_loss: 0.3360 - val_accuracy: 0.8579
# Epoch 15/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3069 - accuracy: 0.8642 - val_loss: 0.3172 - val_accuracy: 0.8685
# Epoch 16/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2915 - accuracy: 0.8704 - val_loss: 0.2852 - val_accuracy: 0.8859
# Epoch 17/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2779 - accuracy: 0.8820 - val_loss: 0.2846 - val_accuracy: 0.8821
# Epoch 18/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2591 - accuracy: 0.8919 - val_loss: 0.3456 - val_accuracy: 0.8375
# Epoch 19/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2512 - accuracy: 0.8950 - val_loss: 0.2329 - val_accuracy: 0.9199
# Epoch 20/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2705 - accuracy: 0.8830 - val_loss: 0.3223 - val_accuracy: 0.8806
# Epoch 21/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2356 - accuracy: 0.9013 - val_loss: 0.2553 - val_accuracy: 0.9055
# Epoch 22/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2264 - accuracy: 0.9067 - val_loss: 0.2224 - val_accuracy: 0.9252
# Epoch 23/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2199 - accuracy: 0.9068 - val_loss: 0.2404 - val_accuracy: 0.9055
# Epoch 24/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2010 - accuracy: 0.9199 - val_loss: 0.3106 - val_accuracy: 0.8881
# Epoch 25/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2162 - accuracy: 0.9161 - val_loss: 0.1925 - val_accuracy: 0.9373
# Epoch 26/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1935 - accuracy: 0.9225 - val_loss: 0.2239 - val_accuracy: 0.9206
# Epoch 27/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1863 - accuracy: 0.9311 - val_loss: 0.2408 - val_accuracy: 0.9101
# Epoch 28/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1804 - accuracy: 0.9284 - val_loss: 0.2746 - val_accuracy: 0.9153
# Epoch 29/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1667 - accuracy: 0.9350 - val_loss: 0.1950 - val_accuracy: 0.9237
# Epoch 30/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1637 - accuracy: 0.9373 - val_loss: 0.2992 - val_accuracy: 0.8828
# Epoch 31/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1701 - accuracy: 0.9357 - val_loss: 0.1840 - val_accuracy: 0.9463
# Epoch 32/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1532 - accuracy: 0.9405 - val_loss: 0.1911 - val_accuracy: 0.9478
# Epoch 33/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1504 - accuracy: 0.9443 - val_loss: 0.1759 - val_accuracy: 0.9463
# Epoch 34/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1451 - accuracy: 0.9447 - val_loss: 0.1830 - val_accuracy: 0.9388
# Epoch 35/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1494 - accuracy: 0.9381 - val_loss: 0.1744 - val_accuracy: 0.9494
# Epoch 36/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1453 - accuracy: 0.9457 - val_loss: 0.1942 - val_accuracy: 0.9282
# Epoch 37/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1370 - accuracy: 0.9473 - val_loss: 0.1875 - val_accuracy: 0.9403
# Epoch 38/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1192 - accuracy: 0.9545 - val_loss: 0.1595 - val_accuracy: 0.9531
# Epoch 39/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1290 - accuracy: 0.9519 - val_loss: 0.2773 - val_accuracy: 0.9093
# Epoch 40/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1591 - accuracy: 0.9357 - val_loss: 0.2312 - val_accuracy: 0.9108
# Epoch 41/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1316 - accuracy: 0.9494 - val_loss: 0.1609 - val_accuracy: 0.9524
# Epoch 42/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1179 - accuracy: 0.9561 - val_loss: 0.3216 - val_accuracy: 0.8987
# Epoch 43/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1402 - accuracy: 0.9433 - val_loss: 0.1672 - val_accuracy: 0.9531
# Epoch 44/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1322 - accuracy: 0.9478 - val_loss: 0.1789 - val_accuracy: 0.9516
# Epoch 45/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1167 - accuracy: 0.9564 - val_loss: 0.1642 - val_accuracy: 0.9531
# Epoch 46/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1223 - accuracy: 0.9512 - val_loss: 0.1532 - val_accuracy: 0.9577
# Epoch 47/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1383 - accuracy: 0.9488 - val_loss: 0.1747 - val_accuracy: 0.9569
# Epoch 48/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1168 - accuracy: 0.9564 - val_loss: 0.1712 - val_accuracy: 0.9569
# Epoch 49/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1023 - accuracy: 0.9595 - val_loss: 0.1551 - val_accuracy: 0.9562
# Epoch 50/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1392 - accuracy: 0.9538 - val_loss: 0.1441 - val_accuracy: 0.9683
# Epoch 51/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1126 - accuracy: 0.9577 - val_loss: 0.2076 - val_accuracy: 0.9539
# Epoch 52/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1152 - accuracy: 0.9559 - val_loss: 0.1908 - val_accuracy: 0.9320
# Epoch 53/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1031 - accuracy: 0.9587 - val_loss: 0.1388 - val_accuracy: 0.9667
# Epoch 54/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1132 - accuracy: 0.9551 - val_loss: 0.1890 - val_accuracy: 0.9403
# Epoch 55/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1007 - accuracy: 0.9605 - val_loss: 0.2087 - val_accuracy: 0.9418
# Epoch 56/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.0967 - accuracy: 0.9622 - val_loss: 0.1464 - val_accuracy: 0.9660
# Epoch 57/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.0949 - accuracy: 0.9669 - val_loss: 0.1905 - val_accuracy: 0.9584
# Epoch 58/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1056 - accuracy: 0.9593 - val_loss: 0.1864 - val_accuracy: 0.9471
# Epoch 59/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1020 - accuracy: 0.9639 - val_loss: 0.1626 - val_accuracy: 0.9599
# Epoch 60/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1060 - accuracy: 0.9613 - val_loss: 0.1429 - val_accuracy: 0.9652
# Epoch 61/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.0901 - accuracy: 0.9634 - val_loss: 0.1577 - val_accuracy: 0.9592
# Epoch 62/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1008 - accuracy: 0.9640 - val_loss: 0.1816 - val_accuracy: 0.9501
# Epoch 63/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.0962 - accuracy: 0.9613 - val_loss: 0.1480 - val_accuracy: 0.9652
# 0.962714496467117

# %%
print(eval_model(runModel(Model1_3(),crossentropy,X_train, Y_train, X_valid, Y_valid), X_test, Y_test))
# Out:
# Epoch 1/200
# 193/193 [==============================] - 3s 13ms/step - loss: 7.3334 - accuracy: 0.5814 - val_loss: 0.5403 - val_accuracy: 0.6901
# Epoch 2/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.5981 - accuracy: 0.6655 - val_loss: 0.5692 - val_accuracy: 0.6266
# Epoch 3/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.4813 - accuracy: 0.7454 - val_loss: 0.4435 - val_accuracy: 0.7566
# Epoch 4/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.4318 - accuracy: 0.7772 - val_loss: 0.4393 - val_accuracy: 0.7891
# Epoch 5/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3905 - accuracy: 0.8185 - val_loss: 0.3984 - val_accuracy: 0.7763
# Epoch 6/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3807 - accuracy: 0.8217 - val_loss: 0.3294 - val_accuracy: 0.8972
# Epoch 7/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3260 - accuracy: 0.8532 - val_loss: 0.3119 - val_accuracy: 0.8730
# Epoch 8/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.3201 - accuracy: 0.8508 - val_loss: 0.3285 - val_accuracy: 0.8866
# Epoch 9/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2945 - accuracy: 0.8739 - val_loss: 0.3276 - val_accuracy: 0.8791
# Epoch 10/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2991 - accuracy: 0.8689 - val_loss: 0.3045 - val_accuracy: 0.9002
# Epoch 11/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2709 - accuracy: 0.8828 - val_loss: 0.2977 - val_accuracy: 0.8995
# Epoch 12/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2672 - accuracy: 0.8845 - val_loss: 0.2676 - val_accuracy: 0.9085
# Epoch 13/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2765 - accuracy: 0.8788 - val_loss: 0.2836 - val_accuracy: 0.8836
# Epoch 14/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2631 - accuracy: 0.8893 - val_loss: 0.2893 - val_accuracy: 0.8881
# Epoch 15/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2802 - accuracy: 0.8822 - val_loss: 0.2843 - val_accuracy: 0.9093
# Epoch 16/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2757 - accuracy: 0.8866 - val_loss: 0.2925 - val_accuracy: 0.8806
# Epoch 17/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2340 - accuracy: 0.9044 - val_loss: 0.2251 - val_accuracy: 0.9373
# Epoch 18/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2251 - accuracy: 0.9050 - val_loss: 0.4362 - val_accuracy: 0.8125
# Epoch 19/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2770 - accuracy: 0.8789 - val_loss: 0.2507 - val_accuracy: 0.9101
# Epoch 20/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2215 - accuracy: 0.9117 - val_loss: 0.2166 - val_accuracy: 0.9350
# Epoch 21/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2316 - accuracy: 0.9057 - val_loss: 0.2007 - val_accuracy: 0.9403
# Epoch 22/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2313 - accuracy: 0.9112 - val_loss: 0.2390 - val_accuracy: 0.9176
# Epoch 23/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2116 - accuracy: 0.9117 - val_loss: 0.2498 - val_accuracy: 0.9131
# Epoch 24/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2011 - accuracy: 0.9188 - val_loss: 0.2222 - val_accuracy: 0.9252
# Epoch 25/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1775 - accuracy: 0.9342 - val_loss: 0.2168 - val_accuracy: 0.9259
# Epoch 26/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2094 - accuracy: 0.9156 - val_loss: 0.2172 - val_accuracy: 0.9267
# Epoch 27/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1816 - accuracy: 0.9277 - val_loss: 0.1923 - val_accuracy: 0.9426
# Epoch 28/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1925 - accuracy: 0.9216 - val_loss: 0.2178 - val_accuracy: 0.9282
# Epoch 29/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1858 - accuracy: 0.9287 - val_loss: 0.2201 - val_accuracy: 0.9335
# Epoch 30/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1876 - accuracy: 0.9264 - val_loss: 0.2382 - val_accuracy: 0.9161
# Epoch 31/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1678 - accuracy: 0.9324 - val_loss: 0.2093 - val_accuracy: 0.9373
# Epoch 32/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2129 - accuracy: 0.9170 - val_loss: 0.2297 - val_accuracy: 0.9070
# Epoch 33/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1880 - accuracy: 0.9227 - val_loss: 0.1872 - val_accuracy: 0.9365
# Epoch 34/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1561 - accuracy: 0.9386 - val_loss: 0.2239 - val_accuracy: 0.9229
# Epoch 35/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.2064 - accuracy: 0.9180 - val_loss: 0.2167 - val_accuracy: 0.9237
# Epoch 36/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1836 - accuracy: 0.9282 - val_loss: 0.2164 - val_accuracy: 0.9199
# Epoch 37/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1460 - accuracy: 0.9451 - val_loss: 0.1991 - val_accuracy: 0.9441
# Epoch 38/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1504 - accuracy: 0.9420 - val_loss: 0.1781 - val_accuracy: 0.9486
# Epoch 39/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1326 - accuracy: 0.9496 - val_loss: 0.2357 - val_accuracy: 0.9169
# Epoch 40/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1506 - accuracy: 0.9412 - val_loss: 0.1706 - val_accuracy: 0.9471
# Epoch 41/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1533 - accuracy: 0.9376 - val_loss: 0.2311 - val_accuracy: 0.9274
# Epoch 42/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1562 - accuracy: 0.9381 - val_loss: 0.1870 - val_accuracy: 0.9403
# Epoch 43/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1442 - accuracy: 0.9397 - val_loss: 0.2436 - val_accuracy: 0.9078
# Epoch 44/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1431 - accuracy: 0.9430 - val_loss: 0.1907 - val_accuracy: 0.9350
# Epoch 45/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1671 - accuracy: 0.9345 - val_loss: 0.2195 - val_accuracy: 0.9350
# Epoch 46/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1371 - accuracy: 0.9488 - val_loss: 0.1664 - val_accuracy: 0.9441
# Epoch 47/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1265 - accuracy: 0.9514 - val_loss: 0.1573 - val_accuracy: 0.9546
# Epoch 48/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1376 - accuracy: 0.9493 - val_loss: 0.1843 - val_accuracy: 0.9395
# Epoch 49/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1129 - accuracy: 0.9541 - val_loss: 0.1483 - val_accuracy: 0.9645
# Epoch 50/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1216 - accuracy: 0.9541 - val_loss: 0.2107 - val_accuracy: 0.9342
# Epoch 51/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1238 - accuracy: 0.9541 - val_loss: 0.1895 - val_accuracy: 0.9441
# Epoch 52/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1515 - accuracy: 0.9383 - val_loss: 0.2354 - val_accuracy: 0.9229
# Epoch 53/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1283 - accuracy: 0.9517 - val_loss: 0.1813 - val_accuracy: 0.9524
# Epoch 54/200
# 193/193 [==============================] - 3s 13ms/step - loss: 0.1211 - accuracy: 0.9571 - val_loss: 0.1907 - val_accuracy: 0.9373
# Epoch 55/200
# 193/193 [==============================] - 2s 13ms/step - loss: 0.1253 - accuracy: 0.9535 - val_loss: 0.1944 - val_accuracy: 0.9441
# Epoch 56/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1429 - accuracy: 0.9454 - val_loss: 0.2483 - val_accuracy: 0.9176
# Epoch 57/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1292 - accuracy: 0.9506 - val_loss: 0.2797 - val_accuracy: 0.9070
# Epoch 58/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1109 - accuracy: 0.9595 - val_loss: 0.2283 - val_accuracy: 0.9229
# Epoch 59/200
# 193/193 [==============================] - 2s 12ms/step - loss: 0.1079 - accuracy: 0.9608 - val_loss: 0.1744 - val_accuracy: 0.9569
# 0.9643570587995893

# %%
def Model2_1_1():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(4,4), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(4,4), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dropout(0.25))
    
    model.add(Dense(9, activation='sigmoid'))
    
    #model.summary()
    return model

def Model2_1_2():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dropout(0.25))
    
    model.add(Dense(50, activation='relu'))
    model.add(Dense(9, activation='sigmoid'))
    
    #model.summary()
    return model

def Model2_1_3():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(4,4), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(4,4), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(128, kernel_size=(4,4), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(128, kernel_size=(4,4), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(32, kernel_size=(4,4), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(32, kernel_size=(4,4), strides=(1,1), activation='relu', padding='same'))
    
    model.add(Flatten())
    model.add(Dense(50, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(9, activation='sigmoid'))
    
    #model.summary()
    return model

# %%
high_x_train, high_x_, high_y_train, high_y_ = train_test_split(high_dataList,high_labelList, train_size=0.7, random_state=True ,stratify = high_labelList)
high_x_valid, high_x_test, high_y_valid, high_y_test = train_test_split(high_x_,high_y_, train_size=0.5, random_state=True ,stratify = high_y_)

print(high_x_train.shape, high_x_valid.shape, high_x_test.shape, high_y_train.shape, high_y_valid.shape, high_y_test.shape)
print(high_x_train.dtype, high_x_valid.dtype, high_x_test.dtype, high_y_train.dtype, high_y_valid.dtype, high_y_test.dtype)
# Out:
# (3086, 14, 14) (661, 14, 14) (662, 14, 14) (3086, 9) (661, 9) (662, 9)
# float64 float64 float64 int32 int32 int32

# %%
def eval_model2(model, x_test, y_test):
    y_pred = model.predict(x_test)
    return f1_score(y_test.argmax(axis=1), y_pred.argmax(axis=1), average='macro')

# %%
crossentropy = 'categorical_crossentropy'

print(eval_model2(runModel(Model2_1_1(),crossentropy,high_x_train, high_y_train, high_x_valid, high_y_valid), high_x_test, high_y_test))
print(eval_model2(runModel(Model2_1_2(),crossentropy,high_x_train, high_y_train, high_x_valid, high_y_valid), high_x_test, high_y_test))
print(eval_model2(runModel(Model2_1_3(),crossentropy,high_x_train, high_y_train, high_x_valid, high_y_valid), high_x_test, high_y_test))
# Out:
# 0.9339760638297872
# 0.9531630964820621
# 0.7260915493771657

# %%
def Model2_2_1():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(4,4), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(4,4), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dropout(0.25))
    
    model.add(Dense(9, activation='sigmoid'))
    
    #model.summary()
    return model

def Model2_2_2():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dropout(0.25))
    
    model.add(Dense(50, activation='relu'))
    model.add(Dense(9, activation='sigmoid'))
    
    model.summary()
    return model

def Model2_2_3():
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(4,4), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(4,4), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(128, kernel_size=(4,4), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(128, kernel_size=(4,4), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(32, kernel_size=(4,4), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(32, kernel_size=(4,4), strides=(1,1), activation='relu', padding='same'))
    
    model.add(Flatten())
    model.add(Dense(50, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(9, activation='sigmoid'))
    
    #model.summary()
    return model

# %%
low_x_train, low_x_, low_y_train, low_y_ = train_test_split(low_dataList,low_labelList, train_size=0.7, random_state=True ,stratify = low_labelList)
low_x_valid, low_x_test, low_y_valid, low_y_test = train_test_split(low_x_,low_y_, train_size=0.5, random_state=True ,stratify = low_y_)

print(low_x_train.shape, low_x_valid.shape, low_x_test.shape, low_y_train.shape, low_y_valid.shape, low_y_test.shape)
print(low_x_train.dtype, low_x_valid.dtype, low_x_test.dtype, low_y_train.dtype, low_y_valid.dtype, low_y_test.dtype)
# Out:
# (3086, 14, 14) (661, 14, 14) (662, 14, 14) (3086, 9) (661, 9) (662, 9)
# float64 float64 float64 int32 int32 int32

# %%
crossentropy = 'categorical_crossentropy'

print(eval_model2(runModel(Model2_2_1(),crossentropy,low_x_train, low_y_train, low_x_valid, low_y_valid), low_x_test, low_y_test))
print(eval_model2(runModel(Model2_2_2(),crossentropy,low_x_train, low_y_train, low_x_valid, low_y_valid), low_x_test, low_y_test))
print(eval_model2(runModel(Model2_2_3(),crossentropy,low_x_train, low_y_train, low_x_valid, low_y_valid), low_x_test, low_y_test))
# Out:
# 0.9967813141184593
# 0.9967813141184593
# 0.9838007145304164

# %%
model = Sequential()
model.add(InputLayer(input_shape=(14, 14)))
model.add(ExpandLastDim())
model.add(CastToFloat32())
    
model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
model.add(MaxPooling2D(2,2))
    
model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPooling2D(2,2))
    
model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
model.add(Dropout(0.25))
    
model.add(Flatten())
model.add(Dropout(0.25))
    
model.add(Dense(50, activation='relu'))
model.add(Dense(9, activation='sigmoid'))
    
model.summary()
# Out:
# Model: "sequential_167"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# expand_last_dim_129 (ExpandL (None, 14, 14, 1)         0
# _________________________________________________________________
# cast_to_float32_143 (CastToF (None, 14, 14, 1)         0
# _________________________________________________________________
# conv2d_659 (Conv2D)          (None, 13, 13, 512)       2560
# _________________________________________________________________
# conv2d_660 (Conv2D)          (None, 12, 12, 512)       1049088
# _________________________________________________________________
# max_pooling2d_259 (MaxPoolin (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_661 (Conv2D)          (None, 6, 6, 128)         262272
# _________________________________________________________________
# conv2d_662 (Conv2D)          (None, 6, 6, 128)         65664
# _________________________________________________________________
# max_pooling2d_260 (MaxPoolin (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_663 (Conv2D)          (None, 3, 3, 32)          16416
# _________________________________________________________________
# conv2d_664 (Conv2D)          (None, 3, 3, 32)          4128
# _________________________________________________________________
# dropout_130 (Dropout)        (None, 3, 3, 32)          0
# _________________________________________________________________
# flatten_71 (Flatten)         (None, 288)               0
# _________________________________________________________________
# dropout_131 (Dropout)        (None, 288)               0
# _________________________________________________________________
# dense_233 (Dense)            (None, 50)                14450
# _________________________________________________________________
# dense_234 (Dense)            (None, 9)                 459
# =================================================================
# Total params: 1,415,037
# Trainable params: 1,415,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
    model = Sequential()
    model.add(InputLayer(input_shape=(14, 14)))
    model.add(ExpandLastDim())
    model.add(CastToFloat32())
    
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(Conv2D(512, kernel_size=(2,2), strides=(1,1), activation='relu', padding='valid'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(128, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(2,2))
    
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    model.add(Conv2D(32, kernel_size=(2,2), strides=(1,1), activation='relu', padding='same'))
    
    model.add(GlobalMaxPooling2D())
    model.add(Dense(1, activation='sigmoid'))
    
    model.summary()
# Out:
# Model: "sequential_168"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# expand_last_dim_130 (ExpandL (None, 14, 14, 1)         0
# _________________________________________________________________
# cast_to_float32_144 (CastToF (None, 14, 14, 1)         0
# _________________________________________________________________
# conv2d_665 (Conv2D)          (None, 13, 13, 512)       2560
# _________________________________________________________________
# conv2d_666 (Conv2D)          (None, 12, 12, 512)       1049088
# _________________________________________________________________
# max_pooling2d_261 (MaxPoolin (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_667 (Conv2D)          (None, 6, 6, 128)         262272
# _________________________________________________________________
# conv2d_668 (Conv2D)          (None, 6, 6, 128)         65664
# _________________________________________________________________
# max_pooling2d_262 (MaxPoolin (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_669 (Conv2D)          (None, 3, 3, 32)          16416
# _________________________________________________________________
# conv2d_670 (Conv2D)          (None, 3, 3, 32)          4128
# _________________________________________________________________
# global_max_pooling2d_61 (Glo (None, 32)                0
# _________________________________________________________________
# dense_235 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 1,400,161
# Trainable params: 1,400,161
# Non-trainable params: 0
# _________________________________________________________________
