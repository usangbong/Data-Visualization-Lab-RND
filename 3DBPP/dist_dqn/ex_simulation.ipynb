# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from libs.generate_boxes import *
from libs.utils import *

# %%
boxes_multi,pos_multi=generation_3dbox_random(case_size=[[20,20,20], [10,15,30]])

# %%
# %matplotlib notebook
vis_box(boxes_multi[0],pos_multi[0])
# Out:
# <img src="data:image/png;base64,..." width="467.84">

# %%
# %matplotlib notebook
vis_box(boxes_multi[1],pos_multi[1])
# Out:
# <img src="data:image/png;base64,..." width="299.52">
