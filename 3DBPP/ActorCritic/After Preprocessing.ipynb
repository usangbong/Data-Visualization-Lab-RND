# %%
import pandas as pd

# %%
path = 'Data\후처리 데이터\GA\GA_20200401.csv'
df = pd.read_csv(path, index_col=0)
df
# Out:
#           등록일자 고객사코드  고객사명        오더번호  차종 차종명           부품번호  \
# 0     20200401    KS   KMS  KSEDK30426   E  ED     243212B000
# 1     20200401    KS   KMS  KSEDK30473   E  ED     243492B000
# 2     20200401    KS   KMS  KSEDK30429   E  ED     2682247291
# 3     20200401    KS   KMS  KSEDK30429   E  ED     282472A100
# 4     20200401    KS   KMS  KSEDK30426   E  ED     254522B000
# ...        ...   ...   ...         ...  ..  ..            ...
# 1172  20200401    HC  HMMC  HCOSK37132  OS  OS  95720K4010PAE
# 1173  20200401    KS   KMS  KSQLK30447  QL  QL    1735125000B
# 1174  20200401    KS   KMS  KSEDK30463   E  ED     223112U011
# 1175  20200401    KS   KMS  KSEDK30427   E  ED     223112U011
# 1176  20200401    KS   KMS  KSEDK30422   E  ED     223112U011
#
#                                부품명  업체코드             업체명  지연일수  중박스적입수  \
# 0                     CHAIN-TIMING  SGQZ   보그워너평택 유한책임회사     5      30
# 1                         BOLT-ARM  S012       영신금속공업(주)     0     700
# ...

# %%
path = 'Data\\UI-PM-890 (포장사양등록)\\포장사양등록_2018-2020_1.csv'
pack_df = pd.read_csv(path, index_col = None)
pack_df
# Out:
# C:\Users\vfgtr\anaconda3\envs\learning\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (26,78) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        CHK_BOX  PACK_FLOW_FG  CORP_CD                        CUST  \
# 0            0             0        1    ACBD-28625A7110-20181023
# 1            0             0        1    ACBD-28625A7210-20181023
# 2            0             0        1    ACBD-28630G2100-20200207
# 3            0             0        1    ACBD-28630G2100-20190715
# 4            0             0        1    ACBD-28630G2100-20181023
# ...        ...           ...      ...                         ...
# 64994        0             0        1    HVCS-926305B000-20180817
# 64995        0             0        1    HVCS-926305B000-20180427
# 64996        0             0        1    HVCS-928045A100-20180418
# ...

# %%
column = ['APLY_STT_DT', 'PART_NO', 'PART_NM', 'CASE_CD', 'M_BOX_CD', 'UNIT_WT', 'GRS_WT']
new_column = ['적용일자', '부품번호', '부품명', '대박스코드', '중박스코드', '개당무게(g)', '총중량(kg)']
new_df = pd.DataFrame(columns = new_column)
new_df
# Out:
# Empty DataFrame
# Columns: [적용일자, 부품번호, 부품명, 대박스코드, 중박스코드, 개당무게(g), 총중량(kg)]
# Index: []

# %%
for i, col in enumerate(column):
    new_df[new_column[i]] = pack_df[col]
new_df
# Out:
#            적용일자          부품번호                    부품명   대박스코드  중박스코드 개당무게(g)  \
# 0      20181023    28625A7110            Seat_Sensor   TBMHW  CS558      25
# 1      20181023    28625A7210            Seat-Sensor   TBMHW  CS558      25
# 2      20200207    28630G2100           Bellows Assy   TBS1F  CM424     481
# 3      20190715    28630G2100           Bellows Assy   TBM1F  CM424     481
# 4      20181023    28630G2100           Bellows Assy   TBM1F  CM424     481
# ...         ...           ...                    ...     ...    ...     ...
# 64994  20180817    926305B000         LAMP ASSY-STEP  TBS34H  CS338     104
# 64995  20180427    926305B000         LAMP ASSY-STEP  TBS34H  CS338     104
# 64996  20180418    928045A100     BLANKING-ROOM LAMP   TBMHW  CS558       1
# 64997  20180816  928045A100SH     BLANKING-ROOM LAMP   TBMHW  CS558       1
# 64998  20180514    928105A111  LAMP ASSY-FLUORESCENT  TBS34H    DUM     997
#
#       총중량(kg)
# 0          13
# 1          13
# ...

# %%
new_df.to_csv('temp.csv', encoding='utf-8-sig')

# %%
#243212B000
#CHAIN-TIMING
#CS558
df2 = new_df_2[(new_df['부품명'] == 'BOLT-EYE JOINT') & (new_df['중박스코드'] == 'CS558')]
df2
# Out:
# C:\Users\vfgtr\anaconda3\envs\learning\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#            적용일자        부품번호       부품명    대박스코드 중박스코드 개당무게(g) 총중량(kg)
# 61024  20150105  2411084700  CAMSHAFT  SB240HW   DUM  23,488   1,568
# 61025  20140327  2411084700  CAMSHAFT    TBMHW   DUM  23,000     569

# %%
df2.sort_values(by='적용일자', ascending=False).head(1)
# Out:
#            적용일자        부품번호       부품명    대박스코드 중박스코드 개당무게(g) 총중량(kg)
# 61024  20150105  2411084700  CAMSHAFT  SB240HW   DUM  23,488   1,568

# %%
new_df_2 = new_df.drop_duplicates(keep='first', ignore_index=True)
new_df_2
# Out:
#            적용일자          부품번호                    부품명   대박스코드  중박스코드 개당무게(g)  \
# 0      20181023    28625A7110            Seat_Sensor   TBMHW  CS558      25
# 1      20181023    28625A7210            Seat-Sensor   TBMHW  CS558      25
# 2      20200207    28630G2100           Bellows Assy   TBS1F  CM424     481
# 3      20190715    28630G2100           Bellows Assy   TBM1F  CM424     481
# 4      20181023    28630G2100           Bellows Assy   TBM1F  CM424     481
# ...         ...           ...                    ...     ...    ...     ...
# 63905  20180817    926305B000         LAMP ASSY-STEP  TBS34H  CS338     104
# 63906  20180427    926305B000         LAMP ASSY-STEP  TBS34H  CS338     104
# 63907  20180418    928045A100     BLANKING-ROOM LAMP   TBMHW  CS558       1
# 63908  20180816  928045A100SH     BLANKING-ROOM LAMP   TBMHW  CS558       1
# 63909  20180514    928105A111  LAMP ASSY-FLUORESCENT  TBS34H    DUM     997
#
#       총중량(kg)
# 0          13
# 1          13
# ...
